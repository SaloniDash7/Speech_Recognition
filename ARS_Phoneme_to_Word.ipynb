# %%
import os
import shutil
import glob
from shutil import copyfile
import numpy as np

count=0
for subdir, dirs, files in os.walk('.\\TIMIT\\'):
    for file in files:
        fullFilename = os.path.join(subdir, file)
        filenameNoSuffix =  os.path.splitext(fullFilename)[0]
        if file.endswith('.WAV'):
            labelFilename = filenameNoSuffix + '.TXT'
            text = []
            with open(labelFilename,'r') as f:
                content=f.read()
                char_count=0
                content_string=""
                for char in content:
                    if char_count>7:
                        content_string+=char
                    char_count+=1
                print(content_string)
                content_string=np.array(content_string)
                count+=1
                print("File Number: " ,count)
                labelFilename = '.\\Text_Targets\\' + filenameNoSuffix.split('\\')[-2]+'-'+filenameNoSuffix.split('\\')[-1]+'.npy'
                print(labelFilename)
                np.save(labelFilename,content_string)
# Out:
# She had your dark suit in greasy wash water all year.
#
# File Number:  1
# .\Text_Targets\FAKS0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  2
# .\Text_Targets\FAKS0-SA2.npy
# His captain was thin and haggard and his beautiful boots were worn and shabby.
#
# File Number:  3
# .\Text_Targets\FAKS0-SI1573.npy
# The reasons for this dive seemed foolish now.
#
# File Number:  4
# .\Text_Targets\FAKS0-SI2203.npy
# Production may fall far below expectations.
#
# File Number:  5
# .\Text_Targets\FAKS0-SI943.npy
# Pizzerias are convenient for a quick lunch.
#
# File Number:  6
# .\Text_Targets\FAKS0-SX133.npy
# Put the butcher block table in the garage.
#
# File Number:  7
# .\Text_Targets\FAKS0-SX223.npy
# Drop five forms in the box before you go out.
#
# File Number:  8
# .\Text_Targets\FAKS0-SX313.npy
# Her wardrobe consists of only skirts and blouses.
#
# File Number:  9
# .\Text_Targets\FAKS0-SX403.npy
# Elderly people are often excluded.
#
# File Number:  10
# .\Text_Targets\FAKS0-SX43.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  11
# .\Text_Targets\FDAC1-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  12
# .\Text_Targets\FDAC1-SA2.npy
# Husky young man, he said with mock distaste.
#
# File Number:  13
# .\Text_Targets\FDAC1-SI1474.npy
# Ahah, he thought, a lush divorcee at last.
#
# File Number:  14
# .\Text_Targets\FDAC1-SI2104.npy
#  Thus technical efficiency is achieved at the expense of actual experience.
#
# File Number:  15
# .\Text_Targets\FDAC1-SI844.npy
# Objects made of pewter are beautiful.
#
# File Number:  16
# .\Text_Targets\FDAC1-SX124.npy
# The morning dew on the spider web glistened in the sun.
#
# File Number:  17
# .\Text_Targets\FDAC1-SX214.npy
# Cheap stockings run the first time they're worn.
#
# File Number:  18
# .\Text_Targets\FDAC1-SX304.npy
# Don't do Charlie's dirty dishes.
#
# File Number:  19
# .\Text_Targets\FDAC1-SX34.npy
# Calcium makes bones and teeth strong.
#
# File Number:  20
# .\Text_Targets\FDAC1-SX394.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  21
# .\Text_Targets\FELC0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  22
# .\Text_Targets\FELC0-SA2.npy
# In wage negotiations, the industry bargains as a unit with a single union.
#
# File Number:  23
# .\Text_Targets\FELC0-SI1386.npy
# Heave on those ropes; the boat's come unstuck.
#
# File Number:  24
# .\Text_Targets\FELC0-SI2016.npy
# Materials: ceramic modeling clay: red, white or buff.
#
# File Number:  25
# .\Text_Targets\FELC0-SI756.npy
# Artificial intelligence is for real.
#
# File Number:  26
# .\Text_Targets\FELC0-SX126.npy
# The small boy put the worm on the hook.
#
# File Number:  27
# .\Text_Targets\FELC0-SX216.npy
# A chosen few will become Generals.
#
# File Number:  28
# .\Text_Targets\FELC0-SX306.npy
# Only the most accomplished artists obtain popularity.
#
# File Number:  29
# .\Text_Targets\FELC0-SX36.npy
# The fish began to leap frantically on the surface of the small lake.
#
# File Number:  30
# .\Text_Targets\FELC0-SX396.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  31
# .\Text_Targets\FJEM0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  32
# .\Text_Targets\FJEM0-SA2.npy
# Dances alternated with sung or spoken verses.
#
# File Number:  33
# .\Text_Targets\FJEM0-SI1264.npy
# My father ran him off here six years ago.
#
# File Number:  34
# .\Text_Targets\FJEM0-SI1894.npy
# Here, he is, quite persuasively, the very embodiment of meanness and slyness.
#
# File Number:  35
# .\Text_Targets\FJEM0-SI634.npy
# The cat's meow always hurts my ears.
#
# File Number:  36
# .\Text_Targets\FJEM0-SX184.npy
# Cliff was soothed by the luxurious massage.
#
# File Number:  37
# .\Text_Targets\FJEM0-SX274.npy
# Each untimely income loss coincided with the breakdown of a heating system part.
#
# File Number:  38
# .\Text_Targets\FJEM0-SX364.npy
# Jane may earn more money by working hard.
#
# File Number:  39
# .\Text_Targets\FJEM0-SX4.npy
# Youngsters love common candy as treats.
#
# File Number:  40
# .\Text_Targets\FJEM0-SX94.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  41
# .\Text_Targets\MDAB0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  42
# .\Text_Targets\MDAB0-SA2.npy
# He has never, himself, done anything for which to be hated -- which of us has?
#
# File Number:  43
# .\Text_Targets\MDAB0-SI1039.npy
# Be excited and don't identify yourself.
#
# File Number:  44
# .\Text_Targets\MDAB0-SI1669.npy
# Sometimes, he coincided with my father's being at home.
#
# File Number:  45
# .\Text_Targets\MDAB0-SI2299.npy
# The bungalow was pleasantly situated near the shore.
#
# File Number:  46
# .\Text_Targets\MDAB0-SX139.npy
# Are you looking for employment?
#
# File Number:  47
# .\Text_Targets\MDAB0-SX229.npy
# A big goat idly ambled through the farmyard.
#
# File Number:  48
# .\Text_Targets\MDAB0-SX319.npy
# Eating spinach nightly increases strength miraculously.
#
# File Number:  49
# .\Text_Targets\MDAB0-SX409.npy
# At twilight on the twelfth day we'll have Chablis.
#
# File Number:  50
# .\Text_Targets\MDAB0-SX49.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  51
# .\Text_Targets\MJSW0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  52
# .\Text_Targets\MJSW0-SA2.npy
# The so-called vegetable ivory is the hard endosperm of the egg-sized seed.
#
# File Number:  53
# .\Text_Targets\MJSW0-SI1010.npy
# How did one join them?
#
# File Number:  54
# .\Text_Targets\MJSW0-SI1640.npy
# Dogs did something to one's ego.
#
# File Number:  55
# .\Text_Targets\MJSW0-SI2270.npy
# The best way to learn is to solve extra problems.
#
# File Number:  56
# .\Text_Targets\MJSW0-SX110.npy
# She wore warm, fleecy, woolen overalls.
#
# File Number:  57
# .\Text_Targets\MJSW0-SX20.npy
# Ralph controlled the stopwatch from the bleachers.
#
# File Number:  58
# .\Text_Targets\MJSW0-SX200.npy
# This brochure is particularly informative for a prospective buyer.
#
# File Number:  59
# .\Text_Targets\MJSW0-SX290.npy
# Why charge money for such garbage?
#
# File Number:  60
# .\Text_Targets\MJSW0-SX380.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  61
# .\Text_Targets\MREB0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  62
# .\Text_Targets\MREB0-SA2.npy
# Often, dominant stress simply indicates a centering of attention or emotion.
#
# File Number:  63
# .\Text_Targets\MREB0-SI1375.npy
# He had left her inviolate, thinking familiarity would gentle her in time.
#
# File Number:  64
# .\Text_Targets\MREB0-SI2005.npy
# Broil or toast as usual.
#
# File Number:  65
# .\Text_Targets\MREB0-SI745.npy
# The emblem depicts the Acropolis all aglow.
#
# File Number:  66
# .\Text_Targets\MREB0-SX115.npy
# Military personnel are expected to obey government orders.
#
# File Number:  67
# .\Text_Targets\MREB0-SX205.npy
# Only lawyers love millionaires.
#
# File Number:  68
# .\Text_Targets\MREB0-SX25.npy
# If Carol comes tomorrow, have her arrange for a meeting at two.
#
# File Number:  69
# .\Text_Targets\MREB0-SX295.npy
# His shoulder felt as if it were broken.
#
# File Number:  70
# .\Text_Targets\MREB0-SX385.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  71
# .\Text_Targets\MRJO0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  72
# .\Text_Targets\MRJO0-SA2.npy
# But within that framework he allowed for as much flexibility as possible.
#
# File Number:  73
# .\Text_Targets\MRJO0-SI1364.npy
# We came on as soon as we could.
#
# File Number:  74
# .\Text_Targets\MRJO0-SI1624.npy
# If necessary to replace both halves on grill, sear cuts and allot extra time.
#
# File Number:  75
# .\Text_Targets\MRJO0-SI734.npy
# He stole a dime from a beggar.
#
# File Number:  76
# .\Text_Targets\MRJO0-SX104.npy
# Before Thursday's exam, review every formula.
#
# File Number:  77
# .\Text_Targets\MRJO0-SX14.npy
# They enjoy it when I audition.
#
# File Number:  78
# .\Text_Targets\MRJO0-SX194.npy
# Jeff thought you argued in favor of a centrifuge purchase.
#
# File Number:  79
# .\Text_Targets\MRJO0-SX284.npy
# John cleans shellfish for a living.
#
# File Number:  80
# .\Text_Targets\MRJO0-SX374.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  81
# .\Text_Targets\MSJS1-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  82
# .\Text_Targets\MSJS1-SA2.npy
# You took me by surprise.
#
# File Number:  83
# .\Text_Targets\MSJS1-SI1899.npy
# The heavens refused to give up their weeping.
#
# File Number:  84
# .\Text_Targets\MSJS1-SI639.npy
# The idea of a central tank with lines to each house is not in itself a novelty.
#
# File Number:  85
# .\Text_Targets\MSJS1-SI869.npy
# Destroy every file related to my audits.
#
# File Number:  86
# .\Text_Targets\MSJS1-SX189.npy
# Alice's ability to work without supervision is noteworthy.
#
# File Number:  87
# .\Text_Targets\MSJS1-SX279.npy
# Bob papered over living room murals.
#
# File Number:  88
# .\Text_Targets\MSJS1-SX369.npy
# Where were you while we were away?
#
# File Number:  89
# .\Text_Targets\MSJS1-SX9.npy
# Medieval society was based on hierarchies.
#
# File Number:  90
# .\Text_Targets\MSJS1-SX99.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  91
# .\Text_Targets\MSTK0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  92
# .\Text_Targets\MSTK0-SA2.npy
# At the base of the rocky hillside, they left their horses and climbed on foot.
#
# File Number:  93
# .\Text_Targets\MSTK0-SI1024.npy
# You young men get to be my age, you won't take flu so lightly.
#
# File Number:  94
# .\Text_Targets\MSTK0-SI2222.npy
# A woman met a famous author at a literary tea.
#
# File Number:  95
# .\Text_Targets\MSTK0-SI2284.npy
# Objects made of pewter are beautiful.
#
# File Number:  96
# .\Text_Targets\MSTK0-SX124.npy
# The morning dew on the spider web glistened in the sun.
#
# File Number:  97
# .\Text_Targets\MSTK0-SX214.npy
# Cheap stockings run the first time they're worn.
#
# File Number:  98
# .\Text_Targets\MSTK0-SX304.npy
# Don't do Charlie's dirty dishes.
#
# File Number:  99
# .\Text_Targets\MSTK0-SX34.npy
# Calcium makes bones and teeth strong.
#
# File Number:  100
# .\Text_Targets\MSTK0-SX394.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  101
# .\Text_Targets\MWBT0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  102
# .\Text_Targets\MWBT0-SA2.npy
# However, the litter remained, augmented by several dozen lunchroom suppers.
#
# File Number:  103
# .\Text_Targets\MWBT0-SI1553.npy
# Books are for schnooks.
#
# File Number:  104
# .\Text_Targets\MWBT0-SI2183.npy
# To many experts, this trend was inevitable.
#
# File Number:  105
# .\Text_Targets\MWBT0-SI923.npy
# A muscular abdomen is good for your back.
#
# File Number:  106
# .\Text_Targets\MWBT0-SX113.npy
# The causeway ended abruptly at the shore.
#
# File Number:  107
# .\Text_Targets\MWBT0-SX203.npy
# Those musicians harmonize marvelously.
#
# File Number:  108
# .\Text_Targets\MWBT0-SX23.npy
# Please take this dirty table cloth to the cleaners for me.
#
# File Number:  109
# .\Text_Targets\MWBT0-SX293.npy
# The carpet cleaners shampooed our oriental rug.
#
# File Number:  110
# .\Text_Targets\MWBT0-SX383.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  111
# .\Text_Targets\FCMR0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  112
# .\Text_Targets\FCMR0-SA2.npy
# What obsessions had she picked up during these long nights of talk?
#
# File Number:  113
# .\Text_Targets\FCMR0-SI1105.npy
# And possessed himself -- how?
#
# File Number:  114
# .\Text_Targets\FCMR0-SI1735.npy
# They will take a wedding trip later.
#
# File Number:  115
# .\Text_Targets\FCMR0-SI475.npy
# The emblem depicts the Acropolis all aglow.
#
# File Number:  116
# .\Text_Targets\FCMR0-SX115.npy
# Military personnel are expected to obey government orders.
#
# File Number:  117
# .\Text_Targets\FCMR0-SX205.npy
# Only lawyers love millionaires.
#
# File Number:  118
# .\Text_Targets\FCMR0-SX25.npy
# If Carol comes tomorrow, have her arrange for a meeting at two.
#
# File Number:  119
# .\Text_Targets\FCMR0-SX295.npy
# His shoulder felt as if it were broken.
#
# File Number:  120
# .\Text_Targets\FCMR0-SX385.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  121
# .\Text_Targets\FDRD1-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  122
# .\Text_Targets\FDRD1-SA2.npy
# He had plunged into the dark woods beyond.
#
# File Number:  123
# .\Text_Targets\FDRD1-SI1544.npy
# One had to believe in final events or one was stranded in the abyss of nothing.
#
# File Number:  124
# .\Text_Targets\FDRD1-SI1566.npy
# Let's be fine superior people of great dignity, he said as if he were joking.
#
# File Number:  125
# .\Text_Targets\FDRD1-SI2149.npy
# He stole a dime from a beggar.
#
# File Number:  126
# .\Text_Targets\FDRD1-SX104.npy
# Before Thursday's exam, review every formula.
#
# File Number:  127
# .\Text_Targets\FDRD1-SX14.npy
# They enjoy it when I audition.
#
# File Number:  128
# .\Text_Targets\FDRD1-SX194.npy
# Jeff thought you argued in favor of a centrifuge purchase.
#
# File Number:  129
# .\Text_Targets\FDRD1-SX284.npy
# John cleaned shellfish for a living.
#
# File Number:  130
# .\Text_Targets\FDRD1-SX374.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  131
# .\Text_Targets\FJAS0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  132
# .\Text_Targets\FJAS0-SA2.npy
# Now that this is at odds with our meaning may be shown as follows.
#
# File Number:  133
# .\Text_Targets\FJAS0-SI1400.npy
# Our boy didn't chicken out, no sir.
#
# File Number:  134
# .\Text_Targets\FJAS0-SI2030.npy
# Vases: make same as salt and pepper shakers, leaving off top pieces.
#
# File Number:  135
# .\Text_Targets\FJAS0-SI770.npy
# Agricultural products are unevenly distributed.
#
# File Number:  136
# .\Text_Targets\FJAS0-SX140.npy
# Allow leeway here, but rationalize all errors.
#
# File Number:  137
# .\Text_Targets\FJAS0-SX230.npy
# The nearest synagogue may not be within walking distance.
#
# File Number:  138
# .\Text_Targets\FJAS0-SX320.npy
# Greg buys fresh milk each weekday morning.
#
# File Number:  139
# .\Text_Targets\FJAS0-SX410.npy
# Catastrophic economic cutbacks neglect the poor.
#
# File Number:  140
# .\Text_Targets\FJAS0-SX50.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  141
# .\Text_Targets\FJRE0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  142
# .\Text_Targets\FJRE0-SA2.npy
# Each is still glorified as a national hero.
#
# File Number:  143
# .\Text_Targets\FJRE0-SI1116.npy
# The jaded amorist conjured up pictures of the blasphemous rites with relish.
#
# File Number:  144
# .\Text_Targets\FJRE0-SI1587.npy
# His salary had reached the ten thousand mark.
#
# File Number:  145
# .\Text_Targets\FJRE0-SI1746.npy
# Artificial intelligence is for real.
#
# File Number:  146
# .\Text_Targets\FJRE0-SX126.npy
# The small boy put the worm on the hook.
#
# File Number:  147
# .\Text_Targets\FJRE0-SX216.npy
# A chosen few will become Generals.
#
# File Number:  148
# .\Text_Targets\FJRE0-SX306.npy
# Only the most accomplished artists obtain popularity.
#
# File Number:  149
# .\Text_Targets\FJRE0-SX36.npy
# The fish began to leap frantically on the surface of the small lake.
#
# File Number:  150
# .\Text_Targets\FJRE0-SX396.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  151
# .\Text_Targets\FJWB0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  152
# .\Text_Targets\FJWB0-SA2.npy
# Ballets were used in opera from its beginning.
#
# File Number:  153
# .\Text_Targets\FJWB0-SI1265.npy
# He is a man of major talent -- but a man of solitary, uncertain impulses.
#
# File Number:  154
# .\Text_Targets\FJWB0-SI635.npy
# They were a vagabond lot and considered to be shady and undesirable characters.
#
# File Number:  155
# .\Text_Targets\FJWB0-SI992.npy
# Did you buy any corduroy overalls?
#
# File Number:  156
# .\Text_Targets\FJWB0-SX185.npy
# Steve wore a bright red cashmere sweater.
#
# File Number:  157
# .\Text_Targets\FJWB0-SX275.npy
# The gunman kept his victim cornered at gunpoint for three hours.
#
# File Number:  158
# .\Text_Targets\FJWB0-SX365.npy
# She is thinner than I am.
#
# File Number:  159
# .\Text_Targets\FJWB0-SX5.npy
# Iguanas and alligators are tropical reptiles.
#
# File Number:  160
# .\Text_Targets\FJWB0-SX95.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  161
# .\Text_Targets\FPAS0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  162
# .\Text_Targets\FPAS0-SA2.npy
# Laboratory astrophysics.
#
# File Number:  163
# .\Text_Targets\FPAS0-SI1272.npy
# Pretty soon a woman came along carrying a folded umbrella as a walking stick.
#
# File Number:  164
# .\Text_Targets\FPAS0-SI2204.npy
# If the farm is rented, the rent must be paid.
#
# File Number:  165
# .\Text_Targets\FPAS0-SI944.npy
# December and January are nice months to spend in Miami.
#
# File Number:  166
# .\Text_Targets\FPAS0-SX134.npy
# How good is your endurance?
#
# File Number:  167
# .\Text_Targets\FPAS0-SX224.npy
# If people were more generous, there would be no need for welfare.
#
# File Number:  168
# .\Text_Targets\FPAS0-SX314.npy
# Barb burned paper and leaves in a big bonfire.
#
# File Number:  169
# .\Text_Targets\FPAS0-SX404.npy
# Basketball can be an entertaining sport.
#
# File Number:  170
# .\Text_Targets\FPAS0-SX44.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  171
# .\Text_Targets\FRAM1-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  172
# .\Text_Targets\FRAM1-SA2.npy
# It provides a frame for the sampling census.
#
# File Number:  173
# .\Text_Targets\FRAM1-SI1360.npy
# Progress is being made, too, in improving motorists' access to many turnpikes.
#
# File Number:  174
# .\Text_Targets\FRAM1-SI522.npy
# Another memo for sightseers: bring your camera along to museums.
#
# File Number:  175
# .\Text_Targets\FRAM1-SI730.npy
# Are your grades higher or lower than Nancy's?
#
# File Number:  176
# .\Text_Targets\FRAM1-SX10.npy
# Project development was proceeding too slowly.
#
# File Number:  177
# .\Text_Targets\FRAM1-SX100.npy
# Serve the coleslaw after I add the oil.
#
# File Number:  178
# .\Text_Targets\FRAM1-SX190.npy
# The oasis was a mirage.
#
# File Number:  179
# .\Text_Targets\FRAM1-SX280.npy
# That noise problem grows more annoying each day.
#
# File Number:  180
# .\Text_Targets\FRAM1-SX370.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  181
# .\Text_Targets\FSLB1-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  182
# .\Text_Targets\FSLB1-SA2.npy
# When suitably lighted, what would it look like?
#
# File Number:  183
# .\Text_Targets\FSLB1-SI1904.npy
# All are well written and are overwritten.
#
# File Number:  184
# .\Text_Targets\FSLB1-SI644.npy
# It was applied with a compost shredder made from a converted manure spreader.
#
# File Number:  185
# .\Text_Targets\FSLB1-SI891.npy
# He stole a dime from a beggar.
#
# File Number:  186
# .\Text_Targets\FSLB1-SX104.npy
# Before Thursday's exam, review every formula.
#
# File Number:  187
# .\Text_Targets\FSLB1-SX14.npy
# They enjoy it when I audition.
#
# File Number:  188
# .\Text_Targets\FSLB1-SX194.npy
# Jeff thought you argued in favor of a centrifuge purchase.
#
# File Number:  189
# .\Text_Targets\FSLB1-SX284.npy
# John cleans shellfish for a living.
#
# File Number:  190
# .\Text_Targets\FSLB1-SX374.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  191
# .\Text_Targets\MABW0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  192
# .\Text_Targets\MABW0-SA2.npy
# Princes and factions clashed in the open street and died on the open scaffold.
#
# File Number:  193
# .\Text_Targets\MABW0-SI1230.npy
# There were other farmhouses nearby.
#
# File Number:  194
# .\Text_Targets\MABW0-SI1664.npy
# Just long enough to make you feel important.
#
# File Number:  195
# .\Text_Targets\MABW0-SI2294.npy
# December and January are nice months to spend in Miami.
#
# File Number:  196
# .\Text_Targets\MABW0-SX134.npy
# How good is your endurance?
#
# File Number:  197
# .\Text_Targets\MABW0-SX224.npy
# If people were more generous, there would be no need for welfare.
#
# File Number:  198
# .\Text_Targets\MABW0-SX314.npy
# Barb burned paper and leaves in a big bonfire.
#
# File Number:  199
# .\Text_Targets\MABW0-SX404.npy
# Basketball can be an entertaining sport.
#
# File Number:  200
# .\Text_Targets\MABW0-SX44.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  201
# .\Text_Targets\MBJK0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  202
# .\Text_Targets\MBJK0-SA2.npy
# Diversity of perception, yes; diversity of fact, yes.
#
# File Number:  203
# .\Text_Targets\MBJK0-SI1175.npy
# Some of them ignored the text and had apparently memorized the words long ago.
#
# File Number:  204
# .\Text_Targets\MBJK0-SI2128.npy
# But how little love we give him!
#
# File Number:  205
# .\Text_Targets\MBJK0-SI545.npy
# Did you buy any corduroy overalls?
#
# File Number:  206
# .\Text_Targets\MBJK0-SX185.npy
# Steve wore a bright red cashmere sweater.
#
# File Number:  207
# .\Text_Targets\MBJK0-SX275.npy
# The gunman kept his victim cornered at gunpoint for three hours.
#
# File Number:  208
# .\Text_Targets\MBJK0-SX365.npy
# She is thinner than I am.
#
# File Number:  209
# .\Text_Targets\MBJK0-SX5.npy
# Iguanas and alligators are tropical reptiles.
#
# File Number:  210
# .\Text_Targets\MBJK0-SX95.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  211
# .\Text_Targets\MCCS0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  212
# .\Text_Targets\MCCS0-SA2.npy
# This can be done to a high degree of accuracy by existing surveying techniques.
#
# File Number:  213
# .\Text_Targets\MCCS0-SI1469.npy
# But she suffered in her off-duty hours.
#
# File Number:  214
# .\Text_Targets\MCCS0-SI2099.npy
# Practically all forecasts mention new and exciting products on the horizon.
#
# File Number:  215
# .\Text_Targets\MCCS0-SI839.npy
# The misquote was retracted with an apology.
#
# File Number:  216
# .\Text_Targets\MCCS0-SX119.npy
# Michael colored the bedroom wall with crayons.
#
# File Number:  217
# .\Text_Targets\MCCS0-SX209.npy
#  Help Greg to pick a peck of potatoes.
#
# File Number:  218
# .\Text_Targets\MCCS0-SX29.npy
# Shaving cream is a popular item on Halloween.
#
# File Number:  219
# .\Text_Targets\MCCS0-SX299.npy
# They own a big house in the remote countryside.
#
# File Number:  220
# .\Text_Targets\MCCS0-SX389.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  221
# .\Text_Targets\MCEM0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  222
# .\Text_Targets\MCEM0-SA2.npy
# Do they make class-biased decisions?
#
# File Number:  223
# .\Text_Targets\MCEM0-SI1398.npy
# He took his mask from his forehead and threw it, unexpectedly, across the deck.
#
# File Number:  224
# .\Text_Targets\MCEM0-SI2028.npy
# Make lid for sugar bowl the same as jar lids, omitting design disk.
#
# File Number:  225
# .\Text_Targets\MCEM0-SI768.npy
# The clumsy customer spilled some expensive perfume.
#
# File Number:  226
# .\Text_Targets\MCEM0-SX138.npy
# The viewpoint overlooked the ocean.
#
# File Number:  227
# .\Text_Targets\MCEM0-SX228.npy
# Please dig my potatoes up before frost.
#
# File Number:  228
# .\Text_Targets\MCEM0-SX318.npy
# I'd ride the subway, but I haven't enough change.
#
# File Number:  229
# .\Text_Targets\MCEM0-SX408.npy
# Grandmother outgrew her upbringing in petticoats.
#
# File Number:  230
# .\Text_Targets\MCEM0-SX48.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  231
# .\Text_Targets\MDBB0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  232
# .\Text_Targets\MDBB0-SA2.npy
# Passing dogs were greeted with a cordial bark.
#
# File Number:  233
# .\Text_Targets\MDBB0-SI1195.npy
# He wasn't likely to come down with hot chills and puzzling striped fever.
#
# File Number:  234
# .\Text_Targets\MDBB0-SI1825.npy
# Stacked heels are also popular on dressy or tailored shoes.
#
# File Number:  235
# .\Text_Targets\MDBB0-SI565.npy
# The emblem depicts the Acropolis all aglow.
#
# File Number:  236
# .\Text_Targets\MDBB0-SX115.npy
# Military personnel are expected to obey government orders.
#
# File Number:  237
# .\Text_Targets\MDBB0-SX205.npy
# Only lawyers love millionaires.
#
# File Number:  238
# .\Text_Targets\MDBB0-SX25.npy
# If Carol comes tomorrow, have her arrange for a meeting at two.
#
# File Number:  239
# .\Text_Targets\MDBB0-SX295.npy
# His shoulder felt as if it were broken.
#
# File Number:  240
# .\Text_Targets\MDBB0-SX385.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  241
# .\Text_Targets\MDLD0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  242
# .\Text_Targets\MDLD0-SA2.npy
# Then he -- then what?
#
# File Number:  243
# .\Text_Targets\MDLD0-SI1543.npy
# He wadded his sweat shirt into a ball and stripped down to his swimming trunks.
#
# File Number:  244
# .\Text_Targets\MDLD0-SI2173.npy
# Do you love to run up a hem, sew on buttons, make neat buttonholes?
#
# File Number:  245
# .\Text_Targets\MDLD0-SI913.npy
# Call an ambulance for medical assistance.
#
# File Number:  246
# .\Text_Targets\MDLD0-SX103.npy
# Swing your arm as high as you can.
#
# File Number:  247
# .\Text_Targets\MDLD0-SX13.npy
# Why buy oil when you always use mine?
#
# File Number:  248
# .\Text_Targets\MDLD0-SX193.npy
# Planned parenthood organizations promote birth control.
#
# File Number:  249
# .\Text_Targets\MDLD0-SX283.npy
# A boring novel is a superb sleeping pill.
#
# File Number:  250
# .\Text_Targets\MDLD0-SX373.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  251
# .\Text_Targets\MGWT0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  252
# .\Text_Targets\MGWT0-SA2.npy
# Fists pummeled him as he staggered forward.
#
# File Number:  253
# .\Text_Targets\MGWT0-SI1539.npy
# Upstairs, busy feet, showering like raindrops, pattered around her room.
#
# File Number:  254
# .\Text_Targets\MGWT0-SI2169.npy
# Compulsory retirement at sixty-five looms on our horizon.
#
# File Number:  255
# .\Text_Targets\MGWT0-SI909.npy
# Destroy every file related to my audits.
#
# File Number:  256
# .\Text_Targets\MGWT0-SX189.npy
# Alice's ability to work without supervision is noteworthy.
#
# File Number:  257
# .\Text_Targets\MGWT0-SX279.npy
# Bob papered over the living room murals.
#
# File Number:  258
# .\Text_Targets\MGWT0-SX369.npy
# Where were you while we were away?
#
# File Number:  259
# .\Text_Targets\MGWT0-SX9.npy
# Medieval society was based on hierarchies.
#
# File Number:  260
# .\Text_Targets\MGWT0-SX99.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  261
# .\Text_Targets\MJAR0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  262
# .\Text_Targets\MJAR0-SA2.npy
# How's it strike you, foul or fair?
#
# File Number:  263
# .\Text_Targets\MJAR0-SI1988.npy
# Weakness in leadership.
#
# File Number:  264
# .\Text_Targets\MJAR0-SI2247.npy
# Poach the apples in this syrup for twelve minutes, drain them, and cool.
#
# File Number:  265
# .\Text_Targets\MJAR0-SI728.npy
# Who authorized the unlimited expense account?
#
# File Number:  266
# .\Text_Targets\MJAR0-SX188.npy
# To further his prestige, he occasionally reads the Wall Street Journal.
#
# File Number:  267
# .\Text_Targets\MJAR0-SX278.npy
# Lori's costume needed black gloves to be completely elegant.
#
# File Number:  268
# .\Text_Targets\MJAR0-SX368.npy
# Why yell or worry over silly items?
#
# File Number:  269
# .\Text_Targets\MJAR0-SX8.npy
# Guess the question from the answer.
#
# File Number:  270
# .\Text_Targets\MJAR0-SX98.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  271
# .\Text_Targets\MMDB1-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  272
# .\Text_Targets\MMDB1-SA2.npy
# He makes me uncomfortable.
#
# File Number:  273
# .\Text_Targets\MMDB1-SI1625.npy
# He swung around, eyes toward the bedroom, some fifteen feet away.
#
# File Number:  274
# .\Text_Targets\MMDB1-SI2255.npy
# At different times he served as glee-club and choir leader and as organist.
#
# File Number:  275
# .\Text_Targets\MMDB1-SI995.npy
# Did you buy any corduroy overalls?
#
# File Number:  276
# .\Text_Targets\MMDB1-SX185.npy
# Steve wore a bright red cashmere sweater.
#
# File Number:  277
# .\Text_Targets\MMDB1-SX275.npy
# The gunman kept his victim cornered at gunpoint for three hours.
#
# File Number:  278
# .\Text_Targets\MMDB1-SX365.npy
# She is thinner than I am.
#
# File Number:  279
# .\Text_Targets\MMDB1-SX5.npy
# Iguanas and alligators are tropical reptiles.
#
# File Number:  280
# .\Text_Targets\MMDB1-SX95.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  281
# .\Text_Targets\MMDM2-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  282
# .\Text_Targets\MMDM2-SA2.npy
# Poultry: results of irradiation tests with poultry have been quite successful.
#
# File Number:  283
# .\Text_Targets\MMDM2-SI1452.npy
# A sleepy voice answered.
#
# File Number:  284
# .\Text_Targets\MMDM2-SI1555.npy
# You're boiling milk, ain't you?
#
# File Number:  285
# .\Text_Targets\MMDM2-SI2082.npy
# Special task forces rescue hostages from kidnappers.
#
# File Number:  286
# .\Text_Targets\MMDM2-SX102.npy
# Will Robin wear a yellow lily?
#
# File Number:  287
# .\Text_Targets\MMDM2-SX12.npy
# Straw hats are out of fashion this year.
#
# File Number:  288
# .\Text_Targets\MMDM2-SX192.npy
# The tooth fairy forgot to come when Roger's tooth fell out.
#
# File Number:  289
# .\Text_Targets\MMDM2-SX282.npy
# That diagram makes sense only after much study.
#
# File Number:  290
# .\Text_Targets\MMDM2-SX372.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  291
# .\Text_Targets\MPDF0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  292
# .\Text_Targets\MPDF0-SA2.npy
# The feet wore army shoes, in obvious disrepair.
#
# File Number:  293
# .\Text_Targets\MPDF0-SI1542.npy
# Strength began to zip up and down his chest.
#
# File Number:  294
# .\Text_Targets\MPDF0-SI2172.npy
# You may amaze yourself and acquire a real knack for it.
#
# File Number:  295
# .\Text_Targets\MPDF0-SI912.npy
# Special task forces rescue hostages from kidnappers.
#
# File Number:  296
# .\Text_Targets\MPDF0-SX102.npy
# Will Robin wear a yellow lily?
#
# File Number:  297
# .\Text_Targets\MPDF0-SX12.npy
# Straw hats are out of fashion this year.
#
# File Number:  298
# .\Text_Targets\MPDF0-SX192.npy
# The tooth fairy forgot to come when Roger's tooth fell out.
#
# File Number:  299
# .\Text_Targets\MPDF0-SX282.npy
# That diagram makes sense only after much study.
#
# File Number:  300
# .\Text_Targets\MPDF0-SX372.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  301
# .\Text_Targets\MPGL0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  302
# .\Text_Targets\MPGL0-SA2.npy
# This does not allow the mystery to invade us.
#
# File Number:  303
# .\Text_Targets\MPGL0-SI1099.npy
# Shrugs met that, from room clerks, from bellhops.
#
# File Number:  304
# .\Text_Targets\MPGL0-SI1729.npy
# In fact our whole defensive unit did a good job.
#
# File Number:  305
# .\Text_Targets\MPGL0-SI469.npy
# She slipped and sprained her ankle on the steep slope.
#
# File Number:  306
# .\Text_Targets\MPGL0-SX109.npy
# Aluminum silverware can often be flimsy.
#
# File Number:  307
# .\Text_Targets\MPGL0-SX19.npy
# Young children should avoid exposure to contagious diseases.
#
# File Number:  308
# .\Text_Targets\MPGL0-SX199.npy
# Weatherproof galoshes are very useful in Seattle.
#
# File Number:  309
# .\Text_Targets\MPGL0-SX289.npy
# Pam gives driving lessons on Thursdays.
#
# File Number:  310
# .\Text_Targets\MPGL0-SX379.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  311
# .\Text_Targets\MRCZ0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  312
# .\Text_Targets\MRCZ0-SA2.npy
# It gave the rubberized fabric a dull gleam, like metal.
#
# File Number:  313
# .\Text_Targets\MRCZ0-SI1541.npy
# How long would it be occupied?
#
# File Number:  314
# .\Text_Targets\MRCZ0-SI2171.npy
# This is followed by a boom in conferences.
#
# File Number:  315
# .\Text_Targets\MRCZ0-SI911.npy
# Kindergarten children decorate their classrooms for all holidays.
#
# File Number:  316
# .\Text_Targets\MRCZ0-SX101.npy
# He will allow a rare lie.
#
# File Number:  317
# .\Text_Targets\MRCZ0-SX11.npy
# Withdraw all phony accusations at once.
#
# File Number:  318
# .\Text_Targets\MRCZ0-SX191.npy
# Cory and Trish played tag with beach balls for hours.
#
# File Number:  319
# .\Text_Targets\MRCZ0-SX281.npy
# Right now may not be the best time for business mergers.
#
# File Number:  320
# .\Text_Targets\MRCZ0-SX371.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  321
# .\Text_Targets\MRGG0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  322
# .\Text_Targets\MRGG0-SA2.npy
# They close sometime after eight.
#
# File Number:  323
# .\Text_Targets\MRGG0-SI1199.npy
# His body processes only slowed down enough for him to dispel fatigue poisons.
#
# File Number:  324
# .\Text_Targets\MRGG0-SI1829.npy
# Most of us brush our teeth by hand.
#
# File Number:  325
# .\Text_Targets\MRGG0-SI569.npy
# The misquote was retracted with an apology.
#
# File Number:  326
# .\Text_Targets\MRGG0-SX119.npy
# Michael colored the bedroom wall with crayons.
#
# File Number:  327
# .\Text_Targets\MRGG0-SX209.npy
# Help Greg to pick a peck of potatoes.
#
# File Number:  328
# .\Text_Targets\MRGG0-SX29.npy
# Shaving cream is a popular item on Halloween.
#
# File Number:  329
# .\Text_Targets\MRGG0-SX299.npy
# They own a big house in the remote countryside.
#
# File Number:  330
# .\Text_Targets\MRGG0-SX389.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  331
# .\Text_Targets\MTAS1-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  332
# .\Text_Targets\MTAS1-SA2.npy
# You don't eat enough, honey.
#
# File Number:  333
# .\Text_Targets\MTAS1-SI1473.npy
# He gave a short hard laugh and looked at her knowingly.
#
# File Number:  334
# .\Text_Targets\MTAS1-SI2098.npy
# Increasing tempo of new product development.
#
# File Number:  335
# .\Text_Targets\MTAS1-SI838.npy
# Combine all the ingredients in a large bowl.
#
# File Number:  336
# .\Text_Targets\MTAS1-SX118.npy
# Rob sat by the pond and sketched the stray geese.
#
# File Number:  337
# .\Text_Targets\MTAS1-SX208.npy
# Beg that guard for one gallon of gas.
#
# File Number:  338
# .\Text_Targets\MTAS1-SX28.npy
# I'd rather not buy these shoes than be overcharged.
#
# File Number:  339
# .\Text_Targets\MTAS1-SX298.npy
# Her right hand aches whenever the barometric pressure changes.
#
# File Number:  340
# .\Text_Targets\MTAS1-SX388.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  341
# .\Text_Targets\MTMR0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  342
# .\Text_Targets\MTMR0-SA2.npy
# A detailed study of this latter phenomenon was not attempted in this paper.
#
# File Number:  343
# .\Text_Targets\MTMR0-SI1303.npy
# Beat me to death in front of a hundred people.
#
# File Number:  344
# .\Text_Targets\MTMR0-SI1933.npy
# Psychologically the reception should be the climax, following the sermon.
#
# File Number:  345
# .\Text_Targets\MTMR0-SI673.npy
# Pizzerias are convenient for a quick lunch.
#
# File Number:  346
# .\Text_Targets\MTMR0-SX133.npy
# Put the butcher block table in the garage.
#
# File Number:  347
# .\Text_Targets\MTMR0-SX223.npy
# Drop five forms in the box before you go out.
#
# File Number:  348
# .\Text_Targets\MTMR0-SX313.npy
# Her wardrobe consists of only skirts and blouses.
#
# File Number:  349
# .\Text_Targets\MTMR0-SX403.npy
# Elderly people are often excluded.
#
# File Number:  350
# .\Text_Targets\MTMR0-SX43.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  351
# .\Text_Targets\MWEW0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  352
# .\Text_Targets\MWEW0-SA2.npy
# But in this one section we welcomed auditors.
#
# File Number:  353
# .\Text_Targets\MWEW0-SI1361.npy
# Lot of people will roam the streets in costumes and masks, and having a ball.
#
# File Number:  354
# .\Text_Targets\MWEW0-SI1991.npy
# A few years later the dome fell in.
#
# File Number:  355
# .\Text_Targets\MWEW0-SI731.npy
# Kindergarten children decorate their classrooms for all holidays.
#
# File Number:  356
# .\Text_Targets\MWEW0-SX101.npy
# He will allow a rare lie.
#
# File Number:  357
# .\Text_Targets\MWEW0-SX11.npy
# Withdraw all phony accusations at once.
#
# File Number:  358
# .\Text_Targets\MWEW0-SX191.npy
# Cory and Trish played tag with beach balls for hours.
#
# File Number:  359
# .\Text_Targets\MWEW0-SX281.npy
# Right now may not be the best time for business mergers.
#
# File Number:  360
# .\Text_Targets\MWEW0-SX371.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  361
# .\Text_Targets\MWVW0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  362
# .\Text_Targets\MWVW0-SA2.npy
# Or: does he get exercise?
#
# File Number:  363
# .\Text_Targets\MWVW0-SI1476.npy
# Our key salesmen are in appliances and cosmetics.
#
# File Number:  364
# .\Text_Targets\MWVW0-SI2106.npy
# This brings us to the question of accreditation of art schools in general.
#
# File Number:  365
# .\Text_Targets\MWVW0-SI846.npy
# Artificial intelligence is for real.
#
# File Number:  366
# .\Text_Targets\MWVW0-SX126.npy
# The small boy put the worm on the hook.
#
# File Number:  367
# .\Text_Targets\MWVW0-SX216.npy
# A chosen few will become Generals.
#
# File Number:  368
# .\Text_Targets\MWVW0-SX306.npy
# Only the most accomplished artists obtain popularity.
#
# File Number:  369
# .\Text_Targets\MWVW0-SX36.npy
# The fish began to leap frantically on the surface of the small lake.
#
# File Number:  370
# .\Text_Targets\MWVW0-SX396.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  371
# .\Text_Targets\FCMH0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  372
# .\Text_Targets\FCMH0-SA2.npy
# Originally, the main types used were various compositions of polyesters.
#
# File Number:  373
# .\Text_Targets\FCMH0-SI1454.npy
# What about a tea room, then?
#
# File Number:  374
# .\Text_Targets\FCMH0-SI2084.npy
# Several firms are merchandising enzyme preparation through feed manufacturers.
#
# File Number:  375
# .\Text_Targets\FCMH0-SI824.npy
# He stole a dime from a beggar.
#
# File Number:  376
# .\Text_Targets\FCMH0-SX104.npy
# Before Thursday's exam, review every formula.
#
# File Number:  377
# .\Text_Targets\FCMH0-SX14.npy
# They enjoy it when I audition.
#
# File Number:  378
# .\Text_Targets\FCMH0-SX194.npy
# Jeff thought you argued in favor of a centrifuge purchase.
#
# File Number:  379
# .\Text_Targets\FCMH0-SX284.npy
# John cleans shellfish for a living.
#
# File Number:  380
# .\Text_Targets\FCMH0-SX374.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  381
# .\Text_Targets\FKMS0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  382
# .\Text_Targets\FKMS0-SA2.npy
# Perhaps it was right; perhaps it was just.
#
# File Number:  383
# .\Text_Targets\FKMS0-SI1490.npy
# He paused, then added: "Everything on a ship is a weapon."
#
# File Number:  384
# .\Text_Targets\FKMS0-SI2120.npy
# These include: leaves of absences, illnesses, and layoffs.
#
# File Number:  385
# .\Text_Targets\FKMS0-SI860.npy
# Agricultural products are unevenly distributed.
#
# File Number:  386
# .\Text_Targets\FKMS0-SX140.npy
# Allow leeway here, but rationalize all errors.
#
# File Number:  387
# .\Text_Targets\FKMS0-SX230.npy
# The nearest synagogue may not be within walking distance.
#
# File Number:  388
# .\Text_Targets\FKMS0-SX320.npy
# Greg buys fresh milk each weekday morning.
#
# File Number:  389
# .\Text_Targets\FKMS0-SX410.npy
# Catastrophic economic cutbacks neglect the poor.
#
# File Number:  390
# .\Text_Targets\FKMS0-SX50.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  391
# .\Text_Targets\FPKT0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  392
# .\Text_Targets\FPKT0-SA2.npy
# A carriage crunched by, its dim lights filtering through the gloom.
#
# File Number:  393
# .\Text_Targets\FPKT0-SI1538.npy
# They make us conformists look good.
#
# File Number:  394
# .\Text_Targets\FPKT0-SI2168.npy
# We always thought we would die with our boots on.
#
# File Number:  395
# .\Text_Targets\FPKT0-SI908.npy
# Who authorized the unlimited expense account?
#
# File Number:  396
# .\Text_Targets\FPKT0-SX188.npy
# To further his prestige, he occasionally reads the Wall Street Journal.
#
# File Number:  397
# .\Text_Targets\FPKT0-SX278.npy
# Lori's costume needed black gloves to be completely elegant.
#
# File Number:  398
# .\Text_Targets\FPKT0-SX368.npy
# Why yell or worry over silly items?
#
# File Number:  399
# .\Text_Targets\FPKT0-SX8.npy
# Guess the question from the answer.
#
# File Number:  400
# .\Text_Targets\FPKT0-SX98.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  401
# .\Text_Targets\MBDG0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  402
# .\Text_Targets\MBDG0-SA2.npy
# We can, however, maximize its expected value.
#
# File Number:  403
# .\Text_Targets\MBDG0-SI1463.npy
# He then offered his own estimate of the weather, which was unenthusiastic.
#
# File Number:  404
# .\Text_Targets\MBDG0-SI2093.npy
# Less personal salesmanship.
#
# File Number:  405
# .\Text_Targets\MBDG0-SI833.npy
# A muscular abdomen is good for your back.
#
# File Number:  406
# .\Text_Targets\MBDG0-SX113.npy
# The causeway ended abruptly at the shore.
#
# File Number:  407
# .\Text_Targets\MBDG0-SX203.npy
# Those musicians harmonize marvelously.
#
# File Number:  408
# .\Text_Targets\MBDG0-SX23.npy
# Please take this dirty table cloth to the cleaners for me.
#
# File Number:  409
# .\Text_Targets\MBDG0-SX293.npy
# The carpet cleaners shampooed our oriental rug.
#
# File Number:  410
# .\Text_Targets\MBDG0-SX383.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  411
# .\Text_Targets\MBWM0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  412
# .\Text_Targets\MBWM0-SA2.npy
# It was exposed to a high velocity gas jet.
#
# File Number:  413
# .\Text_Targets\MBWM0-SI1304.npy
# Wait a little while.
#
# File Number:  414
# .\Text_Targets\MBWM0-SI1934.npy
# This is no spectator-type experience; everyone is to be a participant.
#
# File Number:  415
# .\Text_Targets\MBWM0-SI674.npy
# December and January are nice months to spend in Miami.
#
# File Number:  416
# .\Text_Targets\MBWM0-SX134.npy
# How good is your endurance?
#
# File Number:  417
# .\Text_Targets\MBWM0-SX224.npy
# If people were more generous, there would be no need for welfare.
#
# File Number:  418
# .\Text_Targets\MBWM0-SX314.npy
# Barb burned paper and leaves in a big bonfire.
#
# File Number:  419
# .\Text_Targets\MBWM0-SX404.npy
# Basketball can be an entertaining sport.
#
# File Number:  420
# .\Text_Targets\MBWM0-SX44.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  421
# .\Text_Targets\MCSH0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  422
# .\Text_Targets\MCSH0-SA2.npy
# Y'all should have let me do it.
#
# File Number:  423
# .\Text_Targets\MCSH0-SI1549.npy
# My mother never wops me.
#
# File Number:  424
# .\Text_Targets\MCSH0-SI2179.npy
# Obviously, the bridal pair has many adjustments to make to their new situation.
#
# File Number:  425
# .\Text_Targets\MCSH0-SI919.npy
# She slipped and sprained her ankle on the steep slope.
#
# File Number:  426
# .\Text_Targets\MCSH0-SX109.npy
# Aluminum silverware can often be flimsy.
#
# File Number:  427
# .\Text_Targets\MCSH0-SX19.npy
# Young children should avoid exposure to contagious diseases.
#
# File Number:  428
# .\Text_Targets\MCSH0-SX199.npy
# Weatherproof galoshes are very useful in Seattle.
#
# File Number:  429
# .\Text_Targets\MCSH0-SX289.npy
# Pam gives driving lessons on Thursdays.
#
# File Number:  430
# .\Text_Targets\MCSH0-SX379.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  431
# .\Text_Targets\MCTW0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  432
# .\Text_Targets\MCTW0-SA2.npy
# Each form represented by the dictionary is looked up in the text-form list.
#
# File Number:  433
# .\Text_Targets\MCTW0-SI1373.npy
# In a way, he couldn't blame her.
#
# File Number:  434
# .\Text_Targets\MCTW0-SI2003.npy
# Do buy all-purpose mugs or cups.
#
# File Number:  435
# .\Text_Targets\MCTW0-SI743.npy
# A muscular abdomen is good for your back.
#
# File Number:  436
# .\Text_Targets\MCTW0-SX113.npy
# The causeway ended abruptly at the shore.
#
# File Number:  437
# .\Text_Targets\MCTW0-SX203.npy
# Those musicians harmonize marvelously.
#
# File Number:  438
# .\Text_Targets\MCTW0-SX23.npy
# Please take this dirty table cloth to the cleaners for me.
#
# File Number:  439
# .\Text_Targets\MCTW0-SX293.npy
# The carpet cleaners shampooed our oriental rug.
#
# File Number:  440
# .\Text_Targets\MCTW0-SX383.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  441
# .\Text_Targets\MGJF0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  442
# .\Text_Targets\MGJF0-SA2.npy
# A warm breeze played across it, moving it like waves.
#
# File Number:  443
# .\Text_Targets\MGJF0-SI1901.npy
# Clever light songs were overly coy, tragic songs a little too melodramatic.
#
# File Number:  444
# .\Text_Targets\MGJF0-SI641.npy
# Do not draw yarn too tight.
#
# File Number:  445
# .\Text_Targets\MGJF0-SI776.npy
# Kindergarten children decorate their classrooms for all holidays.
#
# File Number:  446
# .\Text_Targets\MGJF0-SX101.npy
# He will allow a rare lie.
#
# File Number:  447
# .\Text_Targets\MGJF0-SX11.npy
# Withdraw all phony accusations at once.
#
# File Number:  448
# .\Text_Targets\MGJF0-SX191.npy
# Cory and Trish played tag with beach balls for hours.
#
# File Number:  449
# .\Text_Targets\MGJF0-SX281.npy
# Right now may not be the best time for business mergers.
#
# File Number:  450
# .\Text_Targets\MGJF0-SX371.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  451
# .\Text_Targets\MGLB0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  452
# .\Text_Targets\MGLB0-SA2.npy
# Is it because of my slovenliness that hair grows on my face?
#
# File Number:  453
# .\Text_Targets\MGLB0-SI1534.npy
# Take care of yourself then.
#
# File Number:  454
# .\Text_Targets\MGLB0-SI2164.npy
# He peered ahead and grinned as the railroad tracks came into view again below.
#
# File Number:  455
# .\Text_Targets\MGLB0-SI904.npy
# The cat's meow always hurts my ears.
#
# File Number:  456
# .\Text_Targets\MGLB0-SX184.npy
# Cliff was soothed by the luxurious massage.
#
# File Number:  457
# .\Text_Targets\MGLB0-SX274.npy
# Each untimely income loss coincided with the breakdown of a heating system part.
#
# File Number:  458
# .\Text_Targets\MGLB0-SX364.npy
# Jane may earn more money by working hard.
#
# File Number:  459
# .\Text_Targets\MGLB0-SX4.npy
# Youngsters love common candy as treats.
#
# File Number:  460
# .\Text_Targets\MGLB0-SX94.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  461
# .\Text_Targets\MHPG0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  462
# .\Text_Targets\MHPG0-SA2.npy
# But a somewhat more detailed analysis of this process may be illuminating.
#
# File Number:  463
# .\Text_Targets\MHPG0-SI1090.npy
# They took it away, overalls or something.
#
# File Number:  464
# .\Text_Targets\MHPG0-SI1720.npy
# Nothing has been done yet to take advantage of the enabling legislation.
#
# File Number:  465
# .\Text_Targets\MHPG0-SI460.npy
# Are your grades higher or lower than Nancy's?
#
# File Number:  466
# .\Text_Targets\MHPG0-SX10.npy
# Project development was proceeding too slowly.
#
# File Number:  467
# .\Text_Targets\MHPG0-SX100.npy
# Serve the coleslaw after I add the oil.
#
# File Number:  468
# .\Text_Targets\MHPG0-SX190.npy
# The oasis was a mirage.
#
# File Number:  469
# .\Text_Targets\MHPG0-SX280.npy
# That noise problem grows more annoying each day.
#
# File Number:  470
# .\Text_Targets\MHPG0-SX370.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  471
# .\Text_Targets\MJBR0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  472
# .\Text_Targets\MJBR0-SA2.npy
# Oh, he'll be a plumber, came the answer.
#
# File Number:  473
# .\Text_Targets\MJBR0-SI1001.npy
# Her legs hung down long and thin as she sat on the high stool.
#
# File Number:  474
# .\Text_Targets\MJBR0-SI1631.npy
# We're here to transact business.
#
# File Number:  475
# .\Text_Targets\MJBR0-SI2261.npy
# Kindergarten children decorate their classrooms for all holidays.
#
# File Number:  476
# .\Text_Targets\MJBR0-SX101.npy
# He will allow a rare lie.
#
# File Number:  477
# .\Text_Targets\MJBR0-SX11.npy
# Withdraw all phony accusations at once.
#
# File Number:  478
# .\Text_Targets\MJBR0-SX191.npy
# Cory and Trish played tag with beach balls for hours.
#
# File Number:  479
# .\Text_Targets\MJBR0-SX281.npy
# Right now may not be the best time for business mergers.
#
# File Number:  480
# .\Text_Targets\MJBR0-SX371.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  481
# .\Text_Targets\MJES0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  482
# .\Text_Targets\MJES0-SA2.npy
# There need be no squeamishness about admitting this.
#
# File Number:  483
# .\Text_Targets\MJES0-SI1384.npy
# Sulphur, oil, and copra make the kind of tinder any firebug dreams of.
#
# File Number:  484
# .\Text_Targets\MJES0-SI2014.npy
# Instructions for preparing clay, drying, glazing and firing are not given.
#
# File Number:  485
# .\Text_Targets\MJES0-SI754.npy
# Objects made of pewter are beautiful.
#
# File Number:  486
# .\Text_Targets\MJES0-SX124.npy
# The morning dew on the spider web glistened in the sun.
#
# ...
# She had your dark suit in greasy wash water all year.
#
# File Number:  6141
# .\Text_Targets\FNKL0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6142
# .\Text_Targets\FNKL0-SA2.npy
# Why couldn't they have dumped him off on someone else?
#
# File Number:  6143
# .\Text_Targets\FNKL0-SI1522.npy
# His fingers fumbled across the bandages.
#
# File Number:  6144
# .\Text_Targets\FNKL0-SI2152.npy
# No chemical fertilizers and poisonous insecticides and fungicides are used.
#
# File Number:  6145
# .\Text_Targets\FNKL0-SI892.npy
# The triumphant warrior exhibited naive heroism.
#
# File Number:  6146
# .\Text_Targets\FNKL0-SX172.npy
# How do oysters make pearls?
#
# File Number:  6147
# .\Text_Targets\FNKL0-SX196.npy
# Can the agency overthrow alien forces?
#
# File Number:  6148
# .\Text_Targets\FNKL0-SX262.npy
# Suburban housewives often suffer from the gab habit.
#
# File Number:  6149
# .\Text_Targets\FNKL0-SX442.npy
# Good service should be rewarded by big tips.
#
# File Number:  6150
# .\Text_Targets\FNKL0-SX82.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6151
# .\Text_Targets\FPLS0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6152
# .\Text_Targets\FPLS0-SA2.npy
# With his club foot he might well be grateful.
#
# File Number:  6153
# .\Text_Targets\FPLS0-SI1590.npy
# The red pills are a vitamin-and-iron compound.
#
# File Number:  6154
# .\Text_Targets\FPLS0-SI2220.npy
# No group of officers came in for more spirited denunciation than the doctors.
#
# File Number:  6155
# .\Text_Targets\FPLS0-SI960.npy
# Vietnamese cuisine is exquisite.
#
# File Number:  6156
# .\Text_Targets\FPLS0-SX150.npy
# It's not easy to create illuminating examples.
#
# File Number:  6157
# .\Text_Targets\FPLS0-SX240.npy
# This was easy for us.
#
# File Number:  6158
# .\Text_Targets\FPLS0-SX3.npy
# Count the number of teaspoons of soysauce that you add.
#
# File Number:  6159
# .\Text_Targets\FPLS0-SX330.npy
# The legislature met to judge the state of public education.
#
# File Number:  6160
# .\Text_Targets\FPLS0-SX60.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6161
# .\Text_Targets\MBCG0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6162
# .\Text_Targets\MBCG0-SA2.npy
# He'd not only told me so, he'd proved it.
#
# File Number:  6163
# .\Text_Targets\MBCG0-SI2217.npy
# It was time to go up myself.
#
# File Number:  6164
# .\Text_Targets\MBCG0-SI486.npy
# But he was very much like his associates in his hatred of camp routine.
#
# File Number:  6165
# .\Text_Targets\MBCG0-SI957.npy
# Correct execution of my instructions is crucial.
#
# File Number:  6166
# .\Text_Targets\MBCG0-SX147.npy
# The courier was a dwarf.
#
# File Number:  6167
# .\Text_Targets\MBCG0-SX237.npy
# Al received a joint appointment in the biology and the engineering departments.
#
# File Number:  6168
# .\Text_Targets\MBCG0-SX327.npy
# Valley Lodge yearly celebrates the first calf born.
#
# File Number:  6169
# .\Text_Targets\MBCG0-SX417.npy
# The prowler wore a ski mask for disguise.
#
# File Number:  6170
# .\Text_Targets\MBCG0-SX57.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6171
# .\Text_Targets\MBSB0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6172
# .\Text_Targets\MBSB0-SA2.npy
# These needs usually concern the reduction of guilt and some relief of tension.
#
# File Number:  6173
# .\Text_Targets\MBSB0-SI1353.npy
# Brakes shrieked behind us.
#
# File Number:  6174
# .\Text_Targets\MBSB0-SI1983.npy
# The total of these three volumes is the final combustion chamber volume.
#
# File Number:  6175
# .\Text_Targets\MBSB0-SI723.npy
# Why else would Danny allow others to go?
#
# File Number:  6176
# .\Text_Targets\MBSB0-SX183.npy
# The angry boy answered but didn't look up.
#
# File Number:  6177
# .\Text_Targets\MBSB0-SX273.npy
# This was easy for us.
#
# File Number:  6178
# .\Text_Targets\MBSB0-SX3.npy
# The cow wandered from the farmland and became lost.
#
# File Number:  6179
# .\Text_Targets\MBSB0-SX363.npy
# Cut a small corner off each edge.
#
# File Number:  6180
# .\Text_Targets\MBSB0-SX93.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6181
# .\Text_Targets\MCXM0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6182
# .\Text_Targets\MCXM0-SA2.npy
# Religion fosters group life in various ways.
#
# File Number:  6183
# .\Text_Targets\MCXM0-SI1351.npy
# On unoccupied roadway the bottle shattered into a small amber flash.
#
# File Number:  6184
# .\Text_Targets\MCXM0-SI1981.npy
# This tool can also be made with a lathe.
#
# File Number:  6185
# .\Text_Targets\MCXM0-SI721.npy
# Rich looked for spotted hyenas and jaguars on the safari.
#
# File Number:  6186
# .\Text_Targets\MCXM0-SX181.npy
# Be careful not to plow over the flower beds.
#
# File Number:  6187
# .\Text_Targets\MCXM0-SX271.npy
# The speech symposium might begin Monday.
#
# File Number:  6188
# .\Text_Targets\MCXM0-SX361.npy
# The thick elm forest was nearly overwhelmed by Dutch Elm Disease.
#
# File Number:  6189
# .\Text_Targets\MCXM0-SX451.npy
# The misprint provoked an immediate disclaimer.
#
# File Number:  6190
# .\Text_Targets\MCXM0-SX91.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6191
# .\Text_Targets\MEJS0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6192
# .\Text_Targets\MEJS0-SA2.npy
# He is forced to play for little money, and must often take another job to live.
#
# File Number:  6193
# .\Text_Targets\MEJS0-SI1240.npy
# A bayonet hung in a belt scabbard.
#
# File Number:  6194
# .\Text_Targets\MEJS0-SI1870.npy
# But the attack was made from an advance copy.
#
# File Number:  6195
# .\Text_Targets\MEJS0-SI610.npy
# As coauthors, we presented our new book to the haughty audience.
#
# File Number:  6196
# .\Text_Targets\MEJS0-SX160.npy
# The Boston Ballet overcame their funding shortage.
#
# File Number:  6197
# .\Text_Targets\MEJS0-SX250.npy
# Ducks have webbed feet and colorful feathers.
#
# File Number:  6198
# .\Text_Targets\MEJS0-SX340.npy
# Those who are not purists use canned vegetables when making stew.
#
# File Number:  6199
# .\Text_Targets\MEJS0-SX430.npy
# Did you eat yet?
#
# File Number:  6200
# .\Text_Targets\MEJS0-SX70.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6201
# .\Text_Targets\MKDD0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6202
# .\Text_Targets\MKDD0-SA2.npy
# He drove sensual patterns off, carefully shaving his long upper lip.
#
# File Number:  6203
# .\Text_Targets\MKDD0-SI1567.npy
# The ward was a small one, four beds, kept reserved for female alcoholics.
#
# File Number:  6204
# .\Text_Targets\MKDD0-SI2197.npy
# Let the orthodontist decide the proper time to start treatment, he urges.
#
# File Number:  6205
# .\Text_Targets\MKDD0-SI937.npy
# The emperor had a mean temper.
#
# File Number:  6206
# .\Text_Targets\MKDD0-SX127.npy
# How permanent are their records?
#
# File Number:  6207
# .\Text_Targets\MKDD0-SX217.npy
# The meeting is now adjourned.
#
# File Number:  6208
# .\Text_Targets\MKDD0-SX307.npy
# Critical equipment needs proper maintenance.
#
# File Number:  6209
# .\Text_Targets\MKDD0-SX37.npy
# Tim takes Sheila to see movies twice a week.
#
# File Number:  6210
# .\Text_Targets\MKDD0-SX397.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6211
# .\Text_Targets\MKRG0-SA1.npy
# Don't ask me to carry an oily rag like that.
# File Number:  6212
# .\Text_Targets\MKRG0-SA2.npy
# He merely said, any good decorator these days can make you a tasteful home.
#
# File Number:  6213
# .\Text_Targets\MKRG0-SI1491.npy
# Another field had given him fame enough to satisfy any egotist.
#
# File Number:  6214
# .\Text_Targets\MKRG0-SI2121.npy
# Latest models serve hot meals at reasonable prices, and at a profit to you.
#
# File Number:  6215
# .\Text_Targets\MKRG0-SI861.npy
# Pledge to participate in Nevada's aquatic competition.
#
# File Number:  6216
# .\Text_Targets\MKRG0-SX141.npy
# I honor my mom.
#
# File Number:  6217
# .\Text_Targets\MKRG0-SX231.npy
# A good attitude is unbeatable.
#
# File Number:  6218
# .\Text_Targets\MKRG0-SX31.npy
# Butterscotch fudge goes well with vanilla ice cream.
#
# File Number:  6219
# .\Text_Targets\MKRG0-SX411.npy
# Ambidextrous pickpockets accomplish more.
#
# File Number:  6220
# .\Text_Targets\MKRG0-SX51.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6221
# .\Text_Targets\MMEA0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6222
# .\Text_Targets\MMEA0-SA2.npy
# Such legislation was clarified and extended from time to time thereafter.
#
# File Number:  6223
# .\Text_Targets\MMEA0-SI1388.npy
# They were shattered.
#
# File Number:  6224
# .\Text_Targets\MMEA0-SI2018.npy
# When mold has more than one design cavity, make individual paper patterns.
#
# File Number:  6225
# .\Text_Targets\MMEA0-SI758.npy
# Lots of foreign movies have subtitles.
#
# File Number:  6226
# .\Text_Targets\MMEA0-SX128.npy
# Try to recall the events in chronological order.
#
# File Number:  6227
# .\Text_Targets\MMEA0-SX218.npy
# Shipbuilding is a most fascinating process.
#
# File Number:  6228
# .\Text_Targets\MMEA0-SX308.npy
# Young people participate in athletic activities.
#
# File Number:  6229
# .\Text_Targets\MMEA0-SX38.npy
# Children can consume many fruit candies in one sitting.
#
# File Number:  6230
# .\Text_Targets\MMEA0-SX398.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6231
# .\Text_Targets\MMLM0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6232
# .\Text_Targets\MMLM0-SA2.npy
# They'll toe the line.
#
# File Number:  6233
# .\Text_Targets\MMLM0-SI1527.npy
# Then he fled, not waiting to see if she minded him or took notice of his cry.
#
# File Number:  6234
# .\Text_Targets\MMLM0-SI2150.npy
# They serve cracked wheat, oats or cornmeal.
#
# File Number:  6235
# .\Text_Targets\MMLM0-SI897.npy
# Does creole cooking use curry?
#
# File Number:  6236
# .\Text_Targets\MMLM0-SX177.npy
# Draw every outer line first, then fill in the interior.
#
# File Number:  6237
# .\Text_Targets\MMLM0-SX267.npy
# The moisture in my eyes is from eyedrops, not from tears.
#
# File Number:  6238
# .\Text_Targets\MMLM0-SX357.npy
# First add milk to the shredded cheese.
#
# File Number:  6239
# .\Text_Targets\MMLM0-SX447.npy
# Primitive tribes have an upbeat attitude.
#
# File Number:  6240
# .\Text_Targets\MMLM0-SX87.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6241
# .\Text_Targets\MMPM0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6242
# .\Text_Targets\MMPM0-SA2.npy
# But what if somebody decides to break it?
#
# File Number:  6243
# .\Text_Targets\MMPM0-SI1061.npy
# No, they could kill him just as easy right now.
#
# File Number:  6244
# .\Text_Targets\MMPM0-SI1691.npy
# She didn't donate anything of yours, did she?
#
# File Number:  6245
# .\Text_Targets\MMPM0-SI2321.npy
# As a precaution, the outlaws bought gunpowder for their stronghold.
#
# File Number:  6246
# .\Text_Targets\MMPM0-SX161.npy
# We apply auditory modeling to computer speech recognition.
#
# File Number:  6247
# .\Text_Targets\MMPM0-SX251.npy
# The high security prison was surrounded by barbed wire.
#
# File Number:  6248
# .\Text_Targets\MMPM0-SX341.npy
# The fifth jar contains big, juicy peaches.
#
# File Number:  6249
# .\Text_Targets\MMPM0-SX431.npy
# Porcupines resemble sea urchins.
#
# File Number:  6250
# .\Text_Targets\MMPM0-SX71.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6251
# .\Text_Targets\MMWS0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6252
# .\Text_Targets\MMWS0-SA2.npy
# His arm moved swiftly, violently, once, twice.
#
# File Number:  6253
# .\Text_Targets\MMWS0-SI1518.npy
# They seem darned proud of it.
#
# File Number:  6254
# .\Text_Targets\MMWS0-SI559.npy
# Is a dream simply a mental or cerebral movie?
#
# File Number:  6255
# .\Text_Targets\MMWS0-SI888.npy
# Who took the kayak down the bayou?
#
# File Number:  6256
# .\Text_Targets\MMWS0-SX168.npy
# The essay undeniably reflects our view ably.
#
# File Number:  6257
# .\Text_Targets\MMWS0-SX258.npy
# I'll have a scoop of that exotic purple and turquoise sherbet.
#
# File Number:  6258
# .\Text_Targets\MMWS0-SX348.npy
# Shell shock caused by shrapnel is sometimes cured through group therapy.
#
# File Number:  6259
# .\Text_Targets\MMWS0-SX438.npy
# Doctors prescribe drugs too freely.
#
# File Number:  6260
# .\Text_Targets\MMWS0-SX78.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6261
# .\Text_Targets\MRDM0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6262
# .\Text_Targets\MRDM0-SA2.npy
# Residential associations struggle to insulate themselves against intrusions.
#
# File Number:  6263
# .\Text_Targets\MRDM0-SI1044.npy
# A crude ladder ran down to a wooden floor.
#
# File Number:  6264
# .\Text_Targets\MRDM0-SI1595.npy
# A tsunami is not a single wave but a series.
#
# File Number:  6265
# .\Text_Targets\MRDM0-SI965.npy
# The water contained too much chlorine and stung his eyes.
#
# File Number:  6266
# .\Text_Targets\MRDM0-SX155.npy
# Does Hindu ideology honor cows?
#
# File Number:  6267
# .\Text_Targets\MRDM0-SX245.npy
# Gus saw pine trees and redwoods on his walk through Sequoia National Forest.
#
# File Number:  6268
# .\Text_Targets\MRDM0-SX335.npy
# Movies never have enough villains.
#
# File Number:  6269
# .\Text_Targets\MRDM0-SX425.npy
# Challenge each general's intelligence.
#
# File Number:  6270
# .\Text_Targets\MRDM0-SX65.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6271
# .\Text_Targets\MRLK0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6272
# .\Text_Targets\MRLK0-SA2.npy
# A precision transit is set up so that it is lined with respect to true north.
#
# File Number:  6273
# .\Text_Targets\MRLK0-SI1468.npy
# Was it a hysterical release from the long strain of vigilance of those weeks?
#
# File Number:  6274
# .\Text_Targets\MRLK0-SI2140.npy
# To begin with, what is an interior designer?
#
# File Number:  6275
# .\Text_Targets\MRLK0-SI843.npy
# A screwdriver is made from vodka and orange juice.
#
# File Number:  6276
# .\Text_Targets\MRLK0-SX123.npy
# The news agency hired a great journalist.
#
# File Number:  6277
# .\Text_Targets\MRLK0-SX213.npy
# The bluejay flew over the high building.
#
# File Number:  6278
# .\Text_Targets\MRLK0-SX303.npy
# Coconut cream pie makes a nice dessert.
#
# File Number:  6279
# .\Text_Targets\MRLK0-SX33.npy
# She uses both names interchangeably.
#
# File Number:  6280
# .\Text_Targets\MRLK0-SX393.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6281
# .\Text_Targets\MRRE0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6282
# .\Text_Targets\MRRE0-SA2.npy
# Microscopically, there was emphysema, fibrosis, and vascular congestion.
#
# File Number:  6283
# .\Text_Targets\MRRE0-SI1334.npy
# Oh, you'll wobble and weave quite a bit at first.
#
# File Number:  6284
# .\Text_Targets\MRRE0-SI704.npy
# That experience holds a lesson for us all in regard to birth control today.
#
# File Number:  6285
# .\Text_Targets\MRRE0-SI952.npy
# Curiosity and mediocrity seldom coexist.
#
# File Number:  6286
# .\Text_Targets\MRRE0-SX164.npy
# Do they allow atheists in church?
#
# File Number:  6287
# .\Text_Targets\MRRE0-SX254.npy
# I know I didn't meet her early enough.
#
# File Number:  6288
# .\Text_Targets\MRRE0-SX344.npy
# Each stag surely finds a big fawn.
#
# File Number:  6289
# .\Text_Targets\MRRE0-SX434.npy
# An official deadline cannot be postponed.
#
# File Number:  6290
# .\Text_Targets\MRRE0-SX74.npy
# She had your dark suit in greasy wash water all year.
#
# File Number:  6291
# .\Text_Targets\MTCS0-SA1.npy
# Don't ask me to carry an oily rag like that.
#
# File Number:  6292
# .\Text_Targets\MTCS0-SA2.npy
# Perfect, he thought.
#
# File Number:  6293
# .\Text_Targets\MTCS0-SI1972.npy
# That worm a murderer?
#
# File Number:  6294
# .\Text_Targets\MTCS0-SI2265.npy
# Our first necessity, at the very outset of war, is post-attack reconnaissance.
#
# File Number:  6295
# .\Text_Targets\MTCS0-SI712.npy
# The triumphant warrior exhibited naive heroism.
#
# File Number:  6296
# .\Text_Targets\MTCS0-SX172.npy
# Can the agency overthrow alien forces?
#
# File Number:  6297
# .\Text_Targets\MTCS0-SX262.npy
# According to my interpretation of the problem, two lines must be perpendicular.
#
# File Number:  6298
# .\Text_Targets\MTCS0-SX352.npy
# Suburban housewives often suffer from the gab habit.
#
# File Number:  6299
# .\Text_Targets\MTCS0-SX442.npy
# Good service should be rewarded by big tips.
#
# File Number:  6300
# .\Text_Targets\MTCS0-SX82.npy

# %%
import io
import collections
import tensorflow as tf
import time
import numpy as np
import os
import shutil
from numpy import matrix
from tensorflow.python.ops import ctc_ops as ctc

def read_data():
    text_files = [os.path.join(root, name) for root, dirs, files in os.walk('Text_Targets') for name in files
                 if name.endswith((".npy"))]
    full_text=""
    for file in text_files:
        count=0
        text_No_Suffix=os.path.splitext(file)[0]
        text_File_Name=text_No_Suffix.split('\\')[-1]
        content=str(np.load(".\\Text_Targets\\"+text_File_Name+'.npy'))
        content = io.StringIO(content).readlines()
        content = ((content[0].replace("\n","")).replace(".","")).replace("?", "")
        full_text+=(' '+content)
    full_text = full_text.split()
    full_text = np.array(full_text)
    full_text = np.reshape(full_text,[-1,])
    return full_text

def build_dataset(words):
    count = collections.Counter(words).most_common()  #Returns a dictionary with count of each word arranged in descending order of count
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary) #Basically assigns a number to each word 
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return dictionary, reverse_dictionary

data=read_data()
dictionary,reverse_dictionary=build_dataset(data)

n_classes=7029

#Hyperparameters
num_layers=1
n_hidden=100
batch_size=1
n_epochs=1000

#Target log path
logs_path = '/tmp/tensorflow/timit_speech_recognition'

def variable_summaries(var):
    """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
    with tf.name_scope('summaries'):
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        with tf.name_scope('stddev'):
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
        tf.summary.scalar('stddev', stddev)
        tf.summary.scalar('max', tf.reduce_max(var))
        tf.summary.scalar('min', tf.reduce_min(var))
        tf.summary.histogram('histogram', var)

def sparse_tuple_from(sequences, dtype=np.int32):
    """Create a sparse representention of x.
    Args:
        sequences: a list of lists of type dtype where each element is a sequence
    Returns:
        A tuple with (indices, values, shape)
    """
    indices = []
    values = []

    for n, seq in enumerate(sequences):
        indices.extend(zip([n] * len(matrix(seq)), range(len(matrix(seq)))))
        values.extend([seq])

    indices = np.asarray(indices, dtype=np.int32)
    indices[:,[0, 1]] = indices[:,[1, 0]]
    values = np.asarray(values, dtype=dtype)
    shape = np.asarray([len(sequences), np.asarray(indices).max(0)[1] + 1], dtype=np.int32)

    return indices, values, shape


inputs = tf.placeholder(tf.float32,[None,None,1])
target_idx = tf.placeholder(tf.int64)
target_vals = tf.placeholder(tf.int32)
target_shape = tf.placeholder(tf.int64)
targets = tf.SparseTensor(target_idx, target_vals, target_shape)
seq_len = tf.placeholder(tf.int32)

# RNN output node weights and biases
weights = {
        'out': tf.Variable(tf.random_normal([n_hidden,n_classes]),dtype=tf.float32) # Weights_shape = hidden_units X vocab_size
    }
biases = {
        'out': tf.Variable(tf.random_normal([n_classes]),tf.float32)
        }
        
def LSTM_cell():
    cell = tf.contrib.rnn.BasicLSTMCell(n_hidden, reuse=tf.get_variable_scope().reuse)
    return tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=0.4)

def RNN_Model(inputs,seq_len,weights,biases):
    rnn_cell=LSTM_cell()
    #rnn_cell = tf.contrib.rnn.MultiRNNCell(LSTM_cell() for i in range(num_layers))
    outputs,_ = tf.nn.dynamic_rnn(rnn_cell,inputs,seq_len,dtype=tf.float32)
        
    outputs = tf.reshape(outputs,[-1,n_hidden])
    #print(outputs)
    logits = tf.matmul(outputs,weights['out']) + biases['out']
        
    with tf.name_scope('Weights'):
        variable_summaries(weights['out'])
    
    with tf.name_scope('Biases'):
        variable_summaries(biases['out'])
    
    with tf.name_scope('Activations'):
        tf.summary.histogram('Activations',logits)
        
    logits = tf.reshape(logits,[batch_size,-1,n_classes])
    logits = tf.transpose(logits,(1,0,2))
    return logits

logits=RNN_Model(inputs,seq_len,weights,biases)
loss = ctc.ctc_loss(targets,logits,seq_len)
with tf.name_scope("CTC_Loss"):
    cost = tf.reduce_mean(loss)
    tf.summary.scalar('CTC_Loss',cost)
        
optimizer = tf.train.MomentumOptimizer(learning_rate=0.005, momentum=0.9).minimize(cost)
decoded, log_prob = ctc.ctc_greedy_decoder(logits, seq_len)
        
label_error_rate = tf.reduce_mean(tf.edit_distance(tf.cast(decoded[0], tf.int32),
                                              targets)) 
#computes the Levenshtein distance between sequences.
#This operation takes variable-length sequences (hypothesis and truth), each provided as a SparseTensor, and computes the Levenshtein distance.
# You can normalize the edit distance by length of truth by setting normalize to true.

def convert_to_sequence(values):
    result=""
    for value in values:
        result+=' '+reverse_dictionary[value]
    return result
        

merged = tf.summary.merge_all()
writer = tf.summary.FileWriter(logs_path)
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
saver = tf.train.Saver(tf.global_variables())
init=tf.global_variables_initializer()

def train():
    with tf.Session(config=config) as sess:
            sess.run(init)
            writer.add_graph(sess.graph)
            
            phoneme_labels = [os.path.join(root, name) for root, dirs, files in os.walk('phonemeLabels') for name in files
             if name.endswith((".npy"))]
            text_targets=[os.path.join(root, name) for root, dirs, files in os.walk('Text_Targets') for name in files
             if name.endswith((".npy"))]
            for curr_epoch in range(n_epochs):
                train_cost=train_ler=0
                count_files=0
                for label in phoneme_labels:
                    count=0
                    phoneme_No_Suffix=os.path.splitext(label)[0]
                    phoneme_File_Name=phoneme_No_Suffix.split('\\')[-1]
                    for text in text_targets:
                        text_No_Suffix=os.path.splitext(text)[0]
                        text_File_Name=text_No_Suffix.split('\\')[-1]
                        if(phoneme_File_Name==text_File_Name):
                            count+=1
                            train_inputs=np.load(".\\phonemeLabels\\"+phoneme_File_Name+'.npy')
                            train_inputs = np.reshape(train_inputs,[1,-1,1])
                            #print(np.shape(train_inputs))
                            train_seq_len = [train_inputs.shape[1]]
                            #print(train_seq_len)
                            
                            content=str(np.load(".\\Text_Targets\\"+text_File_Name+'.npy'))
                            content = io.StringIO(content).readlines()
                            content = ((content[0].replace("\n","")).replace(".","")).replace("?", "")
                            content = content.split()
                            train_targets=[]
                            for word in content:
                                train_targets.append(dictionary[word])
                            train_targets=np.array(train_targets)
                            
                            target_index,target_values,target_shapes = sparse_tuple_from(train_targets)
                            feed = {inputs: train_inputs,target_idx:target_index,target_vals:target_values,target_shape:target_shapes,seq_len: train_seq_len}
                            summary,batch_cost, _ = sess.run([merged, cost, optimizer], feed)
                            writer.add_summary(summary, count_files)
                            
                            train_cost += batch_cost * batch_size
                            print('Truth:\n' + convert_to_sequence(train_targets))
                            print('Output:\n' + convert_to_sequence(sess.run(decoded[0].values,feed_dict=feed)))
                            #print("Decoded Values: " ,sess.run(decoded[0].values,feed_dict=feed))
                            train_ler += sess.run(label_error_rate, feed_dict=feed) * batch_size
                            count_files+=1
                            print("Batch Cost {0} after {1} file \n".format(batch_cost,count_files))
                            if(count_files==6300):
                                train_cost=(train_cost/6300)
                                tf.summary.scalar('Train_Cost',cost)
                                writer.add_summary(summary, curr_epoch)
                            
                            
                        if(count>=1):
                            break
                
                print(" Train Cost: {0} in Epoch {1} ".format((train_cost),curr_epoch))
                saver.save(sess,"./saver/model.ckpt")
                print("Model saved ")

# %%
train()
# Out:
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  chemical greasy sailed desperately expensive fallen yarn chiefly expensive synonymous reflexes instability ham: desirable greasy curry gassing sailed elements raindrops, week Pretend lewd, Somehow pilots grill, controls massage controls kidnappers parted, seen export humor expensive amateur birthday misbehavior Next canteen expensive abruptly reflexes greasy
# Batch Cost 778.933837890625 after 1 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  human pursued chemical above Bring This Bring necessary, conscience fill fact pneumonia dancers team seen vacuum tides scored another Them instrument enormous raindrops, pilots
# Batch Cost 528.8457641601562 after 2 file
#
# Truth:
#  Bricks are an alternative
# Output:
#  Perhaps forged pilots lip
# Batch Cost 121.40457153320312 after 3 file
#
# Truth:
#  Fat showed in loose rolls beneath the shirt
# Output:
#  forged spaced throughout lip
# Batch Cost 187.8228302001953 after 4 file
#
# Truth:
#  It suffers from a lack of unity of purpose and respect for heroic leadership
# Output:
#  common persons common smile lip tenant's sunburn districts
# Batch Cost 285.9698486328125 after 5 file
#
# Truth:
#  She slipped and sprained her ankle on the steep slope
# Output:
#  likely Bring Suburban pathetic
# Batch Cost 289.9531555175781 after 6 file
#
# Truth:
#  Aluminum silverware can often be flimsy
# Output:
#  worship pursued Somehow valiant,
# Batch Cost 102.94400024414062 after 7 file
#
# Truth:
#  Young children should avoid exposure to contagious diseases
# Output:
#  lip taxation mergers persons, Bring
# Batch Cost 168.06869506835938 after 8 file
#
# Truth:
#  Weatherproof galoshes are very useful in Seattle
# Output:
#  rifle, Fuming, times non-contributory kids Fuming,
# Batch Cost 109.78617858886719 after 9 file
#
# Truth:
#  Pam gives driving lessons on Thursdays
# Output:
#  capillary dark,
# Batch Cost 103.18596649169922 after 10 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  "Steam accuse loaded phrase, Such dark, switched
# Batch Cost 243.66627502441406 after 11 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  frantically mergers Bring flopped
# Batch Cost 219.74754333496094 after 12 file
#
# Truth:
#  Assume, for example, a situation where a farm has a packing shed and fields
# Output:
#  above story Bring quarters enter caraway diversity regenerating were, badness chemical waste sank visiting
# Batch Cost 263.6927185058594 after 13 file
#
# Truth:
#  What outfit does she drive for
# Output:
#  feather story another
# Batch Cost 115.14205932617188 after 14 file
#
# Truth:
#  Fill small hole in bowl with clay
# Output:
#  kids chemical soothed validated hung
# Batch Cost 126.17610931396484 after 15 file
#
# Truth:
#  Publicity and notoriety go hand in hand
# Output:
#  hides earthly obtained around Bake Technical fan Bring feather sunburn
# Batch Cost 159.19869995117188 after 16 file
#
# Truth:
#  You always come up with pathological examples
# Output:
#  twigged diploma obtained grownups notes flopped grownups Bring lived pathetic sunburn likely Pretend flopped repainted
# Batch Cost 137.88844299316406 after 17 file
#
# Truth:
#  Those answers will be straightforward if you think them through carefully first
# Output:
#  memorized accusations regard taxation sample can notes twigged common visiting
# Batch Cost 219.04489135742188 after 18 file
#
# Truth:
#  We'll serve rhubarb pie after Rachel's talk
# Output:
#  spiritual switched sunburned Pretend murderer pursued mergers seeking
# Batch Cost 123.1794204711914 after 19 file
#
# Truth:
#  Biblical scholars argue history
# Output:
#  trouble raccoons twigged unless
# Batch Cost 63.80976486206055 after 20 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  feather his under trouble lived mandates
# Batch Cost 171.77438354492188 after 21 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  drank fan flopped attention developed smooth kids above
# Batch Cost 173.3706512451172 after 22 file
#
# Truth:
#  Both have excellent integration of their fiscal tax collection year calendars
# Output:
#  hawing tenant's sketched Technical cooperates kind regenerating proud Technical officials regenerating encamped
# Batch Cost 190.9625701904297 after 23 file
#
# Truth:
#  It took him a long time to compose himself
# Output:
#  centuries flopped
# Batch Cost 163.07705688476562 after 24 file
#
# Truth:
#  He liked to nip ear lobes of unsuspecting visitors with his needle-sharp teeth
# Output:
#  consumption Bring taxation lives story story baths Fuming,
# Batch Cost 245.99693298339844 after 25 file
#
# Truth:
#  Why else would Danny allow others to go
# Output:
#  were hawing
# Batch Cost 137.25888061523438 after 26 file
#
# Truth:
#  The angry boy answered but didn't look up
# Output:
#  Bake Nor "Steam ways feather encamped
# Batch Cost 139.76922607421875 after 27 file
#
# Truth:
#  This was easy for us
# Output:
#  interpretations justification switched
# Batch Cost 81.22245788574219 after 28 file
#
# Truth:
#  The cow wandered from the farmland and became lost
# Output:
#  hook repainted considered many-bodied persons encamped
# Batch Cost 138.9703826904297 after 29 file
#
# Truth:
#  Cut a small corner off each edge
# Output:
#  times exaggerated non-contributory around added: bed
# Batch Cost 116.06989288330078 after 30 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  becomes neither smooth worth hawing chasing Merely stop swarthy crab
# Batch Cost 163.58203125 after 31 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  Further, coauthors, added: Bake bankers can attention
# Batch Cost 154.7672119140625 after 32 file
#
# Truth:
#  His captain was thin and haggard and his beautiful boots were worn and shabby
# Output:
#  feather worship able Technical eyedrops, swarthy pilots story "Steam fields nearly blistered fan
# Batch Cost 232.6566162109375 after 33 file
#
# Truth:
#  The reasons for this dive seemed foolish now
# Output:
#  deeply costs bed, radioactivity attention visiting chemical non-contributory
# Batch Cost 150.5425567626953 after 34 file
#
# Truth:
#  Production may fall far below expectations
# Output:
#  soybean, his land remember repainted unless
# Batch Cost 80.52508544921875 after 35 file
#
# Truth:
#  Pizzerias are convenient for a quick lunch
# Output:
#  frost peace hung neither
# Batch Cost 107.74468994140625 after 36 file
#
# Truth:
#  Put the butcher block table in the garage
# Output:
#  accuse regenerating chemical spaced warmongering twigged These repainted
# Batch Cost 134.439697265625 after 37 file
#
# Truth:
#  Drop five forms in the box before you go out
# Output:
#  team worth depreciation lives
# Batch Cost 172.63345336914062 after 38 file
#
# Truth:
#  Her wardrobe consists of only skirts and blouses
# Output:
#  need regenerating
# Batch Cost 112.13540649414062 after 39 file
#
# Truth:
#  Elderly people are often excluded
# Output:
#  overeating tasks non-contributory
# Batch Cost 86.42451477050781 after 40 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  neither blistered moisture fan
# Batch Cost 159.30108642578125 after 41 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  crab pathetic park
# Batch Cost 142.82994079589844 after 42 file
#
# Truth:
#  Then the choreographer must arbitrate
# Output:
#  giraffes sketched radiosterilization guys swarthy lived repainted
# Batch Cost 79.54893493652344 after 43 file
#
# Truth:
#  Two other cases also were under advisement
# Output:
#  team Or, need were revised
# Batch Cost 111.33985137939453 after 44 file
#
# Truth:
#  The straight line would symbolize its uniqueness, the circle of universality
# Output:
#  visiting his persons pursued honey, many-bodied we've lucky
# Batch Cost 167.0823516845703 after 45 file
#
# Truth:
#  Would a tomboy often play outdoors
# Output:
#  brim, interpretations nearly taxation predispositions need
# Batch Cost 85.70030212402344 after 46 file
#
# Truth:
#  John's brother repainted the garage door
# Output:
#  girlishly attention repainted met, bright
# Batch Cost 92.316162109375 after 47 file
#
# Truth:
#  Will you please confirm government policy regarding waste removal
# Output:
#  Bring repainted nearly bankers shucks, accordingly
# Batch Cost 131.5049285888672 after 48 file
#
# Truth:
#  Bright sunshine shimmers on the ocean
# Output:
#  wedding pale
# Batch Cost 124.06568908691406 after 49 file
# Truth:
#  Masquerade parties tax one's imagination
# Output:
#  were meaning visiting markets worth drunk; accusations considered
# Batch Cost 77.22614288330078 after 50 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  capillary giraffes brim, thou dream frantically
# Batch Cost 120.85691833496094 after 51 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  drunk; curiosity pursued
# Batch Cost 119.22396850585938 after 52 file
#
# Truth:
#  Quite often, honeybees form a majority on the willow catkins
# Output:
#  in bullet changing; crawling were crab
# Batch Cost 152.90625 after 53 file
#
# Truth:
#  Like enough we'll all be up on top by sundown
# Output:
#  drawled attention inhuman attention
# Batch Cost 149.40615844726562 after 54 file
#
# Truth:
#  The new birth is immediate and instantaneous
# Output:
#
# Batch Cost 98.38925170898438 after 55 file
#
# Truth:
#  The water contained too much chlorine and stung his eyes
# Output:
#  eyedrops, arms kids we've able
# Batch Cost 160.5967254638672 after 56 file
#
# Truth:
#  Does Hindu ideology honor cows
# Output:
#  Fuming, added: brim,
# Batch Cost 70.85294342041016 after 57 file
#
# Truth:
#  Gus saw pine trees and redwoods on his walk through Sequoia National Forest
# Output:
#  antiseptic example, ways were worship padlock realizing mergers
# Batch Cost 234.67892456054688 after 58 file
#
# Truth:
#  Movies never have enough villains
# Output:
#  bullets guys worth nearly were
# Batch Cost 66.6015396118164 after 59 file
#
# Truth:
#  Challenge each general's intelligence
# Output:
#  There, repainted girlishly radiosterilization
# Batch Cost 58.66044235229492 after 60 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  seam daytime lives forced sank These interpretations encamped hawing tell destroy Suburban drunk;
# Batch Cost 144.08169555664062 after 61 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  lacerate us, beside waste considered your shut blistered complicity districts non-contributory accordingly girlishly
# Batch Cost 122.72792053222656 after 62 file
#
# Truth:
#  No question ruffles him or causes him to hesitate
# Output:
#  to Carol primary doctor tell interpretations surveying daydreamed horseplay ephemeral likely
# Batch Cost 137.5260009765625 after 63 file
#
# Truth:
#  It was awkward: very awkward
# Output:
#  apples pursued lucky elevator knit Or,
# Batch Cost 95.13755798339844 after 64 file
#
# Truth:
#  When we left Washington his son Tad was ill and Mrs Lincoln hysterical
# Output:
#  petty Well, interpretations were lip orthodontic his sleigh interpretations love drank
# Batch Cost 193.4536895751953 after 65 file
#
# Truth:
#  They remained lifelong friends and companions
# Output:
#  holds: worship honey, curiosity progress, correct
# Batch Cost 94.36234283447266 after 66 file
#
# Truth:
#  By eating yogurt, you may live longer
# Output:
#  loaded
# Batch Cost 112.66244506835938 after 67 file
#
# Truth:
#  The frightened child was gently subdued by his big brother
# Output:
#  interpretations progress, crab tray encamped
# Batch Cost 143.2483367919922 after 68 file
#
# Truth:
#  The overweight charmer could slip poison into anyone's tea
# Output:
#  dark revealing excellent likely Suburban
# Batch Cost 116.82955169677734 after 69 file
#
# Truth:
#  Cliff's display was misplaced on the screen
# Output:
#  atypical survive inhuman
# Batch Cost 97.45758056640625 after 70 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  girlishly theme shut kidnappers
# Batch Cost 120.45114135742188 after 71 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  nearly infiltration non-contributory
# Batch Cost 129.2750701904297 after 72 file
#
# Truth:
#  Maybe today'll be a good-news day
# Output:
#  tell
# Batch Cost 85.30107116699219 after 73 file
#
# Truth:
#  She spouted a mouthful of water into the air
# Output:
#  have touch
# Batch Cost 119.51691436767578 after 74 file
#
# Truth:
#  Too many new things are happening for it to be a complete erotic fulfillment
# Output:
#  skating his radioactivity blistered club interpretations him!
# Batch Cost 215.34556579589844 after 75 file
#
# Truth:
#  The best way to learn is to solve extra problems
# Output:
#  These liked there, clotted all my
# Batch Cost 152.80201721191406 after 76 file
#
# Truth:
#  She wore warm, fleecy, woolen overalls
# Output:
#  his survive
# Batch Cost 77.3553237915039 after 77 file
#
# Truth:
#  Ralph controlled the stopwatch from the bleachers
# Output:
#  glee-club Merely worth his scalp persons
# Batch Cost 90.63300323486328 after 78 file
#
# Truth:
#  This brochure is particularly informative for a prospective buyer
# Output:
#  able likely cavity, waste blistered evenly have roof
# Batch Cost 117.3392105102539 after 79 file
#
# Truth:
#  Why charge money for such garbage
# Output:
#  fermented These
# Batch Cost 88.94989013671875 after 80 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  Nor mergers making arms inhuman rag daytime worship many-bodied realizing These victim
# Batch Cost 127.63668060302734 after 81 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  "Steam Suburban were persons, Acropolis persons park
# Batch Cost 105.41281127929688 after 82 file
#
# Truth:
#  Soon the office work claimed all her time
# Output:
#  excellent fled, Pa excellent redwoods Avowed acclaim
# Batch Cost 101.71998596191406 after 83 file
#
# Truth:
#  Next, the hen was nested and all seemed well
# Output:
#  rag realizing many-bodied Acropolis follow neither
# Batch Cost 117.39158630371094 after 84 file
#
# Truth:
#  Heavy industry, slanted toward inexhaustible government coffers, attracted him
# Output:
#  tenant's hung flopped pretty ways have Acropolis in in
# Batch Cost 123.66468811035156 after 85 file
#
# Truth:
#  Are your grades higher or lower than Nancy's
# Output:
#  hold were Suburban tell
# Batch Cost 89.02759552001953 after 86 file
#
# Truth:
#  Project development was proceeding too slowly
# Output:
#  minutes petty madstones becomes crossroads moisture liked
# Batch Cost 79.47430419921875 after 87 file
#
# Truth:
#  Serve the coleslaw after I add the oil
# Output:
#  attention in sauce,
# Batch Cost 105.3041763305664 after 88 file
#
# Truth:
#  The oasis was a mirage
# Output:
#  madstones destroy sitting
# Batch Cost 66.92994689941406 after 89 file
#
# Truth:
#  That noise problem grows more annoying each day
# Output:
#  becomes capillary Steve
# Batch Cost 120.33313751220703 after 90 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  discouraging; soothed persons
# Batch Cost 122.5888442993164 after 91 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  blistered Acropolis park in
# Batch Cost 112.10652160644531 after 92 file
#
# Truth:
#  Several factors contributed to this change
# Output:
#  across to underwriting girlishly guys
# Batch Cost 82.81281280517578 after 93 file
#
# Truth:
#  She greeted her husband's colleagues with smiling politeness, offering nothing
# Output:
#  crab pursued becomes Naturally deeply there, excellent twigged girlishly hook
# Batch Cost 113.1904296875 after 94 file
#
# Truth:
#  He saw a pint-sized man with a graying spade beard and an unusually large head
# Output:
#  encamped your clotted carry oily curry safer your
# Batch Cost 182.84336853027344 after 95 file
#
# Truth:
#  The emperor had a mean temper
# Output:
#  Cooperation lives all many-bodied
# Batch Cost 75.39553833007812 after 96 file
#
# Truth:
#  How permanent are their records
# Output:
#  capillary blistered satellites
# Batch Cost 62.10676574707031 after 97 file
#
# Truth:
#  The meeting is now adjourned
# Output:
#  announcing
# Batch Cost 93.57987976074219 after 98 file
#
# Truth:
#  Critical equipment needs proper maintenance
# Output:
#  blistered park excellent blistered regard
# Batch Cost 66.46393585205078 after 99 file
#
# Truth:
#  Tim takes Sheila to see movies twice a week
# Output:
#  wedding Suburban Suburban colleagues grownups Swing worth
# Batch Cost 114.5492172241211 after 100 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  orthodontic park enter redwoods excellent excellent heap many-bodied
# Batch Cost 110.28498077392578 after 101 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  realizing worth attention Etiquette
# Batch Cost 102.66036987304688 after 102 file
#
# Truth:
#  They've never met, you know
# Output:
#  clerk's safer your
# Batch Cost 83.73944091796875 after 103 file
# Truth:
#  Twenty-two or twenty-three
# Output:
#  farmland compose
# Batch Cost 40.834136962890625 after 104 file
#
# Truth:
#  Tetanus could be avoided by pouring warm turpentine over a wound
# Output:
#  Swing mergers dark Suburban across in oily your
# Batch Cost 154.31854248046875 after 105 file
#
# Truth:
#  The triumphant warrior exhibited naive heroism
# Output:
#  suffer swells meaning daydreamed soothed redwoods many-bodied
# Batch Cost 81.10472106933594 after 106 file
#
# Truth:
#  Can the agency overthrow alien forces
# Output:
#  interpretations to mates wedding expression suffer to
# Batch Cost 92.93699645996094 after 107 file
#
# Truth:
#  According to my interpretation of the problem, two lines must be perpendicular
# Output:
#  quarters rolled opaque excellent oil mind loaded calm killed moisture
# Batch Cost 188.63742065429688 after 108 file
#
# Truth:
#  Suburban housewives often suffer from the gab habit
# Output:
#  winter his kidnappers These there,
# Batch Cost 106.61067962646484 after 109 file
#
# Truth:
#  Good service should be rewarded by big tips
# Output:
#
# Batch Cost 105.73190307617188 after 110 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  mergers heap mandates districts interpretations
# Batch Cost 115.57586669921875 after 111 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  liked girlishly attention
# Batch Cost 105.6214370727539 after 112 file
#
# Truth:
#  Your voice is delightful, he approved with a warm smile
# Output:
#  interpretations season likely soothed bullet
# Batch Cost 134.86830139160156 after 113 file
#
# Truth:
#  Turbulent tides rose as much as fifty feet
# Output:
#  the Suburban kidnappers deeply his queen, in
# Batch Cost 121.86083221435547 after 114 file
#
# Truth:
#  Sometimes soldiers wrote letters while bullets were whizzing about their heads
# Output:
#  meaning ask freedom pace Primitive meaning nearly deeply
# Batch Cost 146.85031127929688 after 115 file
#
# Truth:
#  Cyclical programs will never compile
# Output:
#  redwoods interpretations frantically
# Batch Cost 66.286376953125 after 116 file
#
# Truth:
#  Clear pronunciation is appreciated
# Output:
#  lives in queen,
# Batch Cost 53.77238082885742 after 117 file
#
# Truth:
#  Steve collects rare and novel coins
# Output:
#  Suburban accuse his iron atypical admitted
# Batch Cost 89.18273162841797 after 118 file
#
# Truth:
#  A huge power outage rarely occurs
# Output:
#  chives crashing There,
# Batch Cost 105.91848754882812 after 119 file
#
# Truth:
#  Academic aptitude guarantees your diploma
# Output:
#  gin tell ephemeral mind Space dark realizing
# Batch Cost 67.30502319335938 after 120 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  a liked inhuman underwriting oil attention excellent there, validated curry
# Batch Cost 90.97025299072266 after 121 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  latches liked liked
# Batch Cost 97.34312438964844 after 122 file
#
# Truth:
#  Outside, only a handful of reporters remained
# Output:
#  redwoods arms enter to regenerating the the lacerate
# Batch Cost 85.02224731445312 after 123 file
#
# Truth:
#  Naturally curly hair runs in my family
# Output:
#  had Suburban had in to Ideally, frantically regenerating
# Batch Cost 84.90219116210938 after 124 file
#
# Truth:
#  In tradition and in poetry, the marriage bed is a place of unity and harmony
# Output:
#  non-contributory Suburban ephemeral save centuries chronological
# Batch Cost 188.69418334960938 after 125 file
#
# Truth:
#  Tugboats are capable of hauling huge loads
# Output:
#  proud Suburban persons, an frost
# Batch Cost 91.32251739501953 after 126 file
#
# Truth:
#  How much allowance do you get
# Output:
#  radioactive government
# Batch Cost 87.47889709472656 after 127 file
#
# Truth:
#  When all else fails, use force
# Output:
#  throughout
# Batch Cost 85.23538970947266 after 128 file
#
# Truth:
#  These exclusive documents must be locked up at all times
# Output:
#  carry tell worth chronological to curiosity inhuman liked daydreamed
# Batch Cost 137.47727966308594 after 129 file
#
# Truth:
#  George is paranoid about a future gas shortage
# Output:
#  throughout nothing soothed liked shut
# Batch Cost 107.63060760498047 after 130 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  considered Ideally, kidnappers Oval hold radioactive literary kidnappers
# Batch Cost 101.36018371582031 after 131 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  sunburn threatening clarify girlishly hung crawling Suburban
# Batch Cost 95.82267761230469 after 132 file
#
# Truth:
#  Readiness exercises are almost continuous
# Output:
#  oil daydreamed his Halloween hold These Perhaps
# Batch Cost 55.4964485168457 after 133 file
#
# Truth:
#  Something else distracted him, yet there was no sound, only tomblike silence
# Output:
#  nearly kidnappers girlishly a nearly Suburban
# Batch Cost 160.05581665039062 after 134 file
#
# Truth:
#  Don't they still call you "Junior", as though you're about ten years old
# Output:
#  park progress, Give enter worth Suburban Next clerk's kidnappers
# Batch Cost 182.8496551513672 after 135 file
#
# Truth:
#  The drunkard is a social outcast
# Output:
#  carry nearly crashing Suburban liked
# Batch Cost 64.11924743652344 after 136 file
#
# Truth:
#  Reading in poor light gives you eyestrain
# Output:
#  the zebras
# Batch Cost 98.92528533935547 after 137 file
#
# Truth:
#  The dark, murky lagoon wound around for miles
# Output:
#  attention inhuman surveying daytime
# Batch Cost 99.38713073730469 after 138 file
#
# Truth:
#  A crab challenged me, but a quick stab vanquished him
# Output:
#  liked She apparently colleagues liked Suburban
# Batch Cost 111.27924346923828 after 139 file
#
# Truth:
#  Upgrade your status to reflect your wealth
# Output:
#  Suburban liked ask
# Batch Cost 76.91651916503906 after 140 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  Suburban water pursued
# Batch Cost 103.62471771240234 after 141 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  to Suburban Tradition bullets curry
# Batch Cost 91.37289428710938 after 142 file
#
# Truth:
#  We scour literature for them; here we find stored the wisdom of great minds
# Output:
#  to bullets ask progress, shut orthodontist
# Batch Cost 191.95399475097656 after 143 file
#
# Truth:
#  We have better rooms vacant now, he babbled
# Output:
#  throughout radioactivity ask skating daydreamed pursued emphysema,
# Batch Cost 102.93484497070312 after 144 file
#
# Truth:
#  We flew in rickety planes so overloaded that we wondered why they didn't crash
# Output:
#  emphysema, capillary "Steam me attention mind destroy
# Batch Cost 193.8235321044922 after 145 file
#
# Truth:
#  Cyclical programs will never compile
# Output:
#  daytime Remember Then, redwoods lives a
# Batch Cost 70.63652801513672 after 146 file
#
# Truth:
#  Clear pronunciation is appreciated
# Output:
#  liked continuous dark oily nearly realizing in
# Batch Cost 47.580963134765625 after 147 file
#
# Truth:
#  Steve collects rare and novel coins
# Output:
#  girlishly worth heap nothing
# Batch Cost 78.5443115234375 after 148 file
#
# Truth:
#  A huge power outage rarely occurs
# Output:
#
# Batch Cost 63.51921463012695 after 149 file
#
# Truth:
#  Academic aptitude guarantees your diploma
# Output:
#  lives daytime overtake Perhaps apparently
# Batch Cost 68.2460708618164 after 150 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  colleagues dark Home-made park
# Batch Cost 109.04450988769531 after 151 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  wash
# Batch Cost 98.10934448242188 after 152 file
#
# Truth:
#  Afraid you'll lose your job if you don't keep your mouth shut
# Output:
#  lives secret validated girlishly in
# Batch Cost 137.529296875 after 153 file
#
# Truth:
#  Some observers speculated that this might be his revenge on his home town
# Output:
#  liked shucks,
# Batch Cost 158.6611785888672 after 154 file
#
# Truth:
#  Push back up and repeat
# Output:
#  ask to lives daydreamed redwoods
# Batch Cost 62.75956344604492 after 155 file
#
# Truth:
#  Our experiment's positive outcome was unexpected
# Output:
#  redwoods chronological
# Batch Cost 71.0833740234375 after 156 file
#
# Truth:
#  How ancient is this subway escalator
# Output:
#  ask girlishly
# Batch Cost 76.87757110595703 after 157 file
#
# Truth:
#  Rob made Hungarian goulash for dinner and gooseberry pie for dessert
# Output:
#  shucks, validated somewhere progress,
# Batch Cost 123.13423919677734 after 158 file
#
# Truth:
#  A moth zig-zagged along the path through Otto's garden
# Output:
#  radioactive
# Batch Cost 106.92906188964844 after 159 file
#
# Truth:
#  We got drenched from the uninterrupted rain
# Output:
#  liked progress, attention attention
# Batch Cost 91.42311096191406 after 160 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  unauthentic Perhaps suit
# Batch Cost 102.04258728027344 after 161 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  apparently your
# Batch Cost 98.1010971069336 after 162 file
#
# Truth:
#  By the look of him he wasn't that far gone
# Output:
#  attention inhuman
# Batch Cost 103.93892669677734 after 163 file
#
# Truth:
#  Were you in love with that girl
# Output:
#
# Batch Cost 75.60333251953125 after 164 file
#
# Truth:
#  Here they did not need to be in ghettos
# Output:
#  redwoods Halloween rag girlishly
# Batch Cost 120.3586196899414 after 165 file
#
# Truth:
#  Scholastic aptitude is judged by standardized tests
# Output:
#  She shut liked
# Batch Cost 78.34577178955078 after 166 file
#
# Truth:
#  They all agree that the essay is barely intelligible
# Output:
#  girlishly roof Tradition apparently
# Batch Cost 96.41681671142578 after 167 file
#
# Truth:
#  An adult male baboon's teeth are not suitable for eating shellfish
# Output:
#  validated roof lives ritual had
# Batch Cost 126.01518249511719 after 168 file
#
# Truth:
#  Smash lightbulbs and their cash value will diminish to nothing
# Output:
#  girlishly redwoods shut to rag colleagues
# Batch Cost 115.45274353027344 after 169 file
#
# Truth:
#  Continental drift is a geological theory
# Output:
#  electron voice
# Batch Cost 63.03183364868164 after 170 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  These water chronological had
# Batch Cost 101.81255340576172 after 171 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  interpretations
# Batch Cost 94.90489196777344 after 172 file
#
# Truth:
#  Have you got enough blankets
# Output:
#  chronological
# Batch Cost 57.983558654785156 after 173 file
#
# Truth:
#  It had gone like clockwork
# Output:
#  park frost
# Batch Cost 57.52855682373047 after 174 file
#
# Truth:
#  Would a camera club be useful in taking pictures pertinent to plant safety
# Output:
#  to Perhaps These progress, considered to She
# Batch Cost 143.48191833496094 after 175 file
#
# Truth:
#  Angora cats are furrier than Siamese
# Output:
#  She These
# Batch Cost 71.54517364501953 after 176 file
#
# Truth:
#  Nonprofit organizations have frequent fund raisers
# Output:
#  chronological frost ask to
# Batch Cost 74.90569305419922 after 177 file
#
# Truth:
#  The proof that you are seeking is not available in books
# Output:
#  progress, liked the nothing shut daydreamed
# Batch Cost 132.29190063476562 after 178 file
#
# Truth:
#  Barb's gold bracelet was a graduation present
# Output:
#  issue Perhaps
# Batch Cost 80.89591217041016 after 179 file
#
# Truth:
#  They assume no burglar will ever enter here
# Output:
#  Tradition liked
# Batch Cost 105.60189056396484 after 180 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  liked liked suit validated
# Batch Cost 104.31089782714844 after 181 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  Perhaps
# Batch Cost 89.24164581298828 after 182 file
#
# Truth:
#  In what ways, then, did the patient's psychical blindness manifest itself
# Output:
#  to ask She attention
# Batch Cost 131.73765563964844 after 183 file
#
# Truth:
#  It would be a colossal shame to throw away a story like this
# Output:
#  your threatening lives Adults
# Batch Cost 173.81500244140625 after 184 file
#
# Truth:
#  Let all projects dry slowly for several days
# Output:
#  suit water the rag
# Batch Cost 96.5503921508789 after 185 file
#
# Truth:
#  The sound of Jennifer's bugle scared the antelope
# Output:
#  the the considered ask lives
# Batch Cost 100.60810089111328 after 186 file
#
# Truth:
#  Highway and freeway mean the same thing
# Output:
#  progress, Perhaps
# Batch Cost 85.58081817626953 after 187 file
#
# Truth:
#  The fog prevented them from arriving on time
# Output:
#  destroy ask
# Batch Cost 106.10987091064453 after 188 file
#
# Truth:
#  Daphne's Swedish needlepoint scarf matched her skirt
# Output:
#  liked swells to These your
# Batch Cost 90.80615997314453 after 189 file
#
# Truth:
#  Even a simple vocabulary contains symbols
# Output:
#  girlishly enter frost apparently
# Batch Cost 71.30176544189453 after 190 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  threatening
# Batch Cost 88.91212463378906 after 191 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  threatening girlishly
# Batch Cost 83.53411865234375 after 192 file
#
# Truth:
#  The revised procedure was acclaimed as a long-overdue reform
# Output:
#
# Batch Cost 99.37654113769531 after 193 file
#
# Truth:
#  He held his arms close to his sides and made himself as small as possible
# Output:
#  to Perhaps liked liked
# Batch Cost 166.01406860351562 after 194 file
#
# Truth:
#  One could hear a very faint, ladylike sigh of relief
# Output:
#  to
# Batch Cost 128.33082580566406 after 195 file
#
# Truth:
#  Tradition requires parental approval for under-age marriage
# Output:
#  ritual
# Batch Cost 76.48037719726562 after 196 file
#
# Truth:
#  It's healthier to cook without sugar
# Output:
#
# Batch Cost 76.34751892089844 after 197 file
#
# Truth:
#  The cranberry bog gets very pretty in Autumn
# Output:
#  attention
# Batch Cost 86.94586181640625 after 198 file
#
# Truth:
#  Laugh, dance, and sing if fortune smiles upon you
# Output:
#  lives
# Batch Cost 104.99752044677734 after 199 file
#
# Truth:
#  Mom strongly dislikes appetizers
# Output:
#  liked
# Batch Cost 46.14929962158203 after 200 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  attention to
# Batch Cost 94.84200286865234 after 201 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  oily attention attention She
# Batch Cost 77.14479064941406 after 202 file
#
# Truth:
#  Questions came to me from all sides about my world citizenship activities
# Output:
#  She validated
# Batch Cost 117.33041381835938 after 203 file
#
# Truth:
#  Anyhow, it was high time the boy was salted
# Output:
#  She attention
# Batch Cost 118.1050033569336 after 204 file
#
# Truth:
#  We did not accept the diagnosis at once, but gradually we are coming to
# Output:
#  oily She to
# Batch Cost 139.71116638183594 after 205 file
#
# Truth:
#  A huge tapestry hung in her hallway
# Output:
#  She validated
# Batch Cost 88.07169342041016 after 206 file
#
# Truth:
#  A roll of wire lay near the wall
# Output:
#
# Batch Cost 94.88508605957031 after 207 file
#
# Truth:
#  How do oysters make pearls
# Output:
#  She to
# Batch Cost 56.471988677978516 after 208 file
#
# Truth:
#  In every major cloverleaf, traffic sometimes gets backed up
# Output:
#  suffer threatening She She
# Batch Cost 111.89266967773438 after 209 file
#
# Truth:
#  Women may never become completely equal to men
# Output:
#  to was She
# Batch Cost 84.06671142578125 after 210 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  carry
# Batch Cost 83.29519653320312 after 211 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  lives She
# Batch Cost 79.46997833251953 after 212 file
#
# Truth:
#  The trouble is that like many symbols it doesn't seem a very realistic one
# Output:
#  is attention to lucky apparently
# Batch Cost 163.5223846435547 after 213 file
#
# Truth:
#  You'll have to try it alone
# Output:
#
# Batch Cost 74.67847442626953 after 214 file
#
# Truth:
#  He talked about unauthentic storylines too
# Output:
#
# Batch Cost 70.34917449951172 after 215 file
#
# Truth:
#  Who took the kayak down the bayou
# Output:
#
# Batch Cost 78.58594512939453 after 216 file
#
# Truth:
#  The essay undeniably reflects our view ably
# Output:
#  touch madstones
# Batch Cost 76.48844146728516 after 217 file
#
# Truth:
#  I'll have a scoop of that exotic purple and turquoise sherbet
# Output:
#  a me
# Batch Cost 99.40528869628906 after 218 file
#
# Truth:
#  Shell shock caused by shrapnel is sometimes cured through group therapy
# Output:
#
# Batch Cost 132.74288940429688 after 219 file
#
# Truth:
#  Doctors prescribe drugs too freely
# Output:
#  oil rag
# Batch Cost 72.61612701416016 after 220 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 79.64456176757812 after 221 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 73.20711517333984 after 222 file
# Truth:
#  Many selections are themselves convincing contributions to this appraisal
# Output:
#  carry apparently apparently
# Batch Cost 99.0428466796875 after 223 file
#
# Truth:
#  They went downstairs, loaded a tray lavishly
# Output:
#
# Batch Cost 79.18164825439453 after 224 file
#
# Truth:
#  Never happier in my life
# Output:
#
# Batch Cost 52.846099853515625 after 225 file
#
# Truth:
#  Who authorized the unlimited expense account
# Output:
#  apparently
# Batch Cost 74.16215515136719 after 226 file
#
# Truth:
#  To further his prestige, he occasionally reads the Wall Street Journal
# Output:
#  rag
# Batch Cost 128.39688110351562 after 227 file
#
# Truth:
#  Lori's costume needed black gloves to be completely elegant
# Output:
#
# Batch Cost 97.04219055175781 after 228 file
#
# Truth:
#  Why yell or worry over silly items
# Output:
#
# Batch Cost 89.56991577148438 after 229 file
#
# Truth:
#  Guess the question from the answer
# Output:
#
# Batch Cost 69.47579956054688 after 230 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  apparently
# Batch Cost 76.47256469726562 after 231 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  rag apparently
# Batch Cost 90.69911193847656 after 232 file
#
# Truth:
#  Even then, if she took one step forward he could catch her
# Output:
#  rag
# Batch Cost 146.8479461669922 after 233 file
#
# Truth:
#  Or borrow some money from someone and go home by bus
# Output:
#  rag
# Batch Cost 132.2564697265625 after 234 file
#
# Truth:
#  A sailboat may have a bone in her teeth one minute and lie becalmed the next
# Output:
#  water was
# Batch Cost 190.4690399169922 after 235 file
#
# Truth:
#  The emperor had a mean temper
# Output:
#  water rag girlishly
# Batch Cost 61.41001510620117 after 236 file
#
# Truth:
#  How permanent are their records
# Output:
#
# Batch Cost 66.85294342041016 after 237 file
#
# Truth:
#  The meeting is now adjourned
# Output:
#  in Perhaps validated
# Batch Cost 66.1604995727539 after 238 file
#
# Truth:
#  Critical equipment needs proper maintenance
# Output:
#  the inhuman rag
# Batch Cost 76.20919036865234 after 239 file
#
# Truth:
#  Tim takes Sheila to see movies twice a week
# Output:
#
# Batch Cost 94.99234771728516 after 240 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 83.41018676757812 after 241 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 78.91627502441406 after 242 file
#
# Truth:
#  He travelled all over the world
# Output:
#
# Batch Cost 73.74762725830078 after 243 file
#
# Truth:
#  Baseball's no cinch
# Output:
#
# Batch Cost 39.5450325012207 after 244 file
#
# Truth:
#  Next he addressed himself to our souls
# Output:
#
# Batch Cost 75.12187194824219 after 245 file
#
# Truth:
#  Employee layoffs coincided with the company's reorganization
# Output:
#
# Batch Cost 72.25274658203125 after 246 file
#
# Truth:
#  We are open every Monday evening
# Output:
#
# Batch Cost 62.19390106201172 after 247 file
#
# Truth:
#  The patient and the surgeon are both recuperating from the lengthy operation
# Output:
#  pace
# Batch Cost 122.76253509521484 after 248 file
#
# Truth:
#  They used an aggressive policeman to flag thoughtless motorists
# Output:
#
# Batch Cost 95.65279388427734 after 249 file
#
# Truth:
#  Bagpipes and bongos are musical instruments
# Output:
#
# Batch Cost 56.0215950012207 after 250 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 85.31375885009766 after 251 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 81.00997161865234 after 252 file
#
# Truth:
#  How do we define it
# Output:
#
# Batch Cost 53.385711669921875 after 253 file
#
# Truth:
#  She always did before, and showed the utmost confidence in whatever we advised
# Output:
#
# Batch Cost 132.83566284179688 after 254 file
#
# Truth:
#  This, he added, brought about petty jealousies and petty personal grievances
# Output:
#  to
# Batch Cost 131.5635986328125 after 255 file
#
# Truth:
#  Trespassing is forbidden and subject to penalty
# Output:
#
# Batch Cost 74.8643798828125 after 256 file
#
# Truth:
#  Only the best players enjoy popularity
# Output:
#
# Batch Cost 65.02877807617188 after 257 file
#
# Truth:
#  We like bleu cheese but Victor prefers swiss cheese
# Output:
#
# Batch Cost 104.46758270263672 after 258 file
#
# Truth:
#  A good attitude is unbeatable
# Output:
#
# Batch Cost 51.99484634399414 after 259 file
#
# Truth:
#  They all like long hot showers
# Output:
#  inhuman
# Batch Cost 58.79981231689453 after 260 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 64.59546661376953 after 261 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 78.20127868652344 after 262 file
#
# Truth:
#  These always contain metallic inclusions
# Output:
#  to
# Batch Cost 70.29449462890625 after 263 file
#
# Truth:
#  We don't know this guy
# Output:
#
# Batch Cost 59.5318603515625 after 264 file
#
# Truth:
#  A site may also be attractive just through the beauty of its trees and shrubs
# Output:
#  to to
# Batch Cost 174.7774200439453 after 265 file
#
# Truth:
#  She encouraged her children to make their own Halloween costumes
# Output:
#
# Batch Cost 110.1582260131836 after 266 file
#
# Truth:
#  The jaw operates by using antagonistic muscles
# Output:
#
# Batch Cost 80.2585678100586 after 267 file
#
# Truth:
#  George seldom watches daytime movies
# Output:
#
# Batch Cost 52.882911682128906 after 268 file
#
# Truth:
#  Spherical gifts are difficult to wrap
# Output:
#
# Batch Cost 56.397518157958984 after 269 file
#
# Truth:
#  Flying standby can be practical if you want to save money
# Output:
#  the
# Batch Cost 127.1020736694336 after 270 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  the
# Batch Cost 66.12957000732422 after 271 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 75.32268524169922 after 272 file
#
# Truth:
#  Research into several cultures has proven her position to be a mistaken one
# Output:
#  the
# Batch Cost 158.90200805664062 after 273 file
#
# Truth:
#  But it did print good verse and good fiction
# Output:
#
# Batch Cost 99.04759216308594 after 274 file
#
# Truth:
#  He kissed her also, and with deep tenderness
# Output:
#
# Batch Cost 107.7887191772461 after 275 file
#
# Truth:
#  Her auburn hair reminded him of autumn leaves
# Output:
#  the the
# Batch Cost 90.9520492553711 after 276 file
#
# Truth:
#  The gorgeous butterfly ate a lot of nectar
# Output:
#
# Batch Cost 85.93830108642578 after 277 file
#
# Truth:
#  Take charge of choosing her bride's maids' gowns
# Output:
#  the to
# Batch Cost 85.40972137451172 after 278 file
#
# Truth:
#  Coffee is grown on steep, jungle-like slopes in temperate zones
# Output:
#  to
# Batch Cost 111.0738754272461 after 279 file
#
# Truth:
#  Spring Street is straight ahead
# Output:
#
# Batch Cost 61.83570098876953 after 280 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  wash
# Batch Cost 65.25474548339844 after 281 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#  the
# Batch Cost 69.96407318115234 after 282 file
#
# Truth:
#  Originally, the main types used were various compositions of polyesters
# Output:
#  wash
# Batch Cost 97.31291961669922 after 283 file
#
# Truth:
#  What about a tea room, then
# Output:
#
# Batch Cost 68.52783966064453 after 284 file
#
# Truth:
#  Several firms are merchandising enzyme preparation through feed manufacturers
# Output:
#
# Batch Cost 107.1112289428711 after 285 file
#
# Truth:
#  He stole a dime from a beggar
# Output:
#
# Batch Cost 75.48225402832031 after 286 file
#
# Truth:
#  Before Thursday's exam, review every formula
# Output:
#
# Batch Cost 73.3600082397461 after 287 file
#
# Truth:
#  They enjoy it when I audition
# Output:
#
# Batch Cost 81.45890045166016 after 288 file
#
# Truth:
#  Jeff thought you argued in favor of a centrifuge purchase
# Output:
#
# Batch Cost 110.68003845214844 after 289 file
#
# Truth:
#  John cleans shellfish for a living
# Output:
#
# Batch Cost 52.51121139526367 after 290 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 73.80586242675781 after 291 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 79.79312133789062 after 292 file
#
# Truth:
#  By that time, perhaps something better can be done
# Output:
#
# Batch Cost 88.57575988769531 after 293 file
#
# Truth:
#  This tragic lad had forged his own shackles
# Output:
#
# Batch Cost 78.4776840209961 after 294 file
#
# Truth:
#  Check your cafeteria location to make sure it's convenient for most employees
# Output:
#
# Batch Cost 126.3031005859375 after 295 file
#
# Truth:
#  The sound of Jennifer's bugle scared the antelope
# Output:
#
# Batch Cost 92.20995330810547 after 296 file
#
# Truth:
#  Highway and freeway mean the same thing
# Output:
#
# Batch Cost 84.4551010131836 after 297 file
#
# Truth:
#  The fog prevented them from arriving on time
# Output:
#
# Batch Cost 86.37481689453125 after 298 file
#
# Truth:
#  Daphne's Swedish needlepoint scarf matched her skirt
# Output:
#  suit
# Batch Cost 82.98983001708984 after 299 file
#
# Truth:
#  Even a simple vocabulary contains symbols
# Output:
#
# Batch Cost 62.206668853759766 after 300 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 77.14495849609375 after 301 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 72.93346405029297 after 302 file
#
# Truth:
#  The system works as an impersonal mechanism
# Output:
#  rag
# Batch Cost 87.19889068603516 after 303 file
#
# Truth:
#  Clapping spurs to the bronc, he set off at a sharp canter, with growing alarm
# Output:
#
# Batch Cost 175.2367706298828 after 304 file
#
# Truth:
#  Everything went real smooth, the sheriff said
# Output:
#
# Batch Cost 90.82268524169922 after 305 file
#
# Truth:
#  Why else would Danny allow others to go
# Output:
#
# Batch Cost 97.10586547851562 after 306 file
#
# Truth:
#  The angry boy answered but didn't look up
# Output:
#
# Batch Cost 84.206787109375 after 307 file
#
# Truth:
#  The cow wandered from the farmland and became lost
# Output:
#
# Batch Cost 83.7308578491211 after 308 file
#
# Truth:
#  Seamstresses attach zippers with a thimble, needle, and thread
# Output:
#
# Batch Cost 97.58372497558594 after 309 file
#
# Truth:
#  Cut a small corner off each edge
# Output:
#
# Batch Cost 72.67023468017578 after 310 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 71.27145385742188 after 311 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 67.98410034179688 after 312 file
#
# Truth:
#  What obsessions had she picked up during these long nights of talk
# Output:
#
# Batch Cost 130.31613159179688 after 313 file
#
# Truth:
#  And possessed himself -- how
# Output:
#
# Batch Cost 67.97953033447266 after 314 file
#
# Truth:
#  They will take a wedding trip later
# Output:
#
# Batch Cost 75.3738784790039 after 315 file
#
# Truth:
#  The emblem depicts the Acropolis all aglow
# Output:
#
# Batch Cost 52.687255859375 after 316 file
#
# Truth:
#  Military personnel are expected to obey government orders
# Output:
#
# Batch Cost 85.38247680664062 after 317 file
#
# Truth:
#  Only lawyers love millionaires
# Output:
#
# Batch Cost 45.26240158081055 after 318 file
#
# Truth:
#  If Carol comes tomorrow, have her arrange for a meeting at two
# Output:
#
# Batch Cost 125.64666748046875 after 319 file
#
# Truth:
#  His shoulder felt as if it were broken
# Output:
#
# Batch Cost 110.0250473022461 after 320 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 74.93354797363281 after 321 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 64.94482421875 after 322 file
#
# Truth:
#  One wonders about its applicability to people
# Output:
#
# Batch Cost 68.63042449951172 after 323 file
#
# Truth:
#  Do you know what they think of me
# Output:
#
# Batch Cost 88.8011245727539 after 324 file
#
# Truth:
#  This is not a program of socialized medicine
# Output:
#
# Batch Cost 78.51461791992188 after 325 file
#
# Truth:
#  Who authorized the unlimited expense account
# Output:
#
# Batch Cost 70.87789916992188 after 326 file
#
# Truth:
#  To further his prestige, he occasionally reads the Wall Street Journal
# Output:
#
# Batch Cost 116.72480010986328 after 327 file
#
# Truth:
#  Lori's costume needed black gloves to be completely elegant
# Output:
#
# Batch Cost 84.06195831298828 after 328 file
#
# Truth:
#  Why yell or worry over silly items
# Output:
#
# Batch Cost 82.77088165283203 after 329 file
#
# Truth:
#  Guess the question from the answer
# Output:
#
# Batch Cost 67.19071197509766 after 330 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  inhuman
# Batch Cost 77.49629211425781 after 331 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 66.49376678466797 after 332 file
#
# Truth:
#  The gunman nodded, slipping the picture into his breast pocket, saying nothing
# Output:
#
# Batch Cost 118.18702697753906 after 333 file
#
# Truth:
#  He sized up the situation and shook his head
# Output:
#
# Batch Cost 82.3636474609375 after 334 file
#
# Truth:
#  A pool is no place for a shut trap
# Output:
#
# Batch Cost 98.91973876953125 after 335 file
#
# Truth:
#  They remained lifelong friends and companions
# Output:
#
# Batch Cost 69.8046646118164 after 336 file
#
# Truth:
#  By eating yogurt, you may live longer
# Output:
#
# Batch Cost 80.79827117919922 after 337 file
#
# Truth:
#  The frightened child was gently subdued by his big brother
# Output:
#
# Batch Cost 111.46419525146484 after 338 file
#
# Truth:
#  The overweight charmer could slip poison into anyone's tea
# Output:
#
# Batch Cost 84.37313079833984 after 339 file
#
# Truth:
#  Cliff's display was misplaced on the screen
# Output:
#
# Batch Cost 71.16181945800781 after 340 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 67.32140350341797 after 341 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 59.282958984375 after 342 file
#
# Truth:
#  At intervals an alumni directory is issued
# Output:
#
# Batch Cost 80.32093048095703 after 343 file
#
# Truth:
#  You do that or take you out a permit right now
# Output:
#
# Batch Cost 116.10823822021484 after 344 file
#
# Truth:
#  Yes indeed, we too can see a warlike host of infidels encamped against us
# Output:
#
# Batch Cost 153.74179077148438 after 345 file
#
# Truth:
#  The emperor had a mean temper
# Output:
#
# Batch Cost 57.32750701904297 after 346 file
#
# Truth:
#  How permanent are their records
# Output:
#
# Batch Cost 54.16321563720703 after 347 file
#
# Truth:
#  The preschooler couldn't verbalize her feelings about the emergency conditions
# Output:
#
# Batch Cost 101.354248046875 after 348 file
#
# Truth:
#  Critical equipment needs proper maintenance
# Output:
#
# Batch Cost 57.671382904052734 after 349 file
#
# Truth:
#  Tim takes Sheila to see movies twice a week
# Output:
#
# Batch Cost 88.9306411743164 after 350 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 81.79080963134766 after 351 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 70.40209197998047 after 352 file
#
# Truth:
#  Husky young man, he said with mock distaste
# Output:
#
# Batch Cost 93.76419830322266 after 353 file
#
# Truth:
#  Ahah, he thought, a lush divorcee at last
# Output:
#
# Batch Cost 84.33670806884766 after 354 file
#
# Truth:
#  Thus technical efficiency is achieved at the expense of actual experience
# Output:
#
# Batch Cost 100.04928588867188 after 355 file
#
# Truth:
#  Objects made of pewter are beautiful
# Output:
#
# Batch Cost 56.882164001464844 after 356 file
#
# Truth:
#  The morning dew on the spider web glistened in the sun
# Output:
#
# Batch Cost 111.7480239868164 after 357 file
#
# Truth:
#  Cheap stockings run the first time they're worn
# Output:
#
# Batch Cost 83.984375 after 358 file
#
# Truth:
#  Don't do Charlie's dirty dishes
# Output:
#
# Batch Cost 49.04683303833008 after 359 file
#
# Truth:
#  Calcium makes bones and teeth strong
# Output:
#
# Batch Cost 66.85474395751953 after 360 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 71.97151184082031 after 361 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 60.056724548339844 after 362 file
#
# Truth:
#  Measured performance characteristics for this experimental tube will be listed
# Output:
#
# Batch Cost 120.88187408447266 after 363 file
#
# Truth:
#  No temptation, no virtue
# Output:
#
# Batch Cost 50.198123931884766 after 364 file
#
# Truth:
#  Selecting bunks by economic comparison is usually an individual problem
# Output:
#
# Batch Cost 94.15827941894531 after 365 file
#
# Truth:
#  His sudden departure shocked the cast
# Output:
#
# Batch Cost 62.9149169921875 after 366 file
#
# Truth:
#  Approach your interview with statuesque composure
# Output:
#
# Batch Cost 58.852359771728516 after 367 file
#
# Truth:
#  Alfalfa is healthy for you
# Output:
#
# Batch Cost 45.82734298706055 after 368 file
#
# Truth:
#  The avalanche triggered a minor earthquake
# Output:
#
# Batch Cost 54.08099365234375 after 369 file
#
# Truth:
#  We welcome many new students each year
# Output:
#
# Batch Cost 83.30948638916016 after 370 file
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 79.93534088134766 after 371 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 76.52532196044922 after 372 file
#
# Truth:
#  This has been attributed to helium film flow in the vapor pressure thermometer
# Output:
#
# Batch Cost 143.46212768554688 after 373 file
#
# Truth:
#  Receiving no answer, they set the fire
# Output:
#
# Batch Cost 89.1808853149414 after 374 file
#
# Truth:
#  As his feet slowed, he felt ashamed of the panic and resolved to make a stand
# Output:
#
# Batch Cost 141.0621337890625 after 375 file
#
# Truth:
#  Cyclical programs will never compile
# Output:
#
# Batch Cost 50.382659912109375 after 376 file
#
# Truth:
#  Clear pronunciation is appreciated
# Output:
#
# Batch Cost 40.227638244628906 after 377 file
#
# Truth:
#  Steve collects rare and novel coins
# Output:
#
# Batch Cost 64.40753936767578 after 378 file
#
# Truth:
#  A huge power outage rarely occurs
# Output:
#
# Batch Cost 67.98468017578125 after 379 file
#
# Truth:
#  Academic aptitude guarantees your diploma
# Output:
#
# Batch Cost 51.09884262084961 after 380 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 69.8344497680664 after 381 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 60.3573112487793 after 382 file
#
# Truth:
#  To what extent such low density applies to micrometeorites is unknown
# Output:
#
# Batch Cost 118.4748764038086 after 383 file
#
# Truth:
#  He moistened his lips uneasily
# Output:
#
# Batch Cost 58.07586669921875 after 384 file
#
# Truth:
#  The cloudburst cut off abruptly
# Output:
#
# Batch Cost 50.8287239074707 after 385 file
#
# Truth:
#  Most precincts had a third of the votes counted
# Output:
#
# Batch Cost 79.3917007446289 after 386 file
#
# Truth:
#  A doctor was in the ambulance with the patient
# Output:
#
# Batch Cost 83.31400299072266 after 387 file
#
# Truth:
#  Gregory and Tom chose to watch cartoons in the afternoon
# Output:
#
# Batch Cost 84.19730377197266 after 388 file
#
# Truth:
#  Iris thinks the zoo has eleven Spanish zebras
# Output:
#
# Batch Cost 76.74488830566406 after 389 file
#
# Truth:
#  We experience distress and frustration obtaining our degrees
# Output:
#
# Batch Cost 86.23390197753906 after 390 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 67.08741760253906 after 391 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 65.89884948730469 after 392 file
#
# Truth:
#  Visually, these approximated what he was feeling within himself
# Output:
#
# Batch Cost 98.63092803955078 after 393 file
#
# Truth:
#  You saw them always together those years
# Output:
#
# Batch Cost 82.50251007080078 after 394 file
#
# Truth:
#  But such cases were, in the past, unusual
# Output:
#
# Batch Cost 76.62249755859375 after 395 file
#
# Truth:
#  The misquote was retracted with an apology
# Output:
#
# Batch Cost 65.74576568603516 after 396 file
#
# Truth:
#  Michael colored the bedroom wall with crayons
# Output:
#
# Batch Cost 68.10616302490234 after 397 file
#
# Truth:
#  Help Greg to pick a peck of potatoes
# Output:
#
# Batch Cost 81.64962768554688 after 398 file
#
# Truth:
#  Shaving cream is a popular item on Halloween
# Output:
#
# Batch Cost 71.59130859375 after 399 file
#
# Truth:
#  They own a big house in the remote countryside
# Output:
#
# Batch Cost 86.86347961425781 after 400 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 67.88839721679688 after 401 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 57.73185729980469 after 402 file
#
# Truth:
#  They often threw tidbits overboard
# Output:
#
# Batch Cost 58.02614974975586 after 403 file
#
# Truth:
#  "Virus infection nothing!", she'd scream at him
# Output:
#
# Batch Cost 79.6066665649414 after 404 file
#
# Truth:
#  Crooked, overlapping, twisted, or widely spaced teeth
# Output:
#
# Batch Cost 69.95362854003906 after 405 file
#
# Truth:
#  Westchester is a county in New York
# Output:
#
# Batch Cost 75.60858917236328 after 406 file
#
# Truth:
#  The sermon emphasized the need for affirmative action
# Output:
#
# Batch Cost 76.79560852050781 after 407 file
#
# Truth:
#  Cottage cheese with chives is delicious
# Output:
#
# Batch Cost 61.405643463134766 after 408 file
#
# Truth:
#  Help celebrate your brother's success
# Output:
#
# Batch Cost 60.397674560546875 after 409 file
#
# Truth:
#  I took her word for it, but is she really going with you
# Output:
#
# Batch Cost 125.71672058105469 after 410 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 64.37655639648438 after 411 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 63.67810821533203 after 412 file
#
# Truth:
#  Our successors will have an easier task
# Output:
#
# Batch Cost 71.1700668334961 after 413 file
#
# Truth:
#  His artistic accomplishments guaranteed him entry into any social gathering
# Output:
#
# Batch Cost 104.99100494384766 after 414 file
#
# Truth:
#  They're going to louse me up good
# Output:
#
# Batch Cost 67.78738403320312 after 415 file
#
# Truth:
#  Rich looked for spotted hyenas and jaguars on the safari
# Output:
#
# Batch Cost 97.90187072753906 after 416 file
#
# Truth:
#  Be careful not to plow over the flower beds
# Output:
#
# Batch Cost 93.88282775878906 after 417 file
#
# Truth:
#  The speech symposium might begin Monday
# Output:
#
# Batch Cost 67.66950988769531 after 418 file
#
# Truth:
#  The thick elm forest was nearly overwhelmed by Dutch Elm Disease
# Output:
#
# Batch Cost 111.1345443725586 after 419 file
#
# Truth:
#  The misprint provoked an immediate disclaimer
# Output:
#
# Batch Cost 58.64771270751953 after 420 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 61.230125427246094 after 421 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 56.59541702270508 after 422 file
#
# Truth:
#  The response of reaction is dominated by a concern for what is vanishing
# Output:
#
# Batch Cost 102.15028381347656 after 423 file
#
# Truth:
#  They used pink, tan, or cream powder
# Output:
#
# Batch Cost 78.17626953125 after 424 file
#
# Truth:
#  Now forget all this other
# Output:
#
# Batch Cost 52.731170654296875 after 425 file
#
# Truth:
#  The government sought authorization of his citizenship
# Output:
#
# Batch Cost 62.21553039550781 after 426 file
#
# Truth:
#  I ate every oyster on Nora's plate
# Output:
#
# Batch Cost 80.26734924316406 after 427 file
#
# Truth:
#  Did Shawn catch that big goose without help
# Output:
#
# Batch Cost 94.3949203491211 after 428 file
#
# Truth:
#  A toothpaste tube should be squeezed from the bottom
# Output:
#
# Batch Cost 89.897705078125 after 429 file
#
# Truth:
#  Eat your raisins outdoors on the porch steps
# Output:
#
# Batch Cost 78.03559112548828 after 430 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 59.221134185791016 after 431 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 55.160133361816406 after 432 file
#
# Truth:
#  Poets, moreover, dwell on human passions
# Output:
#
# Batch Cost 60.502384185791016 after 433 file
#
# Truth:
#  It was not exactly panic they gave way to, but they could not just sit there
# Output:
#
# Batch Cost 177.726806640625 after 434 file
#
# Truth:
#  We can die, too, we can die like real people
# Output:
#
# Batch Cost 109.05843353271484 after 435 file
#
# Truth:
#  The clumsy customer spilled some expensive perfume
# Output:
#
# Batch Cost 69.84310913085938 after 436 file
#
# Truth:
#  The viewpoint overlooked the ocean
# Output:
#
# Batch Cost 39.580692291259766 after 437 file
#
# Truth:
#  Please dig my potatoes up before frost
# Output:
#
# Batch Cost 70.92494201660156 after 438 file
#
# Truth:
#  I'd ride the subway, but I haven't enough change
# Output:
#
# Batch Cost 96.42180633544922 after 439 file
#
# Truth:
#  Grandmother outgrew her upbringing in petticoats
# Output:
#
# Batch Cost 61.61581039428711 after 440 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#
# Batch Cost 61.941532135009766 after 441 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 58.26667022705078 after 442 file
#
# Truth:
#  Transparent look, waxy skin -- could well be uremia
# Output:
#
# Batch Cost 90.76420593261719 after 443 file
#
# Truth:
#  At the left is a pair of dressy straw pumps in a light, but crisp texture
# Output:
#
# Batch Cost 143.32192993164062 after 444 file
# Truth:
#  Other interpretations present the music as an essentially intimate creation
# Output:
#
# Batch Cost 95.8914794921875 after 445 file
#
# Truth:
#  The mango and the papaya are in a bowl
# Output:
#
# Batch Cost 68.64957427978516 after 446 file
#
# Truth:
#  Do you hear the sleigh bells ringing
# Output:
#
# Batch Cost 72.27197265625 after 447 file
#
# Truth:
#  Did dad do academic bidding
# Output:
#
# Batch Cost 53.9168701171875 after 448 file
#
# Truth:
#  Rock-and-roll music has a great rhythm
# Output:
#
# Batch Cost 56.843326568603516 after 449 file
#
# Truth:
#  The giant redwoods shimmered in the glistening sun
# Output:
#
# Batch Cost 72.9007797241211 after 450 file
#
# Truth:
#  She had your dark suit in greasy wash water all year
# Output:
#  water
# Batch Cost 66.54557037353516 after 451 file
#
# Truth:
#  Don't ask me to carry an oily rag like that
# Output:
#
# Batch Cost 54.62837600708008 after 452 file
#
# Truth:
#  Solid concrete blocks, relatively heavy and dense, are used for this shelter
# Output:
#  water
# Batch Cost 121.37444305419922 after 453 file
#
# Truth:
#  After another long pause he asked, how many people know who they are
# Output:
#  water
# Batch Cost 142.48922729492188 after 454 file
#
# Truth:
#  Of course, dear, she said
# Output:
#
# Batch Cost 63.904117584228516 after 455 file
#
# Truth:
#  His scalp was blistered from today's hot sun
# Output:
#  water
# Batch Cost 84.96028137207031 after 456 file
#
# Truth:
#  Alimony harms a divorced man's wealth
# Output:
#
# Batch Cost 55.28828048706055 after 457 file
#
# Truth:
#  Norwegian sweaters are made of lamb's wool
# Output:
#
# Batch Cost 65.06163024902344 after 458 file
#
# Truth:
#  Brush fires are common in the dry underbrush of Nevada
# Output:
#
# Batch Cost 89.07707977294922 after 459 file
#
# Truth:
#  I just saw Jim near the new archeological museum
# Output:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-93fd337a0d5c> in <module>()
# ----> 1 train()
#
# <ipython-input-2-c01fbaa2750b> in train()
#     197                             print('Output:\n' + convert_to_sequence(sess.run(decoded[0].values,feed_dict=feed)))
#     198                             #print("Decoded Values: " ,sess.run(decoded[0].values,feed_dict=feed))
# --> 199                             train_ler += sess.run(label_error_rate, feed_dict=feed) * batch_size
#     200                             count_files+=1
#     201                             print("Batch Cost {0} after {1} file \n".format(batch_cost,count_files))
#
# c:\users\saloni dash\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\users\saloni dash\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# c:\users\saloni dash\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# c:\users\saloni dash\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# c:\users\saloni dash\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
