# %%
import tensorflow as tf
import time
import numpy as np
import os
import shutil
from numpy import matrix
from tensorflow.python.ops import ctc_ops as ctc
n_features=13
n_classes=63

#Hyperparameters
num_layers=1
n_hidden=300
batch_size=1
n_epochs=100

#Target log path
logs_path = '/tmp/tensorflow/timit_speech_recognition'

def variable_summaries(var):
    """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
    with tf.name_scope('summaries'):
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        with tf.name_scope('stddev'):
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
        tf.summary.scalar('stddev', stddev)
        tf.summary.scalar('max', tf.reduce_max(var))
        tf.summary.scalar('min', tf.reduce_min(var))
        tf.summary.histogram('histogram', var)

def sparse_tuple_from(sequences, dtype=np.int32):
    """Create a sparse representention of x.
    Args:
        sequences: a list of lists of type dtype where each element is a sequence
    Returns:
        A tuple with (indices, values, shape)
    """
    indices = []
    values = []

    for n, seq in enumerate(sequences):
        indices.extend(zip([n] * len(matrix(seq)), range(len(matrix(seq)))))
        values.extend([seq])

    indices = np.asarray(indices, dtype=np.int32)
    indices[:,[0, 1]] = indices[:,[1, 0]]
    values = np.asarray(values, dtype=dtype)
    shape = np.asarray([len(sequences), np.asarray(indices).max(0)[1] + 1], dtype=np.int32)

    return indices, values, shape


inputs = tf.placeholder(tf.float32,[None,None,n_features])
target_idx = tf.placeholder(tf.int64)
target_vals = tf.placeholder(tf.int32)
target_shape = tf.placeholder(tf.int64)
targets = tf.SparseTensor(target_idx, target_vals, target_shape)
seq_len = tf.placeholder(tf.int32)

# RNN output node weights and biases
weights = {
        'out': tf.Variable(tf.random_normal([n_hidden,n_classes]),dtype=tf.float32) # Weights_shape = hidden_units X vocab_size
    }
biases = {
        'out': tf.Variable(tf.random_normal([n_classes]),tf.float32)
        }
        
def LSTM_cell():
    cell = tf.contrib.rnn.BasicLSTMCell(n_hidden, reuse=tf.get_variable_scope().reuse)
    return tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=0.4)

def RNN_Model(inputs,seq_len,weights,biases):
    rnn_cell=LSTM_cell()
    #rnn_cell = tf.contrib.rnn.MultiRNNCell(LSTM_cell() for i in range(num_layers))
    outputs,_ = tf.nn.dynamic_rnn(rnn_cell,inputs,seq_len,dtype=tf.float32)
        
    outputs = tf.reshape(outputs,[-1,n_hidden])
    #print(outputs)
    logits = tf.matmul(outputs,weights['out']) + biases['out']
        
    with tf.name_scope('Weights'):
        variable_summaries(weights['out'])
    
    with tf.name_scope('Biases'):
        variable_summaries(biases['out'])
    
    with tf.name_scope('Activations'):
        tf.summary.histogram('Activations',logits)
        
    logits = tf.reshape(logits,[batch_size,-1,n_classes])
    logits = tf.transpose(logits,(1,0,2))
    return logits

logits=RNN_Model(inputs,seq_len,weights,biases)
loss = ctc.ctc_loss(targets,logits,seq_len)
with tf.name_scope("CTC_Loss"):
    cost = tf.reduce_mean(loss)
    tf.summary.scalar('CTC_Loss',cost)
        
optimizer = tf.train.MomentumOptimizer(learning_rate=0.005, momentum=0.9).minimize(cost)
decoded, log_prob = ctc.ctc_greedy_decoder(logits, seq_len)
        
label_error_rate = tf.reduce_mean(tf.edit_distance(tf.cast(decoded[0], tf.int32),
                                              targets)) 
#computes the Levenshtein distance between sequences.
#This operation takes variable-length sequences (hypothesis and truth), each provided as a SparseTensor, and computes the Levenshtein distance.
# You can normalize the edit distance by length of truth by setting normalize to true.
def convert_to_sequence(val, type='phn'):
    ''' convert the output into sequences of characters or phonemes
    '''
    phn = ['aa', 'ae', 'ah', 'ao', 'aw', 'ax', 'ax-h',
       'axr', 'ay', 'b', 'bcl', 'ch', 'd', 'dcl',
       'dh', 'dx', 'eh', 'el', 'em', 'en', 'eng',
       'epi', 'er', 'ey', 'f', 'g', 'gcl', 'h#',
       'hh', 'hv', 'ih', 'ix', 'iy', 'jh', 'k',
       'kcl', 'l', 'm', 'n', 'ng', 'nx', 'ow',
       'oy', 'p', 'pau', 'pcl', 'q', 'r', 's',
       'sh', 't', 'tcl', 'th', 'uh', 'uw', 'ux',
       'v', 'w', 'y', 'z', 'zh']
    #print(val)
    seq=[]
    for v in val:
        #print(v)
        if(v>=(len(phn))):
            pass
        else :
            seq.append(phn[v])
    seq=' '.join(seq)
    return seq
    
merged = tf.summary.merge_all()
writer = tf.summary.FileWriter(logs_path)
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
saver = tf.train.Saver(tf.global_variables())
init=tf.global_variables_initializer()

def train():
    with tf.Session(config=config) as sess:
            sess.run(init)
            writer.add_graph(sess.graph)
            
            mfcc_files = [os.path.join(root, name) for root, dirs, files in os.walk('mfccnpyFiles') for name in files
             if name.endswith((".npy"))]
            phoneme_labels=[os.path.join(root, name) for root, dirs, files in os.walk('phonemeLabels') for name in files
             if name.endswith((".npy"))]
            for curr_epoch in range(n_epochs):
                train_cost=train_ler=0
                count_files=0
                for file in mfcc_files:
                    count=0
                    mfcc_No_Suffix=os.path.splitext(file)[0]
                    mfcc_File_Name=mfcc_No_Suffix.split('\\')[-1]
                    for label in phoneme_labels:
                        phoneme_No_Suffix=os.path.splitext(label)[0]
                        phoneme_File_Name=phoneme_No_Suffix.split('\\')[-1]
                        if(mfcc_File_Name==phoneme_File_Name):
                            count+=1
                            train_inputs=np.load(".\\mfccnpyFiles\\"+mfcc_File_Name+'.npy')
                            train_inputs = np.asarray(train_inputs[np.newaxis, :])
                            train_inputs = (train_inputs - np.mean(train_inputs)) / np.std(train_inputs)
                            train_seq_len = [train_inputs.shape[1]]
                            
                            train_targets=np.load(".\\phonemeLabels\\"+phoneme_File_Name+'.npy')
                            target_index,target_values,target_shapes = sparse_tuple_from(train_targets)
                            feed = {inputs: train_inputs,target_idx:target_index,target_vals:target_values,target_shape:target_shapes,seq_len: train_seq_len}
                            summary,batch_cost, _ = sess.run([merged, cost, optimizer], feed)
                            writer.add_summary(summary, count_files)
                            
                            train_cost += batch_cost * batch_size
                            print('Truth:\n' + convert_to_sequence(train_targets, type='phn'))
                            print('Output:\n' + convert_to_sequence(sess.run(decoded[0].values,feed_dict=feed),type='phn'))
                            #print("Decoded Values: " ,sess.run(decoded[0].values,feed_dict=feed))
                            train_ler += sess.run(label_error_rate, feed_dict=feed) * batch_size
                            count_files+=1
                            print("Batch Cost {0} after file {1} \n".format(batch_cost,count_files))
                            if(count_files==6300):
                                train_cost=(train_cost/6300)
                                tf.summary.scalar('Train_Cost',cost)
                                writer.add_summary(summary, curr_epoch)
                            
                            
                        if(count>=1):
                            break
                
                print(" Train Cost: {0} in Epoch {1}".format((train_cost),curr_epoch))
                saver.save(sess,"./saver/model.ckpt")
                print("Model saved ")

# %%
train()
# Out:
# Truth:
# h# sh iy hv ae dcl d y axr dcl d aa r kcl k s ux tcl t q ix n gcl g r iy s iy w ao sh epi w ao dx axr q ao l y ih axr h#
# Output:
# dx iy hv dcl axr b hv iy hv b pau b hv iy aa b axr hv d b ow hv b y ih iy d b uh b ah d hv w hv ow uh hv b hv hv hv iy ao hv hv d uh hv b ao b hv hv ao hv
# Batch Cost 423.5744934082031 after file 1
#
# Truth:
# h# d ow n tcl t ae s kcl m iy tcl t ix kcl k ih r iy eh n oy l iy r ae gcl g l ay kcl k dh ae tcl h#
# Output:
#
# Batch Cost 898.9334716796875 after file 2
#
# Truth:
# h# b r ih kcl k s q aa r axr n ao l tcl t er nx ix tcl t ih v h#
# Output:
# k n er n ae hh r w eh m n h# n z zh r ch tcl ch ux n aa tcl aa n tcl n dh r eh k eh h# ch n w ae k epi eh ae h# n ae er n jh n tcl ch n tcl ch er l m r ih ey n ch pcl eh m k r
# Batch Cost 1298.345947265625 after file 3
#
# Truth:
# h# f ae tcl sh ow dcl d q ix n l uw s r ow l z bcl b ix n iy th ix sh er tcl h#
# Output:
# ow ey k
# Batch Cost 687.2442016601562 after file 4
#
# Truth:
# h# ix tcl s ah f axr z f r ax m ax l ae kcl k ix v y ux n ix tcl t iy ax v pcl p er pcl p ix s eh n r ix s pcl p eh kcl t f er hv axr r ow ix kcl k l iy dx axr sh ih pcl p h#
# Output:
# ae pcl aw ix kcl er jh ix sh ix ux ae l ow er ix zh kcl ix h# iy ix ow ix ae kcl ux aw iy pcl ix pcl ix ow er n pcl ow ix er ix ux ix zh ix kcl er ix h# sh er y ae ix ux l er pcl ix er ix uh kcl t sh ow n ow pcl er ix kcl uh z pcl
# Batch Cost 1942.03271484375 after file 5
#
# Truth:
# h# sh iy s epi l ih pcl t eh n s pcl p r ey n hv axr ae ng kcl k el q ao n dh ix s tcl t iy pcl p s l ow pcl p h#
# Output:
# pau zh ix dx ix kcl ix dh ix pcl ix iy ix dh ix t sh ae pcl ix ae nx ix sh ix dh ix aw ix dh aw zh ix dx ix dh ix dh ix ey ix ae ix kcl ix
# Batch Cost 904.04296875 after file 6
#
# Truth:
# h# q eh l uw m ih n ah m s ih l v uw w eh axr kcl k eh n q ao f ix n bcl b iy f l ih m z iy h#
# Output:
# pau f l pcl k y l y m dx ih bcl y ix k h# iy kcl dx y n tcl n bcl iy ix q nx f y q l nx y dx y dx iy l ax-h ng ix pcl ax-h m h# m k l dx ix ow ax n el ax-h iy y nx iy n iy n dcl ix f k m nx pcl t dcl ix h# ix aw ix ax-h ix ey ax epi l zh m
# Batch Cost 940.1292114257812 after file 7
#
# Truth:
# h# y ah ng tcl ch ih l dcl d r ix n sh uh dx ax v oy dcl d ix kcl k s pcl p ow zh axr tcl t ix kcl k ix n tcl t ey dcl jh ix s dcl d ix z iy z ix z h#
# Output:
# tcl h# ow ax aw n ix ih y m f n k dcl m ix pcl f y ax-h pcl ix k m hh zh ix ih ax-h m ix ax f n k ix pcl ix aw ix ax-h m ix dh k epi m l dx y ix zh ax ix pcl n ix r m ix kcl n ax-h s ax-h ix pcl q s dcl ow ih ix dx ix ow ix nx ix
# Batch Cost 877.67333984375 after file 8
#
# Truth:
# h# w eh dh axr pcl p r ux f gcl g ax l aa sh ix z axr v er r iy y ux s f ax l ih n s iy ae dx el h#
# Output:
# ix axr h# f dx ix s ix axr ix f ix f k f ix f ix f zh ix nx ix ax f ix f ih ix f m k ix pcl ix l f h# l ix f ix f ix ax-h ix dh ix l ix k ix kcl ix r ix ax f ix
# Batch Cost 799.62255859375 after file 9
#
# Truth:
# h# p ae m gcl g ih v s dcl d r ay v iy ng l eh s en z ao n th er z dcl d ey z h#
# Output:
# ow ax k s pcl dh m ng k m s m dcl m dcl pcl y m zh ch ih k er r f m dh s m zh m z er zh s m f m dcl l ax h# n m l k l el ix l sh zh l uw l m l s l s l sh l ch l ux ix k m ix z zh h# en l zh
# Batch Cost 991.3016357421875 after file 10
#
# Truth:
# h# sh iy hv eh dcl jh axr dcl d aa r kcl k s ux q ix n gcl g r iy s iy w ao sh epi w ao dx er q ao l y ih er h#
# Output:
# ih k zh l m q s dcl er s m l ax-h l dcl sh l s m l z uh l axr oy l n m uh s em d r s k l eh dcl m uh sh kcl iy zh l r zh l en m ih zh m l dcl k dcl epi l er l z axr l el s iy l aw en dcl uw l aw l
# Batch Cost 729.396728515625 after file 11
#
# Truth:
# h# d ow nx ae s kcl m iy tcl t ix kcl k ih r iy ix n q oy l iy r ae gcl g l ay kcl k dh ae tcl t h#
# Output:
# h# d s l dcl l en dcl l ux l sh l z l uw z l oy l k l dcl l h# l z l th l er sh n l k l er l er l sh l
# Batch Cost 497.9005432128906 after file 12
#
# Truth:
# h# q ax s ux m f ao r ix gcl z ae m pcl p uh l q ax s ix tcl ch uw ey sh en w eh axr f aa r m hv eh z ax pcl p ae kcl k iy ng sh eh dcl d pau q ae n dcl d f iy l dcl s h#
# Output:
# w nx d l dcl q l sh ux en r en ao l m l q dcl er l iy k ux dcl l ux eh l oy l ax l k l d er dcl ih l z l h# l z ux l r l dx h# l q k ux dcl l z l z l dcl l t l ux en z l ux h# ux l ux er
# Batch Cost 776.3574829101562 after file 13
#
# Truth:
# h# w ah dx aw q f ix tcl d uh sh iy dcl d r ay v f ao h#
# Output:
# h# f r ao h# dcl h# z ux w k ux z h# ux ao f ux d h# r en zh w ux h# z h# dcl h# eh z h# dcl z h# dcl en r sh r dcl sh h# ng h# z h# dcl ux d oy z pau d z h# r w d zh r d r ao t dcl r v h# d ao s z ng ux z r h# ao ux dcl h# z dcl er pau ux h# l
# Batch Cost 667.00439453125 after file 14
#
# Truth:
# h# f ih l s epi m ao l hv ow l q ix n bcl b ow l w ih th kcl k l ey h#
# Output:
# h# r h# uw h# w ux h# w ux h# dcl h# w h# ng ux h# q ch h# eh ux h# d h# r h# ao ux h# dh h# dcl h# dcl d q ao h#
# Batch Cost 441.5438232421875 after file 15
#
# Truth:
# h# p ax bcl b l ih s ix dx iy eh n ow dx axr r ay ix dx iy gcl g ow hv ae n dcl d ix n hv ae n dcl d h#
# Output:
# h# s h# q h# q h# ao h# w h# ao w h# ux h# zh h#
# Batch Cost 424.4291687011719 after file 16
#
# Truth:
# h# y ux ao l w ix z kcl k ax m ah pcl p w ix th pcl p ae th ax l aa dcl jh ix kcl k el ix gcl g z ae m pcl p el s h#
# Output:
# h# ux h# d h# ao h# d ux h# ux h# ux h# ux q h# ux h# dcl h# w ux h#
# Batch Cost 474.1841735839844 after file 17
#
# Truth:
# h# dh ow z ae n s axr z w el bcl b iy s tcl t r ey q f ao w axr dx ix f y ux th iy ng kcl k dh ix m th r uw kcl k eh r f el iy f er s tcl t h#
# Output:
# h# w h# w h# ux w h# d h# w h# h# ux h# ux h# w bcl h# ux h# th h# w h# ux iy ao h# ae w ao w h# m h# d h# w h# w h# q h#
# Batch Cost 488.64166259765625 after file 18
#
# Truth:
# h# w ih l s er v r uw bcl b aa r bcl p ay ae f tcl t axr r ey tcl ch el z tcl t ao kcl k h#
# Output:
# h# w h# ao h# w h# q d h# w h# s h# z s d h# h# h# w h# w h# w aa m w h# w h# h# w h# ao h# ng w h# n h# h# w eh h# w h# w eh w dx w ao h# uw h#
# Batch Cost 318.56915283203125 after file 19
#
# Truth:
# h# b ih bcl b l ih kcl k el s kcl k aa l er z pau q aa r gcl g y ux hv ih s tcl t r iy h#
# Output:
# w h# w h# d h# ao h# uw q h# w ae h# w h# s h# eh ow w h# ux w h# w h# w h# ux h# dx h# ix ao w h# m h# w h# h# h# w h# h# w h# h# pau h#
# Batch Cost 297.95025634765625 after file 20
#
# Truth:
# h# sh iy hv ae dcl jh axr dcl d aa r kcl k s ux tcl t q ih ng gcl g r iy s iy w ao sh epi w ao dx axr q ao l y ih axr h#
# Output:
# h# h# aa d h# ao h# ax h# ng q h# ow h# h# ow h# w h# h# ng h# h# h# q h# d h# h# h# t h# m h# hv h# eh ow d f ow
# Batch Cost 309.4309387207031 after file 21
#
# Truth:
# h# d ow n tcl t ax q ae s epi m ix tcl t ix kcl k eh r iy q ix n q oy l iy r ae gcl g l ay kcl dh ae tcl t h#
# Output:
# h# h# h# t h# s h# h# ix h# h# h# h# ix h# h# w h# ix h# ix h# h# ix h# w z h# h#
# Batch Cost 278.0931701660156 after file 22
#
# Truth:
# h# b ow th hv ae v q eh kcl k s el eh n ix nx ix gcl g r ey sh en ax dh axr f ih s kcl k el tcl t ae kcl s kcl k el eh kcl sh en y ih axr kcl k ae l ix n dcl d axr z h#
# Output:
# h# h# h# h# ih h# ux h# ix h# h# ix h# m h# h# h# ix h# d h# ih h# w h# ix h# ix h# w
# Batch Cost 327.511962890625 after file 23
#
# Truth:
# h# ix tcl t uh kcl k hh ih m ax l ao ng tcl t ay m tcl t ax-h kcl k em pcl p ow z em s epi eh l f h#
# Output:
# h# h# h# h# h# ih h# ng h# h# ae ix t h# ae ix ae ix h# ix ih h# m
# Batch Cost 244.74200439453125 after file 24
#
# Truth:
# h# hh iy l ay kcl t ix n ih pcl p q ih r l ow bcl b z ax v q ah n s ax s pcl p eh kcl t ix ng v ih z ix dcl d axr z w ix th ix z n iy dcl d el sh aa r pcl t iy th h#
# Output:
# m h# h# s h# h# ix h# q h# h# h# h# h# h# ae h# h# h# ae h# ix h# h# h# h# h# kcl h# ix h# h# h#
# Batch Cost 310.1119079589844 after file 25
#
# Truth:
# h# w ay q eh l s w uh dcl d ae n iy q ax l aw q ah dh axr z tcl t ix gcl g ow h#
# Output:
# h# h# h# h# h# h# h# h# h# ae h# ae h# ae h# ae h# h# ix h# ae h# h# h# h# h# h# h# h#
# Batch Cost 232.7384490966797 after file 26
#
# Truth:
# h# dh ix q ae ng gcl g r iy bcl b oy q ae n s axr dcl b ix tcl d ih dcl d en l uh kcl k q ah pcl h#
# Output:
# h# ae h# h# h# h# h# h# q h# h# h# bcl s h# ae bcl h# h# s h# q h# s h# h# h# h# h# h# h# h#
# Batch Cost 219.1282958984375 after file 27
#
# Truth:
# h# dh ih s w ah z q iy z iy f ao r q ah s h#
# Output:
# h# ae bcl h# h# h# h# h# tcl h# kcl h# h# h# h# ow h# h# ae h# h# h# h# h# h# ae h# h# h# h# h# h#
# Batch Cost 183.3027801513672 after file 28
# Truth:
# h# dh ix kcl k aw w aa n d axr dcl f ah m dh ax f aa r m l ae n dcl d ix n bcl b ix kcl k ey m l ao s tcl h#
# Output:
# h# h# h# h# h# ae h# q axr h# h# uh h# h# h# q h# h# h# h# h# h# r h# h# h# k h# h#
# Batch Cost 202.12957763671875 after file 29
#
# Truth:
# h# k ah tcl t ix s m ao l kcl k ao nx axr q ao f q iy tcl ch q eh dcl jh h#
# Output:
# h# h# h# dh h# h# h# r h# h# h# h# ae h# h# kcl h# h# h# h# h# h# h# h# h# ae
# Batch Cost 164.8043212890625 after file 30
#
# Truth:
# h# sh iy hv ae dcl d y er dcl d aa r kcl k s uw dx ih ng gcl g r iy s iy w aa sh epi w aa dx er q ao l y iy axr h#
# Output:
# h# h# h# ae h# h# h# h# ix h# h# h# h# h# h# h# h# h# h# h# h# h# h#
# Batch Cost 196.1984100341797 after file 31
#
# Truth:
# h# d ow n ae s epi m iy tcl t ix kcl k eh r iy ix n oy l iy r ae gcl g l ay kcl k dh ae tcl h#
# Output:
# h# l h# ae h# h# ae ae h# aa h# h# kcl h# h# h# h# ae h# h#
# Batch Cost 146.11187744140625 after file 32
#
# Truth:
# h# hh ih z kcl k ae pcl t ix n w ax s th ih n ae n hv ae gcl g er dcl d ix n ih z bcl b y ux dx ux f el bcl b uw tcl t s epi w axr w ao r n ix n epi sh ae bcl b iy h#
# Output:
# kcl h# ae l h# h# h# h# kcl h# h# kcl ae h# h# h# h# kcl h# kcl h# h# h# h# l h# q h#
# Batch Cost 320.55780029296875 after file 33
#
# Truth:
# h# dh ix r iy z ax n z f axr dh ih s dcl d ay v s iy m dcl d f uw l ix sh epi n aw h#
# Output:
# p h# ae h# h# h# h# h# h# h# dh h# h# kcl h# h# h# h# ow h# h# h# h# h# h# h# kcl
# Batch Cost 152.6990509033203 after file 34
#
# Truth:
# h# p axr dcl d ah kcl k sh ix n m ey f ao l f aa r bcl b ax l ow ax kcl k s pcl p ix kcl t ey sh en tcl s h#
# Output:
# h# h# kcl h# h# h# s h# h# h# h# h# h# l h# h# h# h# h# h# h# h#
# Batch Cost 179.4886932373047 after file 35
#
# Truth:
# h# p iy tcl s axr r iy ix z aa r kcl k ix n v iy n y ix n tcl f er ix kcl k w ih kcl k l ah n tcl ch h#
# Output:
# ix h# h# h# h# aa h# kcl kcl kcl h# ux kcl h# ae h# kcl h# h# kcl h# h# h# h#
# Batch Cost 175.90472412109375 after file 36
#
# Truth:
# h# p uh tcl dh ax bcl b uh tcl ch axr bcl b l aa kcl t ey bcl b el ax n dh ix gcl g er aa sh h#
# Output:
# h# dh h# q kcl kcl h# h# h# h# kcl kcl s h# h# h# kcl kcl kcl
# Batch Cost 144.4379119873047 after file 37
#
# Truth:
# h# d r aa pcl f ay v f ao r m z ax n dh ax bcl b aa kcl k s bcl b ax f ao r y ix gcl g ow aw tcl h#
# Output:
# kcl h# ae h# h# ae dh h# kcl h# kcl h# kcl ae h# kcl dh ix h# h# h# h# kcl h# kcl h# ae h#
# Batch Cost 171.03346252441406 after file 38
#
# Truth:
# h# hh er w ao r dcl d r ow bcl k en s ih s ax v ow n l iy s kcl k er tcl t s ax n bcl b l aw s ix q s h#
# Output:
# k h# ix ae ae r ix h# k kcl kcl h# kcl kcl kcl h# h# h# ey kcl q h# h#
# Batch Cost 189.55006408691406 after file 39
#
# Truth:
# h# q eh l dcl d er l iy pcl p iy pcl p el er aa f ix n ix q kcl k s kcl k l ux dcl d ix dcl d h#
# Output:
# h# h# h# h# h# h# h# kcl h# q
# Batch Cost 154.94456481933594 after file 40
#
# Truth:
# h# sh iy hv eh dcl d y er dcl d aa r kcl k s ux tcl q ix n gcl g r iy z iy w ao sh epi w ao dx er q ao l y ih er h#
# Output:
# kcl h# h# tcl h# h# kcl h# h# h# h# h# h# tcl h# h# m q q h# h# h# h# h# kcl tcl ae h# h# h#
# Batch Cost 189.41554260253906 after file 41
#
# Truth:
# h# d ow n q ae s kcl m iy tcl t ix kcl k eh r iy ix n q oy l iy r ae gcl g l ay kcl dh ae tcl t h#
# Output:
# h# h# q h# l h# ae h# kcl h# l h# s m kcl h# h# kcl h# h# q kcl ae kcl n s iy
# Batch Cost 149.5377197265625 after file 42
#
# Truth:
# h# pau dh eh n dh ix kcl k ao r iy aa gcl g axr f er m ah s tcl t q aa r bcl b ix tcl t r ey tcl t h#
# Output:
# dh q kcl h# l s dh n d h# s kcl q kcl s n ix iy q h# kcl h# s h# kcl uh iy h# tcl
# Batch Cost 152.62464904785156 after file 43
#
# Truth:
# h# t ux q ah dh er kcl k ey s ix z q ao l s ow w er q ah n dcl d er ix dcl v ay z m ix n tcl t h#
# Output:
# d s kcl kcl h# kcl q h# q h# kcl s n kcl q kcl h# q dh f kcl ae q q r kcl
# Batch Cost 155.55580139160156 after file 44
#
# Truth:
# h# dh ix s tcl t r ey tcl l ay n w ix dcl s ih m b ax l ay z ix tcl s y ux n iy kcl n eh s pau dh ix s er kcl k el ax v dcl jh y ux nx ax v er s ae l ax tcl t iy h#
# Output:
# ix r kcl tcl n iy kcl s kcl aa kcl s kcl s r kcl dh kcl s r kcl n h# ix s kcl h# kcl kcl kcl kcl ae kcl s ao kcl l kcl ix kcl
# Batch Cost 341.0469055175781 after file 45
#
# Truth:
# h# w uh dcl d ih tcl t aa m bcl b oy q ao f tcl t ix n pcl p l ey aw tcl d ao er z h#
# Output:
# q kcl ux ae h# s kcl h# q ix ae h# q r h# kcl tcl aa ix iy s q h# kcl s q r kcl h# aa n ae s kcl s iy q
# Batch Cost 157.8582305908203 after file 46
#
# Truth:
# h# jh aa n z bcl b r ah dh er r iy pcl p ey nx ix dcl dh ix gcl g axr aa dcl jh dcl d ao er h#
# Output:
# l iy ix h# iy kcl r tcl ae l h# l n kcl ix q q n tcl h# s l n iy iy h# h# z q s s q kcl k tcl h# l s kcl h# q
# Batch Cost 177.25308227539062 after file 47
#
# Truth:
# h# w ix y ux pcl p l iy z kcl k ix n f er m gcl g ah v ax m ix n tcl p aa l ax s iy r ix gcl g aa r dx iy ng w ey s tcl t r iy m uw v el h#
# Output:
# kcl kcl h# tcl s kcl aa n iy ix ix n ix d aa ix ix tcl ix ix kcl kcl dcl n kcl d kcl s n ix tcl ow kcl
# Batch Cost 244.5474090576172 after file 48
#
# Truth:
# h# b r ay tcl s ah n sh ay n sh ih m er z ao n dh iy y ow sh en h#
# Output:
# s ix t s ix kcl q k ux ix ix k s ix h# kcl h# l n ao r kcl n kcl ix iy iy kcl ix kcl ix ix s ix iy h# dh
# Batch Cost 166.6542205810547 after file 49
#
# Truth:
# h# m ae s kcl k axr r ey dcl p aa r dx iy z tcl t ae kcl s epi w ah n z ix m ae dcl jh ix n ey sh ix n h#
# Output:
# s aa h# kcl q tcl ae eng tcl m ix tcl aa ix s kcl iy kcl ix h# h# h# kcl h# iy l kcl ix h# r ix q ix q d kcl s h# iy
# Batch Cost 174.035888671875 after file 50
#
# Truth:
# h# sh iy hv eh dcl jh axr dcl d aa r kcl k s ux tcl t q ix ng gcl g r iy s iy w aa r sh epi w aa dx axr q ao l y ih er h#
# Output:
# n tcl iy h# h# n q l h# h# s h# iy kcl h# h# h# ix
# Batch Cost 181.69703674316406 after file 51
#
# Truth:
# h# d ow nx ae s kcl k m iy tcl t ix kcl k ih r iy ix n q oy l iy r ae gcl g l ay kcl dh ae tcl h#
# Output:
# ae h# ao h# h# ix l h#
# Batch Cost 135.7017059326172 after file 52
#
# Truth:
# h# k w ay dx ao f ax n hv ah n iy bcl b iy z f ao r m ax m ix dcl jh uh r ix dx iy aa n dh ax w ih l ow kcl k ae kcl k ix n s h#
# Output:
# r ih aa ix k eh h# h# iy ix iy aa h# h# iy d iy h#
# Batch Cost 199.61819458007812 after file 53
#
# Truth:
# h# l ay kcl k iy n ah f w ax l ao l bcl b iy ah pcl p ao n tcl t aa pcl p ay s ah n dcl d aw n h#
# Output:
# r kcl d iy tcl r iy kcl iy ix ix kcl l ae q iy
# Batch Cost 153.6956024169922 after file 54
#
# Truth:
# h# dh iy n y ux bcl b axr th ih z ix m iy dx iy ix q eh n ih n s tcl t ix n tcl t ey n iy ix s h#
# Output:
# l iy h# iy h# iy ix ix
# Batch Cost 149.48927307128906 after file 55
#
# Truth:
# h# iy w ao dx axr kcl k ix n tcl t ey n dcl t ux m ah tcl ch kcl k l ao r iy n q ix n s tcl t ah ng hv ix z ay z h#
# Output:
# kcl iy s iy
# Batch Cost 176.22161865234375 after file 56
#
# Truth:
# h# d uh z hh ih n d ux q ih dx iy aa l ix dcl jh iy q aa nx axr kcl k aw z h#
# Output:
# ux dcl iy aa ux l
# Batch Cost 123.13221740722656 after file 57
#
# Truth:
# h# g ah s ao pcl p ay n t r iy z ix n r eh dcl w uh dcl z q ao n hv ix z epi w ao kcl k th r ux s ix kcl k oy ix n ae sh en el f ao axr s tcl t h#
# Output:
# iy h# h# iy iy
# Batch Cost 245.134033203125 after file 58
#
# Truth:
# h# m uw v iy z n eh v axr hv ae v ix n ah f v ih l ax n s h#
# Output:
# iy iy iy r iy d h# h# h# iy ih n
# Batch Cost 122.72505187988281 after file 59
#
# Truth:
# h# ch ae l ix n jh iy tcl ch dcl jh uh nx axr el z ix n tcl t eh l ix dcl jh ix n tcl t s h#
# Output:
# ix ix h# h# ix h# ix iy
# Batch Cost 140.28782653808594 after file 60
#
# Truth:
# h# sh ix hv ae dcl jh uh dcl d aa r kcl s ux q ix n gcl g r iy s ix w ao sh epi w ao dx axr q ao l y ih axr h#
# Output:
# iy iy iy iy
# Batch Cost 159.7183380126953 after file 61
#
# Truth:
# h# d ow n q ae s kcl m ix tcl t ax-h kcl k ae r iy ix n q oy l ix r ae gcl ix l ay kcl dh ae q h#
# Output:
# iy n ix r h# iy n iy h# iy ix
# Batch Cost 134.42062377929688 after file 62
#
# Truth:
# h# n ow kcl k w eh sh tcl ch ix n v r ah f el z hh ih m q ow ax kcl k ao s ix s hv ih m tcl t ux hv eh z ix tcl t ey tcl h#
# Output:
# dcl n h# ix ix ix r
# Batch Cost 184.60443115234375 after file 63
#
# Truth:
# h# ih tcl w ix z q ao kcl k w ax dcl pau v eh r iy q ao kcl k w axr dcl h#
# Output:
# tcl n iy iy h#
# Batch Cost 116.26141357421875 after file 64
#
# Truth:
# h# w eh w iy l eh f epi w aa epi sh epi eng tcl t ix n hv ih s ah n tcl t ae dcl d epi w ih z q ih l q ae n m ix s ix z l ih ng kcl k eh n pau hh ix s tcl t eh r axr kcl k el h#
# Output:
# iy n iy l n ix ix bcl n ix iy iy iy
# Batch Cost 296.2237548828125 after file 65
# Truth:
# h# dh ey r iy m ey n dcl d epi l ay f l ah ng epi f r eh n dcl z q ae n kcl k em pcl p ae n y ix n tcl s h#
# Output:
# h# iy ix h# iy tcl k iy n iy ix
# Batch Cost 166.53427124023438 after file 66
#
# Truth:
# h# b ay q iy dcl d iy ng y ow gcl g er dcl pau y ux m ey l ih v l ao ng gcl g axr h#
# Output:
# ix h#
# Batch Cost 130.5674591064453 after file 67
#
# Truth:
# h# dh ix f r ay tcl en tcl ch ay l dcl w ix z dcl jh eh n tcl l iy s ah bcl d ux dcl d bcl b ay hv ix z bcl b ih gcl b r ah dh axr h#
# Output:
# iy ix
# Batch Cost 184.5084686279297 after file 68
#
# Truth:
# h# dh iy q ow v ax w ey tcl ch aa r m ax kcl k ux dcl d s epi l ih pcl p oy z ih n q ih n tcl t uw q eh n iy w ah n z tcl t iy h#
# Output:
# ao h# s l
# Batch Cost 197.25192260742188 after file 69
#
# Truth:
# h# k l ih f s dcl d ih s pcl p l ey epi w ah s epi m ix s pcl p l ey s tcl t q aa n dh ix s kcl k r iy n h#
# Output:
# z
# Batch Cost 166.9940948486328 after file 70
#
# Truth:
# h# sh iy hv ae dcl d y uh dcl d aa kcl k s ux tcl t pau ih n gcl g r iy s iy w ao sh epi w ao tcl t uh q ao l y ih ax h#
# Output:
# l ix
# Batch Cost 174.17164611816406 after file 71
#
# Truth:
# h# d ow n q ae s epi m iy tcl t ix kcl k eh r iy eh n ax q ao l iy r ae gcl g l ay kcl dh ae tcl h#
# Output:
# s iy tcl iy tcl s epi q iy jh tcl l iy ix iy ao iy r s h# r ay iy kcl iy th ao iy ao iy h# iy gcl t iy t
# Batch Cost 516.0584106445312 after file 72
#
# Truth:
# h# m ey bcl b iy tcl t uh dcl d ey y el bcl b iy ah gcl g uh dcl n ux z dcl d ey h#
# Output:
# h# z iy h#
# Batch Cost 131.87863159179688 after file 73
#
# Truth:
# h# sh iy s pcl p aw tcl t ih dcl d q ah m aw th epi f uh l ax v w ao tcl ah q ih n tcl t uh dh ah q ey axr h#
# Output:
# iy h# n
# Batch Cost 166.89739990234375 after file 74
#
# Truth:
# h# t ux m ih n iy n ux th ih ng z ah hv ae pcl p ax n iy ng f ao q ih tcl t ux bcl b iy q ey kcl k ax m pcl p l iy tcl t pau ih r aa dx ih kcl pau f uh l f ih l m ax n tcl t h#
# Output:
# iy tcl iy ao n q kcl iy
# Batch Cost 287.1207580566406 after file 75
#
# Truth:
# h# dh ah bcl b eh s tcl t pau w ey tcl t ax l er n pau ih z tcl t ax s ao l v q eh kcl k s tcl t r ax pcl p r aa bcl b l ax m s h#
# Output:
# dcl n
# Batch Cost 196.1486358642578 after file 76
#
# Truth:
# h# sh iy w ao w ao m pau f l iy s iy pau w uh l ah n pau ow v er ao l s h#
# Output:
# dcl
# Batch Cost 119.22906494140625 after file 77
#
# Truth:
# h# r ae l f kcl k ax n tcl t r ow l dcl dh ax s tcl t aa pcl p w aa tcl ch f r ah m dh ax bcl b l iy tcl ch uh z h#
# Output:
# iy
# Batch Cost 171.69070434570312 after file 78
#
# Truth:
# h# dh ih s bcl b r ow sh y uh ax q ih z pcl p ax tcl t ih kcl k uh l el dx iy q ih n f ao m ax tcl t iy v pau f ao q ey pcl p uh s pcl p eh kcl t iy v bcl b ay ah h#
# Output:
# tcl iy s tcl iy
# Batch Cost 271.0059814453125 after file 79
#
# Truth:
# h# w ay tcl ch aa r dcl jh epi m ah n iy f ao s ah tcl ch gcl g aa ax bcl b ix dcl jh h#
# Output:
# ao h# h# l iy h#
# Batch Cost 136.26324462890625 after file 80
#
# Truth:
# h# sh iy hv eh dcl jh axr dcl d aa r kcl k s ux tcl en gcl g r iy s iy w aa sh epi w ah dx axr aa l y ih axr h#
# Output:
#
# Batch Cost 159.2658233642578 after file 81
#
# Truth:
# h# d ow n q ae s epi m iy tcl t ix kcl k ih r iy ix n q ao l iy r ae gcl g l ay tcl dh ae tcl t h#
# Output:
# m ih iy ao s
# Batch Cost 136.02822875976562 after file 82
#
# Truth:
# h# s ux n dh iy q aa f ix s epi w er kcl k l ey m dcl d q aa l hh er tcl t aa m h#
# Output:
#
# Batch Cost 127.84890747070312 after file 83
#
# Truth:
# h# n eh kcl k s tcl t pau dh ix hv ih n w ax s epi n eh s tcl t ix dcl d ih n aa l s iy m dcl d w eh l h#
# Output:
# l n h# s
# Batch Cost 149.9639434814453 after file 84
#
# Truth:
# h# hh eh v iy q ih n dcl d ih s tcl t r iy s l ae n tcl t ix dcl t ao r dcl d q ix n ix gcl g z ao s tcl t ax-h bcl b el gcl g ah v ax m ix q kcl k ao f axr z pau ah tcl t r ae kcl t ix dcl d hh ix m h#
# Output:
# s ih iy iy t
# Batch Cost 323.5352478027344 after file 85
#
# Truth:
# h# aa r y er gcl g r ey dcl s hv ay axr q ao r l ow axr dh ix n ae n tcl t s iy s h#
# Output:
# aa s aa l ae iy iy iy l
# Batch Cost 144.40158081054688 after file 86
#
# Truth:
# h# p r aa dcl jh eh tcl d ax v eh l ax pcl m ah tcl t pau w ax z pcl p r ax s iy dx iy n tcl t ux s l ow l iy h#
# Output:
# eh ah
# Batch Cost 162.18313598632812 after file 87
#
# Truth:
# h# s er v dh ix kcl k ah l s l aw q ae f tcl t axr aa q ae dcl dh iy q ao l h#
# Output:
#
# Batch Cost 117.73724365234375 after file 88
#
# Truth:
# h# dh iy ow ey s ix s w ah z ax m er aa dcl jh h#
# Output:
#
# Batch Cost 90.46485900878906 after file 89
#
# Truth:
# h# dh eh tcl n oy z pcl p r aa bcl b l em gcl g r ow z epi m ao r en oy iy n iy tcl ch dcl d ey h#
# Output:
# l
# Batch Cost 152.2875213623047 after file 90
#
# Truth:
# h# sh iy hv ae dcl jh axr dcl d aa r kcl k s ux tcl t pau ih n gcl r iy s iy w aa sh epi w ao dx axr q ao l y ih axr h#
# Output:
#
# Batch Cost 165.05372619628906 after file 91
#
# Truth:
# h# d ow n ae s epi m iy dx ix kcl k eh r iy q eh n q ao l iy r ae gcl g l ay kcl dh ae tcl t h#
# Output:
# q ah
# Batch Cost 140.27195739746094 after file 92
#
# Truth:
# h# s eh v r ax l f ae kcl t axr s pau k ax n tcl t r ih bcl b ih tcl ih dcl d tcl t ix dh ih sh tcl ch ay n dcl jh h#
# Output:
#
# Batch Cost 163.80929565429688 after file 93
#
# Truth:
# h# sh iy gcl g r iy dx ih dcl d hh axr hv ah z bcl b en dcl d z kcl k aa l iy gcl g z epi w ix s m aa l ix ng pcl p el ay tcl n ih s pau q ao f r ih n ah th ih ng h#
# Output:
#
# Batch Cost 262.3037414550781 after file 94
#
# Truth:
# h# hh iy s ao ix pcl p ay eh tcl s ay z dcl m ae n pau w ix th ix gcl g r ay ih ng s pcl p ey dcl b ih er dcl d pau q ae nx ae n ah n y ux zh el iy l aa r dcl jh hh eh dcl d h#
# Output:
#
# Batch Cost 285.5196228027344 after file 95
#
# Truth:
# h# dh ih q eh m pcl p r ax hh ae dx ah m iy n tcl t eh m pcl p axr h#
# Output:
#
# Batch Cost 111.065673828125 after file 96
#
# Truth:
# h# hh aw pcl p er m n ah n tcl t pau q aa r dh eh r eh kcl k axr dcl d z h#
# Output:
# iy l iy m
# Batch Cost 119.8035659790039 after file 97
#
# Truth:
# h# dh ix m iy dx iy n ih z n aw ax dcl jh er n dcl d h#
# Output:
# iy
# Batch Cost 99.87648010253906 after file 98
#
# Truth:
# h# k r ih dx ih kcl k ax l q ah kcl k w ih pcl m ih n tcl n iy dcl d z pcl p r aa pcl p axr m ay n tcl n ah n tcl s h#
# Output:
# n q iy r ey q tcl iy axr tcl
# Batch Cost 171.3289031982422 after file 99
#
# Truth:
# h# t ih m tcl t ey kcl k sh iy l ah tcl t ix s iy m ux v iy z tcl t w ay s ax w iy kcl k h#
# Output:
#
# Batch Cost 132.48471069335938 after file 100
#
# Truth:
# h# sh iy hv ae dcl d y axr dcl d aa r kcl k s ux tcl q ix ng gcl g r iy s iy w aa sh epi w aa dx axr q ao l y ih axr h#
# Output:
# iy iy
# Batch Cost 173.6688232421875 after file 101
#
# Truth:
# h# d ow n q ae s epi m iy tcl t ux kcl k eh r iy q eh n q oy l iy r ae gcl g l ay kcl dh ae q h#
# Output:
# n
# Batch Cost 142.0393829345703 after file 102
#
# Truth:
# h# dh ey v n eh v axr m eh tcl pau y ix n ow h#
# Output:
#
# Batch Cost 87.41136169433594 after file 103
#
# Truth:
# h# t w eh n tcl t iy tcl t ux ao r tcl t w eh n tcl t iy th r iy h#
# Output:
#
# Batch Cost 97.0979232788086 after file 104
#
# Truth:
# h# t eh q n ih s kcl k ih dcl b iy ah v oy dx ih dcl b ay pcl p ao r ix ng w ao r m tcl t er pcl p ix n tcl t ay n q ow v er ax w ux n dcl d h#
# Output:
# r
# Batch Cost 228.37757873535156 after file 105
#
# Truth:
# h# dh ax tcl t r ae ah m f ih n q w ao r iy er q ix gcl z ih v ix dx ih dcl pau n ay iy v hh ih r ow ix z em h#
# Output:
# l
# Batch Cost 170.0622100830078 after file 106
#
# Truth:
# h# k ae n dh iy ey dcl jh ih n s iy q ow v axr th r ow q ey l iy ix n f ao r s ih z h#
# Output:
#
# Batch Cost 130.08978271484375 after file 107
#
# Truth:
# h# ix kcl k ao r dx iy n tcl t ax m ay ix n tcl t er v axr tcl t ey sh en ah dh ax pcl p r aa bcl b l ax m pau t ux l ay n z m ah s bcl b iy pcl p er pcl p ix n dcl d ih kcl k y ix l axr h#
# Output:
# h#
# Batch Cost 346.97174072265625 after file 108
#
# Truth:
# h# s ix bcl b er v ih n hv aw s epi w ay z ao f ix n s ah f axr f r ax m dh ix gcl g ae bcl hv ae bcl b ih tcl h#
# Output:
# n
# Batch Cost 173.3369598388672 after file 109
#
# Truth:
# h# g uh dcl s er v ih sh ih dcl b iy r iy w ao r dx ih dcl b ay bcl b ih gcl t ih pcl s h#
# Output:
# n
# Batch Cost 137.23167419433594 after file 110
#
# Truth:
# h# s iy hv ae dcl jh er dcl d aa r kcl k s ux tcl ix ng gcl g r iy s iy w ao sh epi w ao dx axr q ao l y iy axr h#
# Output:
# m m n r
# Batch Cost 172.3477783203125 after file 111
# Truth:
# h# d ow q ae s kcl k m iy tcl t ix kcl k ih r iy ix nx oy l iy r ae gcl g l ay kcl dh ae tcl t h#
# Output:
# h#
# Batch Cost 140.30453491210938 after file 112
#
# Truth:
# h# y axr v oy s ix z dcl d ax l ay tcl f el hh iy ix pcl p r ux v dcl d w ix dh ax w ao r m s m ay l h#
# Output:
# h#
# Batch Cost 165.18353271484375 after file 113
#
# Truth:
# h# t er bcl b y ih l eh n tcl t ay dcl d z r ow z ax z epi m ah tcl ch ix z f ih f tcl t iy f iy tcl t h#
# Output:
#
# Batch Cost 162.11134338378906 after file 114
#
# Truth:
# h# s ah m tcl t ay m z epi s ow dcl jh er z epi r ow q l ae dx er z epi w aa l bcl b uh l ih tcl s epi w axr w ih z ix n ah bcl b aw tcl dh eh r hh eh dcl d z h#
# Output:
# iy ao m n m s
# Batch Cost 244.47000122070312 after file 115
#
# Truth:
# h# s ih kcl k l ax kcl k ow pcl p r ow gcl er m z w el n eh v axr kcl k ax m pcl p ay l h#
# Output:
#
# Batch Cost 142.0706787109375 after file 116
#
# Truth:
# h# k l ih r pcl p r ax n ah n tcl s ih ey sh ix n eh z ix pcl p r ix sh ix ey dx ix dcl h#
# Output:
# tcl
# Batch Cost 127.88707733154297 after file 117
#
# Truth:
# h# s tcl t iy v kcl k ax l eh kcl k s epi r eh er q eh n aa v el kcl k oy n epi s h#
# Output:
# n
# Batch Cost 125.72230529785156 after file 118
#
# Truth:
# h# q ey hh y ux dcl jh pcl p aw er q aw dx ix dcl jh r eh l iy q ix kcl k er s h#
# Output:
#
# Batch Cost 124.4011001586914 after file 119
#
# Truth:
# h# q ae kcl k ix dcl d ae m ih kcl k q ae pcl t ax-h tcl t ux dcl d gcl g eh er ix n tcl t iy z y axr dcl d ix pcl p l ow m ah h#
# Output:
#
# Batch Cost 199.52357482910156 after file 120
#
# Truth:
# h# sh iy hv ae dcl jh axr dcl d aa r kcl k s ux tcl t q ix ng gcl g r iy s iy w aa sh epi w ao dx er q ao l y ih er h#
# Output:
#
# Batch Cost 174.7841033935547 after file 121
#
# Truth:
# h# d ow n q ae s epi m iy tcl t ax-h kcl k eh r iy ix n oy l iy r ae gcl l ay kcl dh ae tcl h#
# Output:
#
# Batch Cost 130.46177673339844 after file 122
#
# Truth:
# h# q aw tcl s ay dcl d ax q ow n l iy ix hv ae n f el ax v axr pcl p ao r dx axr z r ix m ey n dcl d h#
# Output:
# kcl ix iy
# Batch Cost 154.4416961669922 after file 123
#
# Truth:
# h# n ae tcl ch axr l iy kcl k er l iy hh eh axr r ah n z ix n m ay f aa m l iy h#
# Output:
#
# Batch Cost 118.88742065429688 after file 124
#
# Truth:
# h# q ih n t axr dcl d ih sh ix n eh nx ix m pcl p ow ix tcl t r iy pau dh ix m eh r ih dcl jh bcl b eh dcl q ih z ax pcl p l ey s ix v y ux n ih tcl t iy pau ix n hh aa r m ax n iy h#
# Output:
# ix
# Batch Cost 281.228271484375 after file 125
#
# Truth:
# h# t ah gcl b ow tcl t s q axr kcl k ey pcl ax bcl b el q ax v hh ao l iy ng hh y ux dcl jh l ow dcl d z h#
# Output:
# n
# Batch Cost 162.90789794921875 after file 126
#
# Truth:
# h# hh aa m uh tcl ch ax l aw ix n s tcl t ux y ux gcl g eh tcl h#
# Output:
# n
# Batch Cost 121.73878479003906 after file 127
#
# Truth:
# h# w eh nx ao l eh l s f ey l z pau y ux z f ao r s h#
# Output:
# iy
# Batch Cost 110.98789978027344 after file 128
#
# Truth:
# h# dh iy z ih kcl k s kcl k l uw s ix v dcl d aa kcl k ix m eh n tcl s epi m ah s bcl b iy l aa kcl d ah pcl q eh dx ao l tcl t ay m z h#
# Output:
#
# Batch Cost 195.70127868652344 after file 129
#
# Truth:
# h# dcl jh ao r dcl jh ih z pcl p eh er n oy dcl d q ax bcl b aw dx ax f ux tcl ch axr gcl g ae sh ao r dx ih dcl jh h#
# Output:
#
# Batch Cost 170.09913635253906 after file 130
#
# Truth:
# h# sh iy hv eh dcl jh er dcl d aa r kcl k s ux tcl t q ix ng gcl g r iy s ix w aa r sh epi w aa dx axr q aa l y ih axr h#
# Output:
# n p iy iy
# Batch Cost 177.3646697998047 after file 131
#
# Truth:
# h# d ow n ae s kcl m iy tcl t ux kcl k eh r iy q eh n oy ax l iy r ae gcl g l ay kcl k dh ae q h#
# Output:
# iy h#
# Batch Cost 142.25009155273438 after file 132
#
# Truth:
# h# r eh dcl d iy n ih s eh kcl s axr s ay z ix z q aa r aa l m uh s tcl t kcl k ix n tcl t ix n y ux ix s h#
# Output:
#
# Batch Cost 157.25758361816406 after file 133
#
# Truth:
# h# s ah m epi th ix ng eh l s dcl z ax-h s tcl t r ae kcl t ih dcl d hv ih m pau hh y eh tcl dh ix w ix z epi n ow s aw n dcl d q ow n l iy tcl t ux m l ay kcl k s ay l en tcl t s h#
# Output:
#
# Batch Cost 286.01617431640625 after file 134
#
# Truth:
# h# d ow n tcl dh ey s tcl t ih l kcl k aa l y ux dcl jh ux n y er q eh z epi dh ow y er bcl b ah tcl t ih n y ih r z ow l dcl d h#
# Output:
#
# Batch Cost 197.5242156982422 after file 135
#
# Truth:
# h# dh ih dcl d r ah ng kcl k axr dcl d ih z ah s ow sh ix l q aw tcl k ae s tcl t h#
# Output:
# s n n n l iy ae h# ey l iy
# Batch Cost 174.0326385498047 after file 136
#
# Truth:
# h# r iy dx iy ng ih n pcl p ao r l ay tcl t gcl g ih v zh ux q ay s tcl t r ey n h#
# Output:
# l
# Batch Cost 131.2321319580078 after file 137
#
# Truth:
# h# dh ax dcl d aa r kcl k pau m er kcl k iy l ix gcl g ux n w aw n dcl d ah r aw n dcl d f ao r m ay l epi s h#
# Output:
# n eh dcl h# iy n ix iy r iy r ix iy tcl r tcl p ey ae iy tcl iy p q ix iy ix n
# Batch Cost 218.78187561035156 after file 138
#
# Truth:
# h# q ey kcl k r ae bcl ch ae l ax n dcl jh dcl d epi m iy pau b eh dx ix kcl k w ih kcl k s tcl t ae bcl b v ae ng kcl k w ix sh tcl t hh ih m h#
# Output:
#
# Batch Cost 214.6292724609375 after file 139
#
# Truth:
# h# q ah pcl g r ey dcl jh axr s tcl t ey dcl d ix s tcl t ux r ix f l eh kcl ch ih r w eh l th h#
# Output:
# iy
# Batch Cost 141.2494354248047 after file 140
#
# Truth:
# h# sh iy hv ae dcl jh er dcl d aa r kcl k s ux tcl q ih n g r iy s iy w ao sh epi w ao dx axr q ao l y ih er h#
# Output:
# n
# Batch Cost 169.1934051513672 after file 141
#
# Truth:
# h# d ow n q ae s kcl k m iy dcl d ih kcl k eh r iy ix n q oy l ih r ae gcl g l ay kcl dh ae tcl h#
# Output:
# w q y ae ey iy r h#
# Batch Cost 148.70089721679688 after file 142
#
# Truth:
# h# w iy s kcl k aw axr l ih dx axr tcl ch er f ix dh eh m pau hh ih r w iy f ay n dcl s tcl t ao r dcl dh ix w ih z dcl d ax m ax v gcl g r ey tcl m ay n dcl z h#
# Output:
# n w n ae tcl tcl
# Batch Cost 250.01840209960938 after file 143
#
# Truth:
# h# w iy hv eh v bcl b eh dx axr r ux m z v ey kcl k ix n q n aw hv iy bcl b ae bcl b el dcl d h#
# Output:
# n
# Batch Cost 147.81817626953125 after file 144
#
# Truth:
# h# w iy f l uw w ih n ax r ih kcl k ix dx iy pcl p l ey n s ow q ow v axr l ow dx ih dcl dh eh q w ih w ah n dcl d axr dcl w ay dh ey dcl d ih dcl en tcl k r ae sh h#
# Output:
# n
# Batch Cost 250.77926635742188 after file 145
#
# Truth:
# h# s ay kcl k l ih kcl k el pcl p r ow gcl g r ae m z w el n eh v axr kcl k em pcl p ay l h#
# Output:
#
# Batch Cost 143.116943359375 after file 146
#
# Truth:
# h# k l ih r pcl p axr n ah n s iy ey sh ix n q ih z ax pcl p r iy sh iy ey dx ix dcl d h#
# Output:
# iy h#
# Batch Cost 136.2108612060547 after file 147
#
# Truth:
# h# s tcl t iy v kcl k ax l eh kcl k s r eh r q ix n aa v el kcl k oy n s h#
# Output:
# dcl
# Batch Cost 119.07576751708984 after file 148
#
# Truth:
# h# ax hv y ux dcl jh pcl p aw axr q aw dx ix dcl jh r eh r l iy ix kcl k er z h#
# Output:
# k h# kcl
# Batch Cost 124.17355346679688 after file 149
#
# Truth:
# h# q ae kcl k ix dcl d eh m ih kcl k q ae pcl t ix tcl t ux dcl g eh r ix n tcl t iy zh axr dcl d ix pcl p l ow m ax h#
# Output:
# l
# Batch Cost 166.8545684814453 after file 150
#
# Truth:
# h# sh iy hv ae dcl d q y ao r dcl d aa r kcl k s ux tcl t q ih eng g r iy z iy w ao sh epi w ao dx er epi ao l y ih er h#
# Output:
# kcl
# Batch Cost 184.84033203125 after file 151
#
# Truth:
# h# d ow nx ae s kcl m iy dx ix kcl k eh r iy ix n ao l ix r ae gcl g l ay kcl dh ae tcl t h#
# Output:
#
# Batch Cost 128.64866638183594 after file 152
#
# Truth:
# h# ax f r ey dcl d ix epi y uh l uw z epi y ao r dcl jh aa bcl b q ih f y ux dcl d ow n tcl k iy pcl p y ao r m aw th sh ah tcl t h#
# Output:
#
# Batch Cost 209.18125915527344 after file 153
#
# Truth:
# h# s ah m ax bcl b z er v axr s pcl p eh kcl k y ix l ey dx ix dcl dh ix tcl dh ih s epi m ay tcl t bcl b iy hv ih z axr v ih n dcl jh aa n ih z hv ow m tcl t aw n h#
# Output:
#
# Batch Cost 259.5437927246094 after file 154
#
# Truth:
# h# p uh sh pau bcl b ae kcl k ah pcl p q ix n r ix pcl p iy tcl t h#
# Output:
#
# Batch Cost 105.07659149169922 after file 155
#
# Truth:
# h# q aw axr kcl k s pcl p ih r ix m eh n tcl s pau p aa z ix dx ix v aw tcl k ah m pau w ax z ah nx ix kcl s pcl p eh kcl t ix dcl h#
# Output:
#
# Batch Cost 190.5313720703125 after file 156
#
# Truth:
# h# hh aw ey n sh ix n tcl q ih z epi dh ih s ah bcl b w ey eh s kcl k y ix l ey dx axr h#
# Output:
#
# Batch Cost 134.75405883789062 after file 157
#
# Truth:
# h# r aa bcl b epi m ey dcl d hv ah eng gcl g eh r ih ix n gcl g uw l aa sh f ax dcl d ih nx er pau q ix ng gcl g ux s bcl b eh r ih pcl p ay f ao dcl d ix z er tcl t h#
# Output:
# m h# bcl ey r iy r iy m r ae r ao r iy ih
# Batch Cost 332.39892578125 after file 158
# Truth:
# h# q ax m ao th z ih gcl g z ae gcl d ax l ao ng dh ax pcl p ae th r uw q ao t ow z gcl aa r dx en h#
# Output:
# h# ih aa h# h# h#
# Batch Cost 181.06216430664062 after file 159
#
# Truth:
# h# w iy gcl g aa tcl dcl d r eh n tcl ch tcl t f r ax m dh ih q ah nx ix nx ix r ah pcl t ix dcl r ey n h#
# Output:
#
# Batch Cost 158.28225708007812 after file 160
#
# Truth:
# h# sh ix hv ae dcl y axr dcl d aa r kcl k s ux tcl en gcl g r iy z ix w aa sh epi w ao dx axr q ao l y ix axr h#
# Output:
#
# Batch Cost 159.5186767578125 after file 161
#
# Truth:
# h# d ow nx ae s epi m ix dx ix kcl k eh r iy ix n ao l iy r ae gcl g l ay kcl dh ae tcl h#
# Output:
#
# Batch Cost 127.3191909790039 after file 162
#
# Truth:
# h# b aa dh ax l uh kcl k ah v ih m hv ix w ah z ix n tcl dh ae tcl f aa r gcl g ao n h#
# Output:
# h#
# Batch Cost 132.72642517089844 after file 163
#
# Truth:
# h# w axr y ux ix n l ah v w ax th ae tcl g er el h#
# Output:
# n
# Batch Cost 88.77705383300781 after file 164
#
# Truth:
# h# hh ih r dh eh dx ih dcl n aa tcl n iy dcl t ix bcl b iy eng gcl g eh dx ow z h#
# Output:
#
# Batch Cost 114.89007568359375 after file 165
#
# Truth:
# h# s kcl k ax l ae s tcl t ix kcl k ae pcl t ix tcl t ux dx ix z dcl jh ah dcl jh dcl b ay s tcl t ae n axr dx ay z dcl t eh s h#
# Output:
# tcl
# Batch Cost 186.38938903808594 after file 166
#
# Truth:
# h# dh ey ao l ax gcl g r iy dh ix tcl dh ix eh s ey ih z bcl b eh r l iy ix n tcl t eh l ax dcl jh ix bcl b el h#
# Output:
#
# Batch Cost 174.0290985107422 after file 167
#
# Truth:
# h# eh n ih dcl d ah l tcl m ey l bcl b ae bcl b uw n z tcl t iy th q aa r n aa q s ux dx ix bcl b el f axr q iy dx ix ng sh eh l f ih sh h#
# Output:
#
# Batch Cost 233.92410278320312 after file 168
#
# Truth:
# h# s m ae sh l ay tcl b ah bcl b z ax n dh axr kcl k ae sh v ae y ux w el dcl d ax m ih nx ih sh tcl t ix n ah th ix ng h#
# Output:
#
# Batch Cost 183.37547302246094 after file 169
#
# Truth:
# h# k aa q n eh nx el dcl d r ih f tcl t q ix z ix dcl jh iy ix l aa dcl jh ix kcl k el th iy axr ix h#
# Output:
# ix ae
# Batch Cost 143.09454345703125 after file 170
#
# Truth:
# h# sh iy hv ae dcl jh axr dcl d aa r kcl k s ux tcl t q ix n gcl g r iy s iy w aa sh epi w ao dx axr q ao l y ih axr h#
# Output:
# h#
# Batch Cost 168.31729125976562 after file 171
#
# Truth:
# h# d ow n ae s epi m iy dx ix kcl k eh r iy ix n q oy l iy r ae gcl g l ay kcl dh ae tcl h#
# Output:
# n ix
# Batch Cost 131.32196044921875 after file 172
#
# Truth:
# h# hh ih v ux gcl g aa dx ih nx ah f bcl b l ae ng kcl k ix tcl t s h#
# Output:
#
# Batch Cost 114.27799224853516 after file 173
#
# Truth:
# h# ih dx eh dcl g ao n l ay kcl k l aa kcl k w er kcl k h#
# Output:
#
# Batch Cost 99.0832290649414 after file 174
#
# Truth:
# h# w uh dx ix kcl k ae m r ax kcl k l ah bcl b iy y ux s f ax l ax n tcl t ey kcl k ix ng pcl p ih tcl ch axr z pcl p er q n ih n tcl t ax-h pcl p l ae n tcl t s ey f tcl t iy h#
# Output:
#
# Batch Cost 269.3316345214844 after file 175
#
# Truth:
# h# q ae n gcl g ao axr kcl k ae tcl s axr f er iy axr dh ix n s ay ix m iy z h#
# Output:
# ae
# Batch Cost 120.93619537353516 after file 176
#
# Truth:
# h# n aa n pcl p r aa f ax dx ao r gcl g ix n ix z ey sh en z hh ae v f r iy kcl k w ix n tcl t f ah n d r ey z axr z h#
# Output:
#
# Batch Cost 192.8963165283203 after file 177
#
# Truth:
# h# dh ax pcl p r uw f ix tcl jh ux aa r s iy kcl k iy ng q ih z epi n aa tcl q ax v ey l bcl b el q ih n bcl b uh kcl k s h#
# Output:
#
# Batch Cost 184.4965057373047 after file 178
#
# Truth:
# h# b aa r bcl b z gcl g ow l dcl b r ey s epi l ix tcl w ax z ix gcl g r ae dcl jh uw ey sh en pcl p r eh z ax n tcl h#
# Output:
#
# Batch Cost 172.64610290527344 after file 179
#
# Truth:
# h# dh ey ix s uw m n ow bcl b er gcl g l er w el q eh v er q eh n tcl t axr hv ih axr h#
# Output:
#
# Batch Cost 141.63784790039062 after file 180
#
# Truth:
# h# sh iy hv ae dcl jh axr dcl d aa r kcl k s ux q en gcl g r iy z iy w aa sh epi w ao dx axr q ao l y ix axr h#
# Output:
# h#
# Batch Cost 164.37020874023438 after file 181
#
# Truth:
# h# d ow n ae s kcl m iy tcl t ix kcl k ih r iy ix n q oy l iy r ae gcl g l ay kcl dh ae tcl h#
# Output:
# h#
# Batch Cost 133.93521118164062 after file 182
#
# Truth:
# h# ih n w ah q w ey z dh eh n dcl d ih dcl dh ix pcl p ey sh ih n tcl s ay kcl k ix kcl k el bcl b l ay n ih s epi m ae nx ax f eh s tcl t ix tcl s eh l f h#
# Output:
#
# Batch Cost 230.860107421875 after file 183
#
# Truth:
# h# ix w uh dcl b iy ih kcl k el aa s el sh ey m dcl d ih th r ow w ey ix s tcl t ao r iy l ay kcl dh ih s h#
# Output:
# ae
# Batch Cost 159.66461181640625 after file 184
#
# Truth:
# h# l eh dx ao l pcl p r aa dcl jh eh kcl k s dcl d r ay s l ow l iy f axr s eh v r el dcl d ey z h#
# Output:
#
# Batch Cost 148.9933624267578 after file 185
#
# Truth:
# h# dh ix s aw n d uh v dcl jh ih nx ih f axr z bcl b y ux gcl g el s kcl k eh er dcl dh ah q ae nx el ow pcl h#
# Output:
# tcl
# Batch Cost 168.47567749023438 after file 186
#
# Truth:
# h# hh ay w ey ih n f r iy w ey m iy n dh ix s ey m epi th ih ng h#
# Output:
#
# Batch Cost 106.70330047607422 after file 187
#
# Truth:
# h# dh ix f ao gcl p axr v ih nx ih dcl dh eh m f r em axr r ay v ih ng aa n tcl t ay m h#
# Output:
# ae h# ix r
# Batch Cost 135.69728088378906 after file 188
#
# Truth:
# h# d ae f epi n iy s epi w iy dx ih sh epi n iy dx el pcl p oy n tcl s kcl k aa r f epi m ae tcl ch dcl jh axr s kcl k er tcl t h#
# Output:
#
# Batch Cost 183.38613891601562 after file 189
#
# Truth:
# h# q iy v ix nx ih s ih m pcl p el v ix kcl k ae bcl b y el eh r iy kcl k ih n tcl t ey n s ih m bcl b el z h#
# Output:
#
# Batch Cost 165.0123291015625 after file 190
#
# Truth:
# h# sh iy hv ae dcl jh axr dcl d aa r kcl k s ux tcl t q ih ng gcl g r iy s ix w aa sh epi w aa dx axr q aa l y ih axr h#
# Output:
# iy
# Batch Cost 170.19015502929688 after file 191
#
# Truth:
# h# d ow nx ae s kcl m ix dx ix kcl k eh r iy ix n q oy l iy r ae gcl g l ay kcl k dh ae tcl t h#
# Output:
#
# Batch Cost 136.83349609375 after file 192
#
# Truth:
# h# dh ix r iy v ay z dcl p r ix s iy dcl jh axr w ah z ix kcl k l ey m dcl d q eh z ix l ao ng q ow v axr dcl d ux r ix f ao r m h#
# Output:
#
# Batch Cost 196.484619140625 after file 193
#
# Truth:
# h# hh iy hv eh l dcl d ih z q aa r m z kcl k l ow s tcl t ux ix s ay dcl z q ix m ey dcl hv ix m s eh l f q eh s epi m ao l ix z pcl p aa s ax bcl b el h#
# Output:
# tcl
# Batch Cost 234.94882202148438 after file 194
#
# Truth:
# h# w ah ng kcl k ih dcl hv ih r er v eh r ih f ey n tcl pau l ey dx iy l ay kcl k s ay ix v r iy l iy f h#
# Output:
#
# Batch Cost 156.87046813964844 after file 195
#
# Truth:
# h# t r ix dcl d ih sh ax n r ix kcl k w aa er z pcl p axr eh n tcl t el ah pcl p r uw v el f axr q ah n dcl d axr ey dcl jh epi m eh r ix dcl jh h#
# Output:
#
# Batch Cost 207.40704345703125 after file 196
#
# Truth:
# h# q ih tcl s hv eh l th iy axr dcl d ix kcl k uh kcl k w ix th aw tcl sh uh gcl g axr h#
# Output:
# iy
# Batch Cost 136.99916076660156 after file 197
#
# Truth:
# h# dh ix kcl k r ae m bcl b eh r ix bcl b ao gcl g ix tcl s v er iy pcl p r ix dx iy ix n q ao dcl d ah m h#
# Output:
#
# Batch Cost 154.0316619873047 after file 198
#
# Truth:
# h# l ae f dcl d ae n tcl s q ix n tcl s ih ng ih f ao r tcl ch ix n s epi m aa l z ax pcl p ao n y ux h#
# Output:
# ix
# Batch Cost 154.5790557861328 after file 199
#
# Truth:
# h# m aa m s tcl t r ao ng l iy dcl d ix s epi l ay kcl k s q ae pcl p ix tcl t ay z axr z h#
# Output:
#
# Batch Cost 138.46852111816406 after file 200
#
# Truth:
# h# sh iy hv ae dcl y axr dcl d aa kcl k s uw tcl t q ix n gcl g r iy s iy w aa sh w ao dx ax q ao l y ih er h#
# Output:
# r ix
# Batch Cost 163.7266387939453 after file 201
#
# Truth:
# h# d ow n tcl ae kcl s epi m iy tcl t uw kcl k ae r iy q eh n ax q ao l iy r ae gcl g l ay kcl dh ae tcl h#
# Output:
#
# Batch Cost 147.823974609375 after file 202
#
# Truth:
# h# k w eh sh tcl ch ax n z kcl k ey m tcl t uw m iy f ax m q ao l s ay z ax bcl b aw q m ay w er s ih dx ix z ix n sh ix pcl q ae kcl t ih v ix dx iy s h#
# Output:
#
# Batch Cost 239.7446746826172 after file 203
#
# Truth:
# h# eh n iy hv aw pau ih q w ah z hv ay tcl t ay m dh ax bcl b oy w ax s ao l tcl t ix dcl h#
# Output:
#
# Batch Cost 139.08375549316406 after file 204
#
# Truth:
# h# w iy dcl d ih tcl n aa dx ax kcl k s eh pcl dh ax dcl d ay gcl n ao s ix s q ae q w ah n s epi bcl b ah tcl g r ae zh ax l iy epi w iy q aa kcl k ah m ix ng tcl t ux h#
# Output:
# iy
# Batch Cost 259.87945556640625 after file 205
#
# Truth:
# h# ey hv y uw zh tcl t ae pcl p ax s tcl t r iy hh ah ng q ih n hv er hv ao l w ey h#
# Output:
#
# Batch Cost 135.86756896972656 after file 206
# Truth:
# h# ey r ow l ow epi w ay r hh l ey n ih axr dh ax w ao l h#
# Output:
#
# Batch Cost 91.57411193847656 after file 207
#
# Truth:
# h# hh aw dcl d uw q oy s tcl t ax z m ey kcl p er l s h#
# Output:
# p
# Batch Cost 98.61529541015625 after file 208
#
# Truth:
# h# ih n q eh v r iy m ey dcl jh axr kcl k l ow v ax l iy f tcl t r ae f ix kcl k s ah m tcl t ay ng gcl g eh s bcl b ae kcl t ah pcl h#
# Output:
#
# Batch Cost 206.8291015625 after file 209
#
# Truth:
# h# w ih m ix n m ey n eh v ax bcl b iy kcl k ah m kcl k ax m pcl p l iy tcl t l iy q iy kcl k w uh tcl t uw m eh n h#
# Output:
# h# ix ix ay epi tcl ix iy tcl
# Batch Cost 186.21888732910156 after file 210
#
# Truth:
# h# sh iy eh dcl d y er dcl d aa r kcl k s ux tcl q ih ng g r iy s iy w ao r sh epi w ao dx er q ao l y ih axr h#
# Output:
#
# Batch Cost 166.91517639160156 after file 211
#
# Truth:
# h# d ow n ae s kcl m iy dcl d ih kcl k eh r iy ix n q oy l iy r ae gcl g l ay kcl dh ae tcl h#
# Output:
#
# Batch Cost 128.80056762695312 after file 212
#
# Truth:
# h# dh iy tcl t r ah bcl el ih z th ae l ay kcl m ih nx iy s ih m bcl el z ih tcl d ah z en tcl s iy m ey v eh r iy r ih l ih s tcl t ix kcl k w ah n h#
# Output:
# tcl ae tcl m
# Batch Cost 220.57748413085938 after file 213
#
# Truth:
# h# y uh l hv ae f tcl t ix tcl t r ay ix dx ax l ow n h#
# Output:
#
# Batch Cost 90.75702667236328 after file 214
#
# Truth:
# h# hh iy tcl t ao kcl t ix bcl b aw tcl t q ah n ao th eh n tcl t ih kcl s tcl t ao r ix l ay n z tcl t ux h#
# Output:
# h#
# Batch Cost 152.76541137695312 after file 215
#
# Truth:
# h# hh ux tcl t uh kcl dh ix kcl k ay y ae kcl d aw n dh ax bcl b ay y ux h#
# Output:
# r s n ey
# Batch Cost 125.89715576171875 after file 216
#
# Truth:
# h# dh iy eh s ey q ah n dcl d en ay ax bcl b l iy r iy f l eh kcl k s aa r v y ux q ey bcl b l iy h#
# Output:
# l h#
# Batch Cost 157.32058715820312 after file 217
#
# Truth:
# h# aa l hv ae v ix s kcl k ux pcl p ax v dh ae tcl q ix gcl g z aa dx ih kcl p er pcl p el ix n tcl t er kcl k oy sh er bcl b ix tcl h#
# Output:
#
# Batch Cost 199.5898895263672 after file 218
#
# Truth:
# h# sh eh l sh aa kcl k ao z bcl b ay sh r ae pcl q n ah l ix s ah m tcl t ay m z kcl k y er dcl th r ux gcl g r ux pcl p th eh er pcl p iy h#
# Output:
# ix
# Batch Cost 221.192138671875 after file 219
#
# Truth:
# h# d aa kcl t er z pcl p axr s kcl k r ay bcl d r ah gcl g z tcl t ix f r iy l iy h#
# Output:
# h#
# Batch Cost 128.72471618652344 after file 220
#
# Truth:
# h# sh iy hv ae dcl d y er dcl d aa r kcl k s ux dx ix n gcl g r iy s iy w aa sh w ao dx er ao l y ih er h#
# Output:
# ih
# Batch Cost 160.41445922851562 after file 221
#
# Truth:
# h# d ow nx ae s kcl m iy dx ix kcl k eh r iy ix n ao l iy r ae gcl g l ay kcl dh ae tcl h#
# Output:
#
# Batch Cost 124.40882873535156 after file 222
#
# Truth:
# h# m eh n iy s ax l eh kcl k sh ix n z aa r dh ax m s eh l z kcl k en v ih n s ix ng kcl k aa n tcl t ax-h bcl b ux sh en z tcl t ax dh ih s ax-h pcl p r ey z el h#
# Output:
#
# Batch Cost 260.97265625 after file 223
#
# Truth:
# h# dh ey w eh n tcl d aw n s tcl t eh er z l ow dx ix dcl d ax tcl t r ey l ae v ix sh l iy h#
# Output:
#
# Batch Cost 137.6752471923828 after file 224
#
# Truth:
# h# n eh v er hv ae pcl p ix er ih n m aa l aa f h#
# Output:
#
# Batch Cost 94.71634674072266 after file 225
#
# Truth:
# h# hh uw ao th ax r ay z dh ih ah n l ih m ix tcl t ix dcl d ix kcl k s pcl p eh n tcl s ix kcl k aw n tcl h#
# Output:
#
# Batch Cost 152.53858947753906 after file 226
#
# Truth:
# h# t ax-h f er dh er hv ih z pcl p axr s tcl t iy dcl jh hh iy ix kcl k ey sh epi en ax l iy r iy dcl z dh ax w ao l s tcl t r iy tcl jh er n el h#
# Output:
#
# Batch Cost 208.7465362548828 after file 227
#
# Truth:
# h# l ao r ix z kcl k aa s tcl t ux m n iy dx ix dcl b l ae kcl g l ah v z tcl t ax bcl b iy kcl k ax m pcl p l iy tcl l iy eh l ax gcl g ix n tcl h#
# Output:
#
# Batch Cost 206.03985595703125 after file 228
#
# Truth:
# h# hh w ay y eh l er w er ix ow v er s ih l ix ay dx ax m z h#
# Output:
#
# Batch Cost 112.28962707519531 after file 229
#
# Truth:
# h# g eh s dh ax kcl k w eh sh tcl ch ix n f r ah m dh iy ae n tcl s axr h#
# Output:
#
# Batch Cost 113.96861267089844 after file 230
#
# Truth:
# h# sh ix hv eh dcl jh ih dcl d ah kcl k s ux q en gcl g r ix s ix w ao sh epi w ao dx axr ao l y ih axr h#
# Output:
# iy
# Batch Cost 152.16598510742188 after file 231
#
# Truth:
# h# d uh n ae s kcl k m ix dx ix kcl k eh r ix n oy l ax r ae gcl g oy kcl dh ae tcl h#
# Output:
#
# Batch Cost 122.45478820800781 after file 232
#
# Truth:
# h# q iy v ih n eh n q ix f sh ix tcl t uh kcl k w ah n s tcl t ih pcl f ow w ix dcl d hh iy kcl k ix kcl k ae tcl ch epi axr h#
# Output:
# iy s
# Batch Cost 181.47181701660156 after file 233
#
# Truth:
# h# q ao r bcl b aa r ax s em ah n ih f em s ah w ah n q eh ng gcl g ow hv ow m bcl b ay bcl b ah epi th h#
# Output:
# r tcl h#
# Batch Cost 175.00021362304688 after file 234
#
# Truth:
# h# ax-h s ey l v ow q m ey hv ae v ax bcl b ow n ih n hv axr tcl t iy dh w ah n m ih n ih q ix n l ay bcl b ax-h kcl k aa m dh ix n eh kcl s tcl t h#
# Output:
#
# Batch Cost 234.74684143066406 after file 235
#
# Truth:
# h# dh iy q eh m pcl p r ix hv ae dx ix m iy n tcl t eh m pcl p axr h#
# Output:
#
# Batch Cost 99.4884033203125 after file 236
#
# Truth:
# h# hh aw pcl p er m ix nx eh n aa dh eh r eh kcl k ix dcl d z h#
# Output:
#
# Batch Cost 97.83746337890625 after file 237
#
# Truth:
# h# dh ix m iy dx iy ng ih z epi n aw ix dcl jh er n dcl d h#
# Output:
#
# Batch Cost 90.28767395019531 after file 238
#
# Truth:
# h# k r ih dx ih kcl k el ax kcl k w ih q m ix n iy dcl d z pcl p r aa pcl p axr m ey n tcl t ix n ix n tcl t s h#
# Output:
#
# Batch Cost 164.6602783203125 after file 239
#
# Truth:
# h# t ih m tcl t ey kcl sh iy l ih tcl t s ix m uw v ix z tcl t w ay s ax w iy kcl k h#
# Output:
#
# Batch Cost 122.14502716064453 after file 240
#
# Truth:
# h# sh iy hv ae dcl d y er dcl d aa r kcl k s ux tcl t q ih n gcl g r iy s ix w aa sh epi w aa dx axr q ao l y ih axr h#
# Output:
#
# Batch Cost 179.52610778808594 after file 241
#
# Truth:
# h# d ow nx ae s kcl k m iy tcl t ux kcl k ih r ih eh n ah q ao l iy r ae gcl l ay kcl k dh ae tcl h#
# Output:
#
# Batch Cost 137.07225036621094 after file 242
#
# Truth:
# h# hh iy tcl t r ae v el dx aa l ow v ix dh ax w er l dcl d h#
# Output:
# l
# Batch Cost 100.3409652709961 after file 243
#
# Truth:
# h# b ey s bcl b ao l z epi n ow s ih n tcl ch h#
# Output:
#
# ...
# Output:
#
# Batch Cost 120.61133575439453 after file 286
#
# Truth:
# h# b iy f ao r th er z dcl d ih z ix gcl z ae m pau r iy v y uw eh v r iy f ao r m y ix l ah h#
# Output:
# ih s
# Batch Cost 157.7027587890625 after file 287
#
# Truth:
# h# dh ey q ih n dcl jh oy ix q w ih nx ay ao dcl d ih sh ix n h#
# Output:
# iy
# Batch Cost 111.26692962646484 after file 288
#
# Truth:
# h# jh eh f th ao q y ux q aa r gcl g y ux dcl d ix n f ey v axr q ah v ix s ih n tcl t axr f y ux dcl jh pcl p er tcl ch ix s h#
# Output:
#
# Batch Cost 193.8999786376953 after file 289
#
# Truth:
# h# jh aa n kcl k l iy n z epi sh eh l f ih sh f ao r ax l ih v ih ng h#
# Output:
#
# Batch Cost 117.49185180664062 after file 290
#
# Truth:
# h# sh iy hv ae dcl jh er dcl d aa r kcl k s ux tcl q ix ng gcl g r iy s ix w aa sh epi w ao dx er ao l y ih axr h#
# Output:
#
# Batch Cost 163.1885986328125 after file 291
#
# Truth:
# h# d ow nx ae s epi m iy tcl t ix kcl k eh r ih eh n oy l iy r ae gcl g l ay kcl dh ae tcl h#
# Output:
#
# Batch Cost 134.12356567382812 after file 292
#
# Truth:
# h# b ay dh ae tcl t ay m pcl p er ae pcl p s ah m th iy ng bcl b eh dx er kcl k ix n bcl b iy dcl d ah n h#
# Output:
#
# Batch Cost 158.87026977539062 after file 293
#
# Truth:
# h# dh ih s tcl t r ae dcl jh ih kcl k l ae dcl d ax hv ae dcl f ao r dcl jh dcl d hh ix z ow n epi sh ae kcl k el s h#
# Output:
#
# Batch Cost 175.70474243164062 after file 294
#
# Truth:
# h# ch eh kcl y er kcl k ae f ix tcl t iy r iy ax l ow kcl k ey sh ix n tcl t ax-h m ey kcl sh er ix tcl s kcl k en v iy n y ix n tcl f m ow s tcl t ix m pcl p l oy iy s h#
# Output:
#
# Batch Cost 283.38818359375 after file 295
#
# Truth:
# h# dh ix s aw n ix v dcl jh eh nx ix f axr z bcl b y ux gcl g el s kcl k eh r dcl dh iy ae n tcl t ax-h l ah pcl h#
# Output:
# ih
# Batch Cost 166.00848388671875 after file 296
#
# Truth:
# h# hh ay w ey eh n epi f r iy w ey m iy n ix s ey m epi th ih ng h#
# Output:
#
# Batch Cost 111.3464584350586 after file 297
#
# Truth:
# h# dh ix f aa gcl p r iy v eh n tcl t ix dcl dh eh m f em er ay v ix ng aa n tcl t ay m h#
# Output:
#
# Batch Cost 133.7436065673828 after file 298
#
# Truth:
# h# d ae f n iy s epi w iy dx ih sh epi n iy dx el pcl p oy n tcl s kcl k aa r f pau m ae tcl ch tcl t hh axr s kcl k er tcl t h#
# Output:
#
# Batch Cost 186.1701202392578 after file 299
#
# Truth:
# h# q iy v ih nx ax s ih m pcl p uh v ah kcl k ae bcl b iy l eh r ix kcl k en tcl t ey n tcl s ih m bcl b el s h#
# Output:
#
# Batch Cost 163.4691619873047 after file 300
#
# Truth:
# h# sh iy hv eh dcl jh axr dcl d aa r kcl k s ux q ix n gcl g r iy s iy w aa sh epi w ao dx axr q ao l y iy er h#
# Output:
#
# Batch Cost 160.34539794921875 after file 301
#
# Truth:
# h# d ow n q ae s epi m iy dx ix kcl k er iy ix n q oy l ix r ae gcl g l ay kcl dh ae tcl h#
# Output:
# h#
# Batch Cost 135.50103759765625 after file 302
#
# Truth:
# h# dh ix s ih s tcl t ax m w er kcl k s q eh z ix n ix m pcl p er s epi en el m eh kcl k ix n ih z ax m h#
# Output:
#
# Batch Cost 153.04673767089844 after file 303
# Truth:
# h# k l ae pcl ix ng s pcl er z tcl t ix dh ix bcl b r aa ng kcl k hh iy s eh dx ao f ix dx ix sh aa r pcl k ae n tcl t axr pau w ix th gcl g r ow ix ng q ax l aa r m h#
# Output:
#
# Batch Cost 250.59356689453125 after file 304
#
# Truth:
# h# eh v r iy th iy eng w eh n q r ih l s epi m uw dh ix sh er ix f s eh dcl h#
# Output:
#
# Batch Cost 120.22505187988281 after file 305
#
# Truth:
# h# w ay eh l tcl s w ax dcl d ae nx iy ax l aw ah dh axr z tcl t ix gcl g ow h#
# Output:
#
# Batch Cost 126.41519165039062 after file 306
#
# Truth:
# h# dh iy q ae ng g r ix bcl b oy q ae n s axr dcl bcl b ah tcl d ih dcl en tcl l uh kcl k ah pcl h#
# Output:
#
# Batch Cost 139.27490234375 after file 307
#
# Truth:
# h# dh ax kcl k aw w aa n axr dcl f axr m dh ax f aa r m l ae n q ix n bcl b iy kcl k ey m l ao s tcl t h#
# Output:
#
# Batch Cost 154.2710418701172 after file 308
#
# Truth:
# h# s iy m epi s tcl t r ix s ix z q ix tcl t ae tcl ch z ih pcl p axr z epi w ax th ey th ih m bcl el pau n iy dx el q ix n dcl th r eh dcl h#
# Output:
#
# Batch Cost 214.62242126464844 after file 309
#
# Truth:
# h# kcl k ah dx ax s epi m ao l kcl k ao r nx er q ao f iy tcl ch q eh dcl jh h#
# Output:
#
# Batch Cost 115.49385833740234 after file 310
#
# Truth:
# h# sh iy hv eh dcl jh er dcl d aa r kcl k s ux tcl en gcl g r iy s iy w aa sh epi w ao dx axr q ao l y iy er h#
# Output:
# h# h# iy
# Batch Cost 157.06971740722656 after file 311
#
# Truth:
# h# d ow n ae s kcl m iy dx ix kcl k eh r iy ix n q oy l iy r ae gcl g l ay kcl k dh ae tcl h#
# Output:
# ix n h# ix s
# Batch Cost 130.1866912841797 after file 312
#
# Truth:
# h# w ah dx ix bcl b s eh sh ix n z hv ix dcl sh iy pcl p ih kcl t ah pcl d er ix ng dh iy z l ao ng n ay tcl s ax v tcl t ao kcl k h#
# Output:
# h#
# Batch Cost 187.18519592285156 after file 313
#
# Truth:
# h# eh n dcl p ax z eh s tcl t hh ix m s eh l f pau hh aw h#
# Output:
#
# Batch Cost 95.70254516601562 after file 314
#
# Truth:
# h# dh ey w el tcl t ey kcl k ax w eh dx iy ng tcl t r ih pcl p l ey tcl t axr h#
# Output:
# h# ay h# ix s s p ae iy
# Batch Cost 125.6778335571289 after file 315
#
# Truth:
# h# dh iy eh m bcl b l ah m dcl d iy pcl p ih kcl k s dh iy ix kcl k r aa pcl p ax l ih s q ao l ax gcl g l ow h#
# Output:
#
# Batch Cost 162.62228393554688 after file 316
#
# Truth:
# h# m ih l ix tcl t eh r ix pcl p er s en eh l aa r ix kcl k s pcl p eh kcl t ix dcl t uw ow bcl b ey gcl g ah v axr m ax n ao r dcl d er z h#
# Output:
#
# Batch Cost 203.24560546875 after file 317
#
# Truth:
# h# q ow n l iy l oy er z l ah v m ih l y ix n eh er z h#
# Output:
#
# Batch Cost 94.94136047363281 after file 318
#
# Truth:
# h# q ix f kcl k eh r el kcl k ah m z tcl t ax-h m aa r ow pau hh ae v er axr r ey n jh f er m iy dx ix ng ix tcl t ux h#
# Output:
#
# Batch Cost 185.2491455078125 after file 319
#
# Truth:
# h# hh ih sh ow l dcl d er f eh l tcl t ix z ix f ix q w axr bcl b r ow kcl k ix n h#
# Output:
#
# Batch Cost 122.49869537353516 after file 320
#
# Truth:
# h# sh iy hv ae dcl d y axr dcl d aa r kcl k s ux tcl t pau ix n gcl g r iy s iy w aa sh w ao dx axr q ao l y iy axr h#
# Output:
#
# Batch Cost 167.2766571044922 after file 321
#
# Truth:
# h# dcl d ow n q ae kcl s epi m iy tcl t ix kcl k eh r iy pau ix n q ao l iy r ae gcl g l ay kcl dh ae tcl t h#
# Output:
# tcl
# Batch Cost 145.93643188476562 after file 322
#
# Truth:
# h# w ah n w ah n dcl d axr z ax bcl aw tcl t pau ix s ae pcl k ax bcl b ih l ax tcl t iy tcl t ix pcl p iy pcl el h#
# Output:
#
# Batch Cost 161.75111389160156 after file 323
#
# Truth:
# h# d ix y ux n ow w ax tcl dh ey th iy ng kcl k ax v m iy h#
# Output:
#
# Batch Cost 102.39061737060547 after file 324
#
# Truth:
# h# dh ih z ix z n aa dx ax pcl p r ow gcl g r ae m pau ax v s ow sh ax l ay z dcl m eh dx ix s ix n h#
# Output:
# m
# Batch Cost 153.36093139648438 after file 325
#
# Truth:
# h# hh uw q ao th axr r ay z pau dh iy ah n l ih m ix tcl t ix dcl q ix kcl k s pcl eh n tcl s ax kcl k aw n tcl h#
# Output:
# iy h#
# Batch Cost 154.17431640625 after file 326
#
# Truth:
# h# t ax-h f er dh axr hv ix z pcl p r ix s tcl t iy dcl jh hh iy ix kcl k ey zh ax n l iy r iy dcl z dh ax w ao l s tcl t r iy tcl jh er n el h#
# Output:
#
# Batch Cost 203.19960021972656 after file 327
#
# Truth:
# h# l ao r ix z kcl k aa s tcl t uw m pau n iy dx ix dcl b l ae kcl g l ah v z pau t ix bcl b iy kcl k ax m pcl p l iy tcl l iy pau eh l ax gcl g ix n tcl h#
# Output:
# m
# Batch Cost 219.82891845703125 after file 328
#
# Truth:
# h# w ay y eh l q ao w ih r iy pau ow v ix s ih l iy q ay dcl d ax m epi z h#
# Output:
# h# tcl iy h#
# Batch Cost 135.47479248046875 after file 329
#
# Truth:
# h# g eh s dh ax kcl k w ao r sh tcl ch ix n f axr m dh iy ae n s axr h#
# Output:
#
# Batch Cost 107.61274719238281 after file 330
#
# Truth:
# h# sh iy hv eh dcl jh axr dcl d aa r kcl k s ux tcl en gcl g r iy s iy w aa sh epi w aa dx axr ao l y ih axr h#
# Output:
#
# Batch Cost 158.79647827148438 after file 331
#
# Truth:
# h# d ow n ae s epi m iy tcl t kcl k er ih ix nx ow l ix r ae gcl g l ay kcl k dh ae tcl t h#
# Output:
#
# Batch Cost 129.2417449951172 after file 332
#
# Truth:
# h# dh ix gcl g ah n m ah n aa dcl d ih dcl d s l ih pcl p ix n ix pcl p ix tcl ch axr ix n tcl t ux s bcl b r eh s pcl p aa kcl k ix tcl s ey ix n ah th iy ng h#
# Output:
#
# Batch Cost 239.24574279785156 after file 333
#
# Truth:
# h# hh ix s ay z ah pcl dh ix s ih tcl ch uh w ey sh en ix n dcl ch uh kcl k ix z hh eh dcl d h#
# Output:
#
# Batch Cost 142.74794006347656 after file 334
#
# Truth:
# h# q ey pcl p uw l ih z n ow pcl p l ey s f axr ix sh ah tcl t r ae pcl p h#
# Output:
#
# Batch Cost 119.56525421142578 after file 335
#
# Truth:
# h# dh ey r ih m ey n l ay f l ao ng f r eh n dcl d z ix ng kcl k ix m pcl p ae n y ix n epi z h#
# Output:
#
# Batch Cost 146.83883666992188 after file 336
#
# Truth:
# h# b ay q iy dx iy ng y ow gcl g er tcl y ix m ey l ih v l ao ng gcl g axr h#
# Output:
#
# Batch Cost 117.8366470336914 after file 337
#
# Truth:
# h# d ix f r ay q en dcl ch aa l dcl d w ix z dcl jh eh q l ix s ix bcl d ux dcl b ay hv ix z bcl b ih gcl b r ah dh axr h#
# Output:
#
# Batch Cost 184.79067993164062 after file 338
#
# Truth:
# h# dh iy ow v axr w ey tcl ch aa r m axr kcl k ix dcl d s l ih pcl p oy z en ih n tcl t ix q ih n iy w ah n z tcl t iy h#
# Output:
#
# Batch Cost 171.9499053955078 after file 339
#
# Truth:
# h# k l ih f s dcl d ih s pcl p l ey w ix z bcl b ix s pcl p l ey s ao n dh s kcl k r iy n h#
# Output:
#
# Batch Cost 139.60487365722656 after file 340
#
# Truth:
# h# sh iy hv ae dcl d y axr dcl d aa r kcl k s ux tcl t ix n gcl g r iy s iy w aa sh epi w aa dx axr q ao l y ih axr h#
# Output:
# h# h#
# Batch Cost 166.78277587890625 after file 341
#
# Truth:
# h# d ow n q ae s kcl m iy tcl t ix kcl k eh r iy ix n q oy l iy r ae gcl g l ay kcl k dh ae tcl t h#
# Output:
#
# Batch Cost 141.68870544433594 after file 342
#
# Truth:
# h# q eh tcl q ih nx axr v el z pau q ix nx ax n el ah m n ay dcl d r eh kcl t r iy q ix z ih sh ux dcl d h#
# Output:
# h# l tcl
# Batch Cost 162.440185546875 after file 343
#
# Truth:
# h# y ux dcl d ux dh ae tcl q ao r tcl t ey kcl k y uw ah tcl q ax pcl p er m ih tcl t r ay tcl n aw h#
# Output:
#
# Batch Cost 149.55226135253906 after file 344
#
# Truth:
# h# y eh s ih n dcl d iy dcl d ix w iy tcl t ux kcl k ix n s iy ix w ao r l ay kcl k hh ow s tcl t q ah v q ih n f ix dcl d eh l z ix n kcl k ae m pcl t q ix gcl g eh n s tcl t ah s h#
# Output:
#
# Batch Cost 275.69842529296875 after file 345
#
# Truth:
# h# dh ix q eh m pcl p axr er hv ae dx ih m iy n tcl t eh m pcl p axr h#
# Output:
# h# h# n
# Batch Cost 120.66453552246094 after file 346
#
# Truth:
# h# hh aw pcl p er m ix n ih n tcl t q aa r dh eh axr r eh kcl k axr dcl z h#
# Output:
# h# h# h# s h#
# Batch Cost 120.26167297363281 after file 347
#
# Truth:
# h# dh ix pcl p r iy s kcl k uw l axr kcl k uh dx en tcl t v er bcl b el ay z hh axr f iy l ih ng z ax bcl b aw tcl dh iy ix m er dcl jh en s iy kcl k ix n d ih sh ax n z h#
# Output:
#
# Batch Cost 260.43695068359375 after file 348
#
# Truth:
# h# k r ih dx ih kcl k el iy kcl k w ih pcl m ix n tcl n iy dcl z pcl p r aa pcl p axr m ey tcl en eh n tcl s h#
# Output:
# h#
# Batch Cost 149.46966552734375 after file 349
#
# Truth:
# h# t ih m tcl t ey kcl k sh iy l ah tcl t ax-h s iy m uw v iy z tcl t w ay s ax w iy kcl k h#
# Output:
#
# Batch Cost 133.08741760253906 after file 350
#
# Truth:
# h# sh iy hv ae dcl d y uh dcl d ae kcl k s ux tcl ih n gcl g r iy s iy w aa sh pau w ao dx ah q ao l y ih er h#
# Output:
#
# Batch Cost 161.2371368408203 after file 351
# Truth:
# h# d ow n q ae s epi m iy dx ih kcl k ae r iy ix n oy l iy r ae gcl g l ay kcl th ae tcl h#
# Output:
#
# Batch Cost 127.47306060791016 after file 352
#
# Truth:
# h# hh ah s kcl k iy y ah ng m ae n hv iy s eh dcl pau w ih dh epi m aa kcl pau d ih s tcl t ey s tcl t h#
# Output:
#
# Batch Cost 147.59893798828125 after file 353
#
# Truth:
# h# aa hv aa hh iy th ao tcl q ey epi l ah sh dcl d ix v ao r s iy pau q ae q l ae s tcl t h#
# Output:
#
# Batch Cost 133.2965850830078 after file 354
#
# Truth:
# h# dh ah s tcl t eh kcl n ix kcl k el q ax f ih sh ix n s iy q ih z ax tcl ch iy v pau q ae tcl dh iy ih kcl k s pcl p eh n tcl t s ah v ae tcl ch uw ax l q ix kcl k s pcl p ih r iy ix n tcl t s h#
# Output:
#
# Batch Cost 313.01531982421875 after file 355
#
# Truth:
# h# aa bcl jh ih kcl s epi m ey dx ax v pcl p y uw dx axr r axr bcl b y uw dx ax f uh l h#
# Output:
#
# Batch Cost 138.7455596923828 after file 356
#
# Truth:
# h# dh ix m ao nx iy ng dcl d uw q ah n dh uh s pcl p ay dx ih w eh bcl pau g l ih s ih n dcl d ax-h pau q ih n dh ax s ah n h#
# Output:
#
# Batch Cost 182.7653350830078 after file 357
#
# Truth:
# h# ch iy pcl s tcl t aa kcl k iy ng z epi r ah n dh ax f er s tcl t ay m dh eh r w ao ax n h#
# Output:
# iy
# Batch Cost 135.23085021972656 after file 358
#
# Truth:
# h# d ow n q d ux tcl ch ae l iy z dcl d er dx iy dcl d ih sh ih z h#
# Output:
#
# Batch Cost 116.76542663574219 after file 359
#
# Truth:
# h# k ae l s iy ih m ey kcl s pau bcl b ow n z ix n tcl t iy th s tcl t r ao ng h#
# Output:
# p ih ah p iy iy q ae ey h# iy ih iy h# ae bcl ih
# Batch Cost 159.35296630859375 after file 360
#
# Truth:
# h# sh iy hv ae dcl jh er dcl d aa r kcl k s ux tcl q ix n gcl g r iy s iy w aa sh epi w ao dx er ao l y ih er h#
# Output:
#
# Batch Cost 159.78318786621094 after file 361
#
# Truth:
# h# d ow nx ae s epi m iy dx ax kcl k er iy ix n q oy l iy r ae gcl g l ay kcl k dh ae tcl h#
# Output:
#
# Batch Cost 129.60720825195312 after file 362
#
# Truth:
# h# m eh zh er dcl p axr f ao r m ix n s kcl k eh r ix kcl t axr ih s tcl t ix kcl k s f axr dh ih s ix kcl k s pcl p er ix m eh n el tcl t ux bcl b q w uh bcl b iy l ih s tcl t eh dcl h#
# Output:
#
# Batch Cost 300.385498046875 after file 363
#
# Truth:
# h# n ow tcl t eh m pcl t ey sh eh n pau n ow v er tcl ch ux h#
# Output:
#
# Batch Cost 92.33214569091797 after file 364
#
# Truth:
# h# s ax l eh kcl t iy ng bcl b ah ng kcl k s bcl b ay eh kcl k ix n aa m ix kcl k em pcl p er ix s ix nx ih zh ux zh uw ax l iy ih n q ih n dcl d ix v ih dcl jh uw el pcl p r aa bcl b l ax m h#
# Output:
#
# Batch Cost 322.0785217285156 after file 365
#
# Truth:
# h# hh ix s ah dcl en dcl d ix pcl p aa r tcl ch er sh aa kcl dh ix kcl k ae s tcl t h#
# Output:
#
# Batch Cost 117.38147735595703 after file 366
#
# Truth:
# h# q ax pcl p r ow tcl ch y er ih n er v y ux w ix th s tcl t ae tcl ch uw eh s kcl k em pcl p ow zh er h#
# Output:
#
# Batch Cost 165.94528198242188 after file 367
#
# Truth:
# h# ae l f ae l f ah ih z hh eh l th iy f axr y ux h#
# Output:
#
# Batch Cost 106.18506622314453 after file 368
#
# Truth:
# h# dh ix q ae v el l ae n tcl ch tcl t r ih gcl er dx ax m ay n er q er th kcl k w ey kcl k h#
# Output:
#
# Batch Cost 140.04498291015625 after file 369
#
# Truth:
# h# w iy w eh l kcl k ax m eh n iy n ux s tcl t ux dcl en s q iy tcl ch y ih er h#
# Output:
#
# Batch Cost 116.28408813476562 after file 370
#
# Truth:
# h# sh iy hv ae dcl d y uh dcl d aa r kcl k s ux q en gcl g r iy s iy w aa sh epi w aa dx axr q aa l y ix axr h#
# Output:
#
# Batch Cost 166.2229766845703 after file 371
#
# Truth:
# h# d ow n ae s kcl m ih dx ix kcl k eh r iy ix n q ao l iy r ae gcl g l ay kcl dh ae tcl h#
# Output:
#
# Batch Cost 127.8498764038086 after file 372
#
# Truth:
# h# dh ih s hh eh z bcl b eh n ih tcl ch ih bcl b ux dx ih dcl t ux hv ih l iy ix m f ih l m f l ow ax n dh ix v ey pcl p ax pcl p r eh sh er th ax m aa m ix dx axr h#
# Output:
#
# Batch Cost 273.0246276855469 after file 373
#
# Truth:
# h# r iy s iy v ih ng n ow q ae n s er dh ey s eh q dh ix f ay axr h#
# Output:
#
# Batch Cost 104.37840270996094 after file 374
#
# Truth:
# h# ae z ix z f iy tcl s l ow dcl hh iy f eh l tcl t ix sh ey m q ax v dh ax pcl p ae n ih kcl k ix n r ix z aa l v dcl t ix m ey kcl k ey s tcl t ae n dcl h#
# Output:
#
# Batch Cost 240.67276000976562 after file 375
#
# Truth:
# h# s ih kcl k l ix kcl k el pcl p r ow gcl g r ae m z epi w el n eh v axr kcl k ax m pcl p aa l h#
# Output:
#
# Batch Cost 143.82366943359375 after file 376
#
# Truth:
# h# k l ih r pcl p ix n aw n s iy ey sh ix n q ih z ix pcl p r iy sh iy ey dx ix dcl h#
# Output:
#
# Batch Cost 126.47528839111328 after file 377
#
# Truth:
# h# s tcl t iy v kcl k ax l eh kcl s r eh r q ix n aa v el kcl k oy n s h#
# Output:
#
# Batch Cost 112.5426025390625 after file 378
#
# Truth:
# h# ey y ux dcl jh pcl p aw axr q aw dx ix dcl jh r eh r l iy q ax kcl k er s h#
# Output:
#
# Batch Cost 124.1653060913086 after file 379

# %%
with tf.Session() as session:
    session.run(init)
    saver.restore(session,"./saver/model.ckpt")
    print("Restored")
    print(session.run(weights['out']))

# %% [markdown]
# # **NOTE**
# When using any of Tensorflow’s rnn functions with padded inputs it is important to pass the sequence_length parameter. In my opinion this parameter should be required, not optional. sequence_length serves two purposes: 1. Save computational time and 2. Ensure Correctness.
# Let’s say you have a batch of two examples, one is of length 13, and the other of length 20. Each one is a vector of 128 numbers. The length 13 example is 0-padded to length 20. Then your RNN input tensor is of shape [2, 20, 128]. The dynamic_rnn function returns a tuple of (outputs, state), where outputs is a tensor of size [2, 20, ...] with the last dimension being the RNN output at each time step. state is the last state for each example, and it’s a tensor of size [2, ...] where the last dimension also depends on what kind of RNN cell you’re using.
# So, here’s the problem: Once your reach time step 13, your first example in the batch is already “done” and you don’t want to perform any additional calculation on it. The second example isn’t and must go through the RNN until step 20. By passing sequence_length=[13,20] you tell Tensorflow to stop calculations for example 1 at step 13 and simply copy the state from time step 13 to the end. The output will be set to 0 for all time steps past 13. You’ve just saved some computational cost. But more importantly, if you didn’t pass sequence_length you would get incorrect results! Without passing sequence_length, Tensorflow will continue calculating the state until T=20 instead of simply copying the state from T=13. This means you would calculate the state using the padded elements, which is not what you want.
